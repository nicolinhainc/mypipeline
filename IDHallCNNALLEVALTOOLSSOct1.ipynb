# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolinhainc/mypipeline/blob/master/IDHallCNNALLEVALTOOLSSOct1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd '/content'
# Out:
# /content

# %%
# !wget --no-check-certificate 'https://www.dropbox.com/s/nw79ua6y1nng9s4/png.zip?dl=1' -O ./png.zip
# Out:
# --2020-04-22 19:50:54--  https://www.dropbox.com/s/nw79ua6y1nng9s4/png.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/nw79ua6y1nng9s4/png.zip [following]
# --2020-04-22 19:50:54--  https://www.dropbox.com/s/dl/nw79ua6y1nng9s4/png.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc11dd06929a81aa83dab42c22c.dl.dropboxusercontent.com/cd/0/get/A2UlUA7wK2MmyZ1c5LANVmqX8ceIdGFSimFYVAAx1fdnktVCGdCLSLzRoEFVZPnXZ8vmbXNab5hY6wiKi6e8Dr_7sbIgH-insy4KkkHHcsL8mdklaglusA5aC_tkLl-1ub0/file?dl=1# [following]
# --2020-04-22 19:50:54--  https://ucc11dd06929a81aa83dab42c22c.dl.dropboxusercontent.com/cd/0/get/A2UlUA7wK2MmyZ1c5LANVmqX8ceIdGFSimFYVAAx1fdnktVCGdCLSLzRoEFVZPnXZ8vmbXNab5hY6wiKi6e8Dr_7sbIgH-insy4KkkHHcsL8mdklaglusA5aC_tkLl-1ub0/file?dl=1
# Resolving ucc11dd06929a81aa83dab42c22c.dl.dropboxusercontent.com (ucc11dd06929a81aa83dab42c22c.dl.dropboxusercontent.com)... 162.125.1.6, 2620:100:601b:6::a27d:806
# Connecting to ucc11dd06929a81aa83dab42c22c.dl.dropboxusercontent.com (ucc11dd06929a81aa83dab42c22c.dl.dropboxusercontent.com)|162.125.1.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52732524 (50M) [application/binary]
# Saving to: ‘./png.zip’
#
# ./png.zip           100%[===================>]  50.29M  49.6MB/s    in 1.0s
#
# 2020-04-22 19:50:55 (49.6 MB/s) - ‘./png.zip’ saved [52732524/52732524]

# %%
# !unzip -q ./IDH.zip
# Out:
# warning [./IDH.zip]:  141282102 extra bytes at beginning or within zipfile
#   (attempting to process anyway)
# file #1:  bad zipfile offset (local header sig):  141282102
#   (attempting to re-compensate)
#   error:  invalid compressed data to inflate IDH/wt/pat00005/Reg-N4-t1_bet.nii.gz
# file #243:  bad zipfile offset (local header sig):  6984964
#   (attempting to re-compensate)
# file #243:  bad zipfile offset (local header sig):  6984964
# file #244:  bad zipfile offset (local header sig):  154326327
# file #245:  bad zipfile offset (local header sig):  160339867
# file #246:  bad zipfile offset (local header sig):  160342646
# file #247:  bad zipfile offset (local header sig):  160346031
# file #248:  bad zipfile offset (local header sig):  160346269
# file #249:  bad zipfile offset (local header sig):  160347243
# file #250:  bad zipfile offset (local header sig):  160347402
# file #251:  bad zipfile offset (local header sig):  160353158
# file #252:  bad zipfile offset (local header sig):  160354543
# file #253:  bad zipfile offset (local header sig):  160359347
# file #254:  bad zipfile offset (local header sig):  160360888
# file #255:  bad zipfile offset (local header sig):  160363139
# file #256:  bad zipfile offset (local header sig):  160368357
# file #257:  bad zipfile offset (local header sig):  160370417
# file #258:  bad zipfile offset (local header sig):  160373025
# file #259:  bad zipfile offset (local header sig):  160377298
# file #260:  bad zipfile offset (local header sig):  160382051
# file #261:  bad zipfile offset (local header sig):  160386044
# file #262:  bad zipfile offset (local header sig):  160390340
# file #263:  bad zipfile offset (local header sig):  160391034
# file #264:  bad zipfile offset (local header sig):  160391193
# file #265:  bad zipfile offset (local header sig):  160394508
# file #266:  bad zipfile offset (local header sig):  160400622
# file #267:  bad zipfile offset (local header sig):  160406426
# file #268:  bad zipfile offset (local header sig):  160409165
# file #269:  bad zipfile offset (local header sig):  160412499
# file #270:  bad zipfile offset (local header sig):  160412658
# file #271:  bad zipfile offset (local header sig):  160412817
# file #272:  bad zipfile offset (local header sig):  160412976
# file #273:  bad zipfile offset (local header sig):  160414132
# file #274:  bad zipfile offset (local header sig):  160418798
# file #275:  bad zipfile offset (local header sig):  160418957
# file #276:  bad zipfile offset (local header sig):  160423293
# file #277:  bad zipfile offset (local header sig):  160423452
# file #278:  bad zipfile offset (local header sig):  160423611
# file #279:  bad zipfile offset (local header sig):  160428486
# file #280:  bad zipfile offset (local header sig):  160429465
# file #281:  bad zipfile offset (local header sig):  160435496
# file #282:  bad zipfile offset (local header sig):  160440252
# file #283:  bad zipfile offset (local header sig):  160440411
# file #284:  bad zipfile offset (local header sig):  160440714
# file #285:  bad zipfile offset (local header sig):  160444146
# file #286:  bad zipfile offset (local header sig):  160446574
# file #287:  bad zipfile offset (local header sig):  160448969
# file #288:  bad zipfile offset (local header sig):  160454868
# file #289:  bad zipfile offset (local header sig):  160455492
# file #290:  bad zipfile offset (local header sig):  160458659
# file #291:  bad zipfile offset (local header sig):  160460354
# file #292:  bad zipfile offset (local header sig):  160466017
# file #293:  bad zipfile offset (local header sig):  160466797
# file #294:  bad zipfile offset (local header sig):  160471419
# file #295:  bad zipfile offset (local header sig):  160475449
# file #296:  bad zipfile offset (local header sig):  160476561
# file #297:  bad zipfile offset (local header sig):  160480600
# file #298:  bad zipfile offset (local header sig):  160483118
# file #299:  bad zipfile offset (local header sig):  160486748
# file #300:  bad zipfile offset (local header sig):  160492630
# file #301:  bad zipfile offset (local header sig):  160498827
# file #302:  bad zipfile offset (local header sig):  160502825
# file #303:  bad zipfile offset (local header sig):  160504454
# file #304:  bad zipfile offset (local header sig):  160506080
# file #305:  bad zipfile offset (local header sig):  160509015
# file #306:  bad zipfile offset (local header sig):  160514255
# file #307:  bad zipfile offset (local header sig):  160514662
# file #308:  bad zipfile offset (local header sig):  160520713
# file #309:  bad zipfile offset (local header sig):  160527319
# file #310:  bad zipfile offset (local header sig):  160529419
# file #311:  bad zipfile offset (local header sig):  160531399
# file #312:  bad zipfile offset (local header sig):  160537474
# file #313:  bad zipfile offset (local header sig):  160542374
# file #314:  bad zipfile offset (local header sig):  160546174
# file #315:  bad zipfile offset (local header sig):  160547768
# file #316:  bad zipfile offset (local header sig):  160550836
# file #317:  bad zipfile offset (local header sig):  160551891
# file #318:  bad zipfile offset (local header sig):  160557167
# file #319:  bad zipfile offset (local header sig):  160561856
# file #320:  bad zipfile offset (local header sig):  160565362
# file #321:  bad zipfile offset (local header sig):  160567514
# file #322:  bad zipfile offset (local header sig):  160568787
# file #323:  bad zipfile offset (local header sig):  160570411
# file #324:  bad zipfile offset (local header sig):  160574712
# file #325:  bad zipfile offset (local header sig):  160581072
# file #326:  bad zipfile offset (local header sig):  160584655
# file #327:  bad zipfile offset (local header sig):  160587349
# file #328:  bad zipfile offset (local header sig):  160587508
# file #329:  bad zipfile offset (local header sig):  160591209
# file #330:  bad zipfile offset (local header sig):  160595111
# file #331:  bad zipfile offset (local header sig):  160601102
# file #332:  bad zipfile offset (local header sig):  160601261
# file #333:  bad zipfile offset (local header sig):  160606895
# file #334:  bad zipfile offset (local header sig):  160608491
# file #335:  bad zipfile offset (local header sig):  160614053
# file #336:  bad zipfile offset (local header sig):  160614878
# file #337:  bad zipfile offset (local header sig):  160616679
# file #338:  bad zipfile offset (local header sig):  160616838
# file #339:  bad zipfile offset (local header sig):  160623069
# file #340:  bad zipfile offset (local header sig):  160623228
# file #341:  bad zipfile offset (local header sig):  160627674
# file #342:  bad zipfile offset (local header sig):  160627911
# file #343:  bad zipfile offset (local header sig):  160632702
# file #344:  bad zipfile offset (local header sig):  160634408
# file #345:  bad zipfile offset (local header sig):  160636935
# file #346:  bad zipfile offset (local header sig):  160640335
# file #347:  bad zipfile offset (local header sig):  160644125
# file #348:  bad zipfile offset (local header sig):  160644356
# file #349:  bad zipfile offset (local header sig):  160647786
# file #350:  bad zipfile offset (local header sig):  160648098
# file #351:  bad zipfile offset (local header sig):  160654309
# file #352:  bad zipfile offset (local header sig):  160660532
# file #353:  bad zipfile offset (local header sig):  160662410
# file #354:  bad zipfile offset (local header sig):  160663156
# file #355:  bad zipfile offset (local header sig):  160665798
# file #356:  bad zipfile offset (local header sig):  160669218
# file #357:  bad zipfile offset (local header sig):  160669377
# file #358:  bad zipfile offset (local header sig):  160675614
# file #359:  bad zipfile offset (local header sig):  160675773
# file #360:  bad zipfile offset (local header sig):  160676273
# file #361:  bad zipfile offset (local header sig):  160682392
# file #362:  bad zipfile offset (local header sig):  160683732
# file #363:  bad zipfile offset (local header sig):  160686877
# file #364:  bad zipfile offset (local header sig):  160692900
# file #365:  bad zipfile offset (local header sig):  160696013
# file #366:  bad zipfile offset (local header sig):  160698680
# file #367:  bad zipfile offset (local header sig):  160698839
# file #368:  bad zipfile offset (local header sig):  160698998
# file #369:  bad zipfile offset (local header sig):  160705324
# file #370:  bad zipfile offset (local header sig):  160705483
# file #371:  bad zipfile offset (local header sig):  160705642
# file #372:  bad zipfile offset (local header sig):  160712254
# file #373:  bad zipfile offset (local header sig):  160718175
# file #374:  bad zipfile offset (local header sig):  160721923
# file #375:  bad zipfile offset (local header sig):  160722082
# file #376:  bad zipfile offset (local header sig):  160723607
# file #377:  bad zipfile offset (local header sig):  160726876
# file #378:  bad zipfile offset (local header sig):  160727035
# file #379:  bad zipfile offset (local header sig):  160730712
# file #380:  bad zipfile offset (local header sig):  160731665
# file #381:  bad zipfile offset (local header sig):  160732660
# file #382:  bad zipfile offset (local header sig):  160738863
# file #383:  bad zipfile offset (local header sig):  160744970
# file #384:  bad zipfile offset (local header sig):  160748614
# file #385:  bad zipfile offset (local header sig):  160754964
# file #447:  bad zipfile offset (local header sig):  198625504
# file #448:  bad zipfile offset (local header sig):  198625663
# file #449:  bad zipfile offset (local header sig):  198628933
# file #450:  bad zipfile offset (local header sig):  198630618
# file #451:  bad zipfile offset (local header sig):  198631886
# file #452:  bad zipfile offset (local header sig):  198633170
# file #453:  bad zipfile offset (local header sig):  198633329
# file #454:  bad zipfile offset (local header sig):  198637729
# file #455:  bad zipfile offset (local header sig):  198637888
# file #456:  bad zipfile offset (local header sig):  198641748
# file #457:  bad zipfile offset (local header sig):  198642633
# file #458:  bad zipfile offset (local header sig):  198642792
# file #459:  bad zipfile offset (local header sig):  198647169
# file #460:  bad zipfile offset (local header sig):  198647328
# file #461:  bad zipfile offset (local header sig):  198651096
# file #462:  bad zipfile offset (local header sig):  198655960
# file #463:  bad zipfile offset (local header sig):  198659814
# file #464:  bad zipfile offset (local header sig):  198662656
# file #465:  bad zipfile offset (local header sig):  198666285
# file #466:  bad zipfile offset (local header sig):  198671334
# file #467:  bad zipfile offset (local header sig):  198677793
# file #468:  bad zipfile offset (local header sig):  198677952
# file #469:  bad zipfile offset (local header sig):  198682181
# file #470:  bad zipfile offset (local header sig):  198683645
# file #471:  bad zipfile offset (local header sig):  198683804
# file #472:  bad zipfile offset (local header sig):  198688780
# file #473:  bad zipfile offset (local header sig):  198690093
# file #474:  bad zipfile offset (local header sig):  198693018
# file #475:  bad zipfile offset (local header sig):  198697523
# file #476:  bad zipfile offset (local header sig):  198697682
# file #477:  bad zipfile offset (local header sig):  198703808
# file #478:  bad zipfile offset (local header sig):  198710253
# file #479:  bad zipfile offset (local header sig):  198716458
# file #480:  bad zipfile offset (local header sig):  198720439
# file #481:  bad zipfile offset (local header sig):  198720598
# file #482:  bad zipfile offset (local header sig):  198722056
# file #483:  bad zipfile offset (local header sig):  198722420
# file #484:  bad zipfile offset (local header sig):  198724876
# file #485:  bad zipfile offset (local header sig):  198725335
# file #486:  bad zipfile offset (local header sig):  198731645
# file #487:  bad zipfile offset (local header sig):  198731804
# file #488:  bad zipfile offset (local header sig):  198737752
# file #489:  bad zipfile offset (local header sig):  198741905
# file #490:  bad zipfile offset (local header sig):  198746872
# file #491:  bad zipfile offset (local header sig):  198752880
# file #492:  bad zipfile offset (local header sig):  198758376
# file #493:  bad zipfile offset (local header sig):  198760290
# file #494:  bad zipfile offset (local header sig):  198761236
# file #495:  bad zipfile offset (local header sig):  198767390
# file #496:  bad zipfile offset (local header sig):  198773718
# file #497:  bad zipfile offset (local header sig):  198776226
# file #498:  bad zipfile offset (local header sig):  198778259
# file #499:  bad zipfile offset (local header sig):  198782309
# file #500:  bad zipfile offset (local header sig):  198788487
# file #501:  bad zipfile offset (local header sig):  198790158
# file #502:  bad zipfile offset (local header sig):  198795823
# file #503:  bad zipfile offset (local header sig):  198796506
# file #504:  bad zipfile offset (local header sig):  198802480
# file #505:  bad zipfile offset (local header sig):  198804485
# file #506:  bad zipfile offset (local header sig):  198808839
# file #507:  bad zipfile offset (local header sig):  198812542
# file #508:  bad zipfile offset (local header sig):  198816673
# file #509:  bad zipfile offset (local header sig):  198819754
# file #510:  bad zipfile offset (local header sig):  198820132
# file #511:  bad zipfile offset (local header sig):  198826070
# file #512:  bad zipfile offset (local header sig):  198827491
# file #513:  bad zipfile offset (local header sig):  198829728
# file #514:  bad zipfile offset (local header sig):  198835972
# file #515:  bad zipfile offset (local header sig):  198836613
# file #516:  bad zipfile offset (local header sig):  198836772
# file #517:  bad zipfile offset (local header sig):  198838308
# file #518:  bad zipfile offset (local header sig):  198840649
# file #519:  bad zipfile offset (local header sig):  198840808
# file #520:  bad zipfile offset (local header sig):  198841390
# file #521:  bad zipfile offset (local header sig):  198841549
# file #522:  bad zipfile offset (local header sig):  198842563
# file #523:  bad zipfile offset (local header sig):  198843156
# file #524:  bad zipfile offset (local header sig):  198849163
# file #525:  bad zipfile offset (local header sig):  198849800
# file #526:  bad zipfile offset (local header sig):  198849959
# file #527:  bad zipfile offset (local header sig):  198853916
# file #528:  bad zipfile offset (local header sig):  198860001
# file #529:  bad zipfile offset (local header sig):  198860160
# file #530:  bad zipfile offset (local header sig):  198864990
# file #531:  bad zipfile offset (local header sig):  198865514
# file #532:  bad zipfile offset (local header sig):  198868986
# file #533:  bad zipfile offset (local header sig):  198870450
# file #534:  bad zipfile offset (local header sig):  198875288
# file #535:  bad zipfile offset (local header sig):  198879820
# file #536:  bad zipfile offset (local header sig):  198879990
# file #537:  bad zipfile offset (local header sig):  198880340
# file #538:  bad zipfile offset (local header sig):  198884901
# file #539:  bad zipfile offset (local header sig):  198885060
# file #540:  bad zipfile offset (local header sig):  198890950
# file #541:  bad zipfile offset (local header sig):  198894319
# file #542:  bad zipfile offset (local header sig):  198894478
# file #543:  bad zipfile offset (local header sig):  198896052
# file #544:  bad zipfile offset (local header sig):  198897098
# file #545:  bad zipfile offset (local header sig):  198898320
# file #546:  bad zipfile offset (local header sig):  198899678
# file #547:  bad zipfile offset (local header sig):  198902753
# file #548:  bad zipfile offset (local header sig):  198904116
# file #549:  bad zipfile offset (local header sig):  198904275
# file #550:  bad zipfile offset (local header sig):  198906814
# file #551:  bad zipfile offset (local header sig):  198906973
# file #552:  bad zipfile offset (local header sig):  198912807
# file #553:  bad zipfile offset (local header sig):  198916169
# file #554:  bad zipfile offset (local header sig):  198922064
# file #555:  bad zipfile offset (local header sig):  198922223
# file #556:  bad zipfile offset (local header sig):  198923008
# file #557:  bad zipfile offset (local header sig):  198923167
# file #558:  bad zipfile offset (local header sig):  198928171
# file #559:  bad zipfile offset (local header sig):  198928239
# file #560:  bad zipfile offset (local header sig):  198930129
# file #561:  bad zipfile offset (local header sig):  198930571
# file #562:  bad zipfile offset (local header sig):  198931380
# file #563:  bad zipfile offset (local header sig):  198934966
# file #564:  bad zipfile offset (local header sig):  198939713
# file #565:  bad zipfile offset (local header sig):  198939875
# file #566:  bad zipfile offset (local header sig):  198944900
# file #567:  bad zipfile offset (local header sig):  198950190
# file #568:  bad zipfile offset (local header sig):  198951407
# file #569:  bad zipfile offset (local header sig):  198951569
# file #570:  bad zipfile offset (local header sig):  198954796
# file #571:  bad zipfile offset (local header sig):  198959480
# file #572:  bad zipfile offset (local header sig):  198959788
# file #573:  bad zipfile offset (local header sig):  198964403
# file #574:  bad zipfile offset (local header sig):  198966691
# file #575:  bad zipfile offset (local header sig):  198966899
# file #576:  bad zipfile offset (local header sig):  198970635
# file #577:  bad zipfile offset (local header sig):  198974688
# file #578:  bad zipfile offset (local header sig):  198979101
# file #579:  bad zipfile offset (local header sig):  198979564
# file #580:  bad zipfile offset (local header sig):  198983724
# file #581:  bad zipfile offset (local header sig):  198988540
# file #582:  bad zipfile offset (local header sig):  198990583
# file #583:  bad zipfile offset (local header sig):  198995222
# file #584:  bad zipfile offset (local header sig):  198998645
# file #585:  bad zipfile offset (local header sig):  198999546
# file #586:  bad zipfile offset (local header sig):  199005701
# file #587:  bad zipfile offset (local header sig):  199005863
# file #588:  bad zipfile offset (local header sig):  199011176
# file #589:  bad zipfile offset (local header sig):  199013401
# file #590:  bad zipfile offset (local header sig):  199018209
# file #591:  bad zipfile offset (local header sig):  199022608
# file #592:  bad zipfile offset (local header sig):  199026696
# file #593:  bad zipfile offset (local header sig):  199031439
# file #594:  bad zipfile offset (local header sig):  199036852
# file #595:  bad zipfile offset (local header sig):  199038892
# file #596:  bad zipfile offset (local header sig):  199042978
# file #597:  bad zipfile offset (local header sig):  199044309
# file #598:  bad zipfile offset (local header sig):  199045849
# file #599:  bad zipfile offset (local header sig):  199046717
# file #600:  bad zipfile offset (local header sig):  199048251
# file #601:  bad zipfile offset (local header sig):  199053480
# file #602:  bad zipfile offset (local header sig):  199055885
# file #603:  bad zipfile offset (local header sig):  199059956
# file #604:  bad zipfile offset (local header sig):  199065045
# file #605:  bad zipfile offset (local header sig):  199065207
# file #606:  bad zipfile offset (local header sig):  199067347
# file #607:  bad zipfile offset (local header sig):  199069956
# file #608:  bad zipfile offset (local header sig):  199072433
# file #609:  bad zipfile offset (local header sig):  199076993
# file #610:  bad zipfile offset (local header sig):  199077155
# file #611:  bad zipfile offset (local header sig):  199080433
# file #612:  bad zipfile offset (local header sig):  199084679
# file #613:  bad zipfile offset (local header sig):  199084841
# file #614:  bad zipfile offset (local header sig):  199090010
# file #615:  bad zipfile offset (local header sig):  199090243
# file #616:  bad zipfile offset (local header sig):  199090405
# file #617:  bad zipfile offset (local header sig):  199093871
# file #618:  bad zipfile offset (local header sig):  199096401
# file #619:  bad zipfile offset (local header sig):  199098346
# file #620:  bad zipfile offset (local header sig):  199102611
# file #621:  bad zipfile offset (local header sig):  199104045
# file #622:  bad zipfile offset (local header sig):  199107786
# file #623:  bad zipfile offset (local header sig):  199112464
# file #624:  bad zipfile offset (local header sig):  199112626
# file #625:  bad zipfile offset (local header sig):  199113740
# file #626:  bad zipfile offset (local header sig):  199117406
# file #627:  bad zipfile offset (local header sig):  199120944
# file #628:  bad zipfile offset (local header sig):  199125042
# file #629:  bad zipfile offset (local header sig):  199125204
# file #1353:  bad zipfile offset (local header sig):  275757174
# file #1354:  bad zipfile offset (local header sig):  275758447
# file #1355:  bad zipfile offset (local header sig):  275761101
# file #1356:  bad zipfile offset (local header sig):  275761776
# file #1357:  bad zipfile offset (local header sig):  275767738
# file #1358:  bad zipfile offset (local header sig):  275772504
# file #1359:  bad zipfile offset (local header sig):  275777809
# file #1360:  bad zipfile offset (local header sig):  275781391
# file #1361:  bad zipfile offset (local header sig):  275784878
# file #1362:  bad zipfile offset (local header sig):  275789631
# file #1363:  bad zipfile offset (local header sig):  275795107
# file #1364:  bad zipfile offset (local header sig):  275795267
# file #1365:  bad zipfile offset (local header sig):  275797558
# file #1366:  bad zipfile offset (local header sig):  275797773
# file #1367:  bad zipfile offset (local header sig):  275799103
# file #1368:  bad zipfile offset (local header sig):  275802399
# file #1369:  bad zipfile offset (local header sig):  275804744
# file #1370:  bad zipfile offset (local header sig):  275808911
# file #1371:  bad zipfile offset (local header sig):  275813267
# file #1372:  bad zipfile offset (local header sig):  275816226
# file #1373:  bad zipfile offset (local header sig):  275817303
# file #1374:  bad zipfile offset (local header sig):  275822230
# file #1375:  bad zipfile offset (local header sig):  275822390
# file #1376:  bad zipfile offset (local header sig):  275827078
# file #1377:  bad zipfile offset (local header sig):  275831741
# file #1378:  bad zipfile offset (local header sig):  275834891
# file #1379:  bad zipfile offset (local header sig):  275835483
# file #1380:  bad zipfile offset (local header sig):  275839769
# file #1381:  bad zipfile offset (local header sig):  275842247
# file #1382:  bad zipfile offset (local header sig):  275847605
# file #1383:  bad zipfile offset (local header sig):  275848341
# file #1384:  bad zipfile offset (local header sig):  275851585
# file #1385:  bad zipfile offset (local header sig):  275851806
# file #1386:  bad zipfile offset (local header sig):  275851881
# file #1387:  bad zipfile offset (local header sig):  282796855

# %%
# Cell #7
# now we are ready to load data and train classifier
# while we did this in separate cells before, we will do it all in one
# this should look familiar.
import numpy as np
import tensorflow as tf
# !pip install tensornets
import tensornets as nets
import tensorflow_hub as hub
import keras
import tensorflow.keras 
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense,GlobalAveragePooling2D,Dropout,Flatten
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.nasnet import NASNetLarge, NASNetMobile, preprocess_input
directory = "./content"

base_model=tensorflow.keras.applications.nasnet.NASNetLarge(input_shape=(331, 331, 3), include_top=False, weights='imagenet', input_tensor=None, pooling=None) #imports the nasnet large model and discards the last 1000 neuron layer.

# diesen Teil würde ich gleich hier machen, weil die Layer unten willst du ja auch jeden fall trainable haben.
# Es geht whrs darum, die Layer von deinem TransferLearning Model trainable zu machen oder?
# Dann einfach aus model --> base_model machen:

for i,layer in enumerate(base_model.layers):
  print(i,layer.name)

#for layer in base_model.layers:
#    layer.trainable=False
# or if we want to set the first 20 layers of the network to be non-trainable
#for layer in base_model.layers[:200]:
#    layer.trainable=False
#for layer in base_model.layers[201:]:
#    layer.trainable=True






x=base_model.output
#x=Flatten()(x) #either flatten with dense OR globavgpool with last layer direct (lin 2013 paper)
x=GlobalAveragePooling2D()(x)
#x=Dropout(0.7)(x)
#x=Dense()(x) #we add dense layers so that the model can learn more complex functions and classify for better results.
x=Dense(512,activation='relu')(x) #dense layer 2
#x=Dropout(0.5)(x)

#x=Dense(1000,activation='relu')(x) #dense layer 3
preds=Dense(2,activation='softmax')(x) #final layer with softmax activation, for 2 classes

# Also ich verwende als ClassificationLayer immer sigmoid bei binary Classification.
# Der Wert der dann raus kommt, ist einfach die Wahrscheinlichkeit: 
# Ergebnis 0.0 --> ganz sicher Klasse 0
# Ergebnis 1.0 --> ganz sicher Klasse 1
# Ergebnis 0.5 --> ganz unsicher welche Klasse.

#preds=Dense(1,activation='sigmoid')(x)

model=Model(inputs=base_model.input,outputs=preds) 
# to load saved model with weights use 
#model= tensorflow.keras.models.load_model('./3epochtester')
#specify the inputs
#specify the outputs
#now a model has been created based on our architecture

model.trainable = True    
set_trainable = False
for layer in model.layers:
  if layer.name == 'activation_249':
    set_trainable = True
  if set_trainable:
    layer.trainable = True
  else:
    layer.trainable = False
  print("layer {} is {}".format(layer.name, '+++trainable' if layer.trainable else '---frozen'))




train_datagen=ImageDataGenerator(rotation_range=10, zoom_range=0.1, width_shift_range=0.1, height_shift_range=0.1, shear_range=0, brightness_range=[0.01,100], fill_mode='nearest', horizontal_flip=True, data_format='channels_last', validation_split=0.0, dtype='float32') #included in our dependencies
# add the directory below very important ##########################

train=train_datagen.flow_from_directory('./IDH/train',
                                                 target_size=(331,331),
                                                 color_mode='rgb',
                                                 batch_size=30,
                                                 class_mode='categorical',
                                                 shuffle=True)

val_datagen=ImageDataGenerator()

val=val_datagen.flow_from_directory('./IDH/validate',
                                                 target_size=(331,331),
                                                 color_mode='rgb',
                                                 batch_size=30,
                                                 class_mode='categorical',
                                                 shuffle=False)

# auch hier, wenn du nur 2 Klassen hast, dann nimmt man eig binary_crossentropy
#model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])


# Adam optimizer
# loss function will be categorical cross entropy
# evaluation metric will be accuracy

step_size_train=train.n//train.batch_size
step_size_val=val.n//val.batch_size
#model.fit_generator(generator=train_generator,
#                   steps_per_epoch=step_size_train,
#                   epochs=3)

history = model.fit(train, steps_per_epoch=step_size_train, epochs=3,
                              validation_data=val, validation_steps=step_size_val, 
                              verbose=1)
# Out:
# Requirement already satisfied: tensornets in /usr/local/lib/python3.6/dist-packages (0.4.6)
# 0 input_1
# 1 stem_conv1
# 2 stem_bn1
# 3 activation
# 4 reduction_conv_1_stem_1
# 5 reduction_bn_1_stem_1
# 6 activation_1
# 7 activation_3
# 8 separable_conv_1_pad_reduction_left1_stem_1
# 9 separable_conv_1_pad_reduction_right1_stem_1
# 10 separable_conv_1_reduction_left1_stem_1
# 11 separable_conv_1_reduction_right1_stem_1
# 12 separable_conv_1_bn_reduction_left1_stem_1
# 13 separable_conv_1_bn_reduction_right1_stem_1
# 14 activation_2
# 15 activation_4
# 16 separable_conv_2_reduction_left1_stem_1
# 17 separable_conv_2_reduction_right1_stem_1
# 18 activation_5
# 19 separable_conv_2_bn_reduction_left1_stem_1
# 20 separable_conv_2_bn_reduction_right1_stem_1
# 21 separable_conv_1_pad_reduction_right2_stem_1
# 22 activation_7
# 23 reduction_add_1_stem_1
# 24 separable_conv_1_reduction_right2_stem_1
# 25 separable_conv_1_pad_reduction_right3_stem_1
# 26 activation_9
# 27 separable_conv_1_bn_reduction_right2_stem_1
# 28 separable_conv_1_reduction_right3_stem_1
# 29 separable_conv_1_reduction_left4_stem_1
# 30 activation_6
# 31 separable_conv_1_bn_reduction_right3_stem_1
# 32 separable_conv_1_bn_reduction_left4_stem_1
# 33 reduction_pad_1_stem_1
# 34 separable_conv_2_reduction_right2_stem_1
# 35 activation_8
# 36 activation_10
# 37 reduction_left2_stem_1
# 38 separable_conv_2_bn_reduction_right2_stem_1
# 39 separable_conv_2_reduction_right3_stem_1
# 40 separable_conv_2_reduction_left4_stem_1
# 41 adjust_relu_1_stem_2
# 42 reduction_add_2_stem_1
# 43 reduction_left3_stem_1
# 44 separable_conv_2_bn_reduction_right3_stem_1
# 45 reduction_left4_stem_1
# 46 separable_conv_2_bn_reduction_left4_stem_1
# 47 reduction_right5_stem_1
# 48 zero_padding2d
# 49 reduction_add3_stem_1
# 50 add
# 51 reduction_add4_stem_1
# 52 cropping2d
# 53 reduction_concat_stem_1
# 54 adjust_avg_pool_1_stem_2
# 55 adjust_avg_pool_2_stem_2
# 56 activation_11
# 57 adjust_conv_1_stem_2
# 58 adjust_conv_2_stem_2
# 59 reduction_conv_1_stem_2
# 60 concatenate
# 61 reduction_bn_1_stem_2
# 62 adjust_bn_stem_2
# 63 activation_12
# 64 activation_14
# 65 separable_conv_1_pad_reduction_left1_stem_2
# 66 separable_conv_1_pad_reduction_right1_stem_2
# 67 separable_conv_1_reduction_left1_stem_2
# 68 separable_conv_1_reduction_right1_stem_2
# 69 separable_conv_1_bn_reduction_left1_stem_2
# 70 separable_conv_1_bn_reduction_right1_stem_2
# 71 activation_13
# 72 activation_15
# 73 separable_conv_2_reduction_left1_stem_2
# 74 separable_conv_2_reduction_right1_stem_2
# 75 activation_16
# 76 separable_conv_2_bn_reduction_left1_stem_2
# 77 separable_conv_2_bn_reduction_right1_stem_2
# 78 separable_conv_1_pad_reduction_right2_stem_2
# 79 activation_18
# 80 reduction_add_1_stem_2
# 81 separable_conv_1_reduction_right2_stem_2
# 82 separable_conv_1_pad_reduction_right3_stem_2
# 83 activation_20
# 84 separable_conv_1_bn_reduction_right2_stem_2
# 85 separable_conv_1_reduction_right3_stem_2
# 86 separable_conv_1_reduction_left4_stem_2
# 87 activation_17
# 88 separable_conv_1_bn_reduction_right3_stem_2
# 89 separable_conv_1_bn_reduction_left4_stem_2
# 90 reduction_pad_1_stem_2
# 91 separable_conv_2_reduction_right2_stem_2
# 92 activation_19
# 93 activation_21
# 94 reduction_left2_stem_2
# 95 separable_conv_2_bn_reduction_right2_stem_2
# 96 separable_conv_2_reduction_right3_stem_2
# 97 separable_conv_2_reduction_left4_stem_2
# 98 adjust_relu_1_0
# 99 reduction_add_2_stem_2
# 100 reduction_left3_stem_2
# 101 separable_conv_2_bn_reduction_right3_stem_2
# 102 reduction_left4_stem_2
# 103 separable_conv_2_bn_reduction_left4_stem_2
# 104 reduction_right5_stem_2
# 105 zero_padding2d_1
# 106 reduction_add3_stem_2
# 107 add_1
# 108 reduction_add4_stem_2
# 109 cropping2d_1
# 110 reduction_concat_stem_2
# 111 adjust_avg_pool_1_0
# 112 adjust_avg_pool_2_0
# 113 adjust_conv_1_0
# 114 adjust_conv_2_0
# 115 activation_22
# 116 concatenate_1
# 117 normal_conv_1_0
# 118 adjust_bn_0
# 119 normal_bn_1_0
# 120 activation_23
# 121 activation_25
# 122 activation_27
# 123 activation_29
# 124 activation_31
# 125 separable_conv_1_normal_left1_0
# 126 separable_conv_1_normal_right1_0
# 127 separable_conv_1_normal_left2_0
# 128 separable_conv_1_normal_right2_0
# 129 separable_conv_1_normal_left5_0
# 130 separable_conv_1_bn_normal_left1_0
# 131 separable_conv_1_bn_normal_right1_0
# 132 separable_conv_1_bn_normal_left2_0
# 133 separable_conv_1_bn_normal_right2_0
# 134 separable_conv_1_bn_normal_left5_0
# 135 activation_24
# 136 activation_26
# 137 activation_28
# 138 activation_30
# 139 activation_32
# 140 separable_conv_2_normal_left1_0
# 141 separable_conv_2_normal_right1_0
# 142 separable_conv_2_normal_left2_0
# 143 separable_conv_2_normal_right2_0
# 144 separable_conv_2_normal_left5_0
# 145 separable_conv_2_bn_normal_left1_0
# 146 separable_conv_2_bn_normal_right1_0
# 147 separable_conv_2_bn_normal_left2_0
# 148 separable_conv_2_bn_normal_right2_0
# 149 normal_left3_0
# 150 normal_left4_0
# 151 normal_right4_0
# 152 separable_conv_2_bn_normal_left5_0
# 153 normal_add_1_0
# 154 normal_add_2_0
# 155 normal_add_3_0
# 156 normal_add_4_0
# 157 normal_add_5_0
# 158 normal_concat_0
# 159 activation_33
# 160 activation_34
# 161 adjust_conv_projection_1
# 162 normal_conv_1_1
# 163 adjust_bn_1
# 164 normal_bn_1_1
# 165 activation_35
# 166 activation_37
# 167 activation_39
# 168 activation_41
# 169 activation_43
# 170 separable_conv_1_normal_left1_1
# 171 separable_conv_1_normal_right1_1
# 172 separable_conv_1_normal_left2_1
# 173 separable_conv_1_normal_right2_1
# 174 separable_conv_1_normal_left5_1
# 175 separable_conv_1_bn_normal_left1_1
# 176 separable_conv_1_bn_normal_right1_1
# 177 separable_conv_1_bn_normal_left2_1
# 178 separable_conv_1_bn_normal_right2_1
# 179 separable_conv_1_bn_normal_left5_1
# 180 activation_36
# 181 activation_38
# 182 activation_40
# 183 activation_42
# 184 activation_44
# 185 separable_conv_2_normal_left1_1
# 186 separable_conv_2_normal_right1_1
# 187 separable_conv_2_normal_left2_1
# 188 separable_conv_2_normal_right2_1
# 189 separable_conv_2_normal_left5_1
# 190 separable_conv_2_bn_normal_left1_1
# 191 separable_conv_2_bn_normal_right1_1
# 192 separable_conv_2_bn_normal_left2_1
# 193 separable_conv_2_bn_normal_right2_1
# 194 normal_left3_1
# 195 normal_left4_1
# 196 normal_right4_1
# 197 separable_conv_2_bn_normal_left5_1
# 198 normal_add_1_1
# 199 normal_add_2_1
# 200 normal_add_3_1
# 201 normal_add_4_1
# 202 normal_add_5_1
# 203 normal_concat_1
# 204 activation_45
# 205 activation_46
# 206 adjust_conv_projection_2
# 207 normal_conv_1_2
# 208 adjust_bn_2
# 209 normal_bn_1_2
# 210 activation_47
# 211 activation_49
# 212 activation_51
# 213 activation_53
# 214 activation_55
# 215 separable_conv_1_normal_left1_2
# 216 separable_conv_1_normal_right1_2
# 217 separable_conv_1_normal_left2_2
# 218 separable_conv_1_normal_right2_2
# 219 separable_conv_1_normal_left5_2
# 220 separable_conv_1_bn_normal_left1_2
# 221 separable_conv_1_bn_normal_right1_2
# 222 separable_conv_1_bn_normal_left2_2
# 223 separable_conv_1_bn_normal_right2_2
# 224 separable_conv_1_bn_normal_left5_2
# 225 activation_48
# 226 activation_50
# 227 activation_52
# 228 activation_54
# 229 activation_56
# 230 separable_conv_2_normal_left1_2
# 231 separable_conv_2_normal_right1_2
# 232 separable_conv_2_normal_left2_2
# 233 separable_conv_2_normal_right2_2
# 234 separable_conv_2_normal_left5_2
# 235 separable_conv_2_bn_normal_left1_2
# 236 separable_conv_2_bn_normal_right1_2
# 237 separable_conv_2_bn_normal_left2_2
# 238 separable_conv_2_bn_normal_right2_2
# 239 normal_left3_2
# 240 normal_left4_2
# 241 normal_right4_2
# 242 separable_conv_2_bn_normal_left5_2
# 243 normal_add_1_2
# 244 normal_add_2_2
# 245 normal_add_3_2
# 246 normal_add_4_2
# 247 normal_add_5_2
# 248 normal_concat_2
# 249 activation_57
# 250 activation_58
# 251 adjust_conv_projection_3
# 252 normal_conv_1_3
# 253 adjust_bn_3
# 254 normal_bn_1_3
# 255 activation_59
# 256 activation_61
# 257 activation_63
# 258 activation_65
# 259 activation_67
# 260 separable_conv_1_normal_left1_3
# 261 separable_conv_1_normal_right1_3
# 262 separable_conv_1_normal_left2_3
# 263 separable_conv_1_normal_right2_3
# 264 separable_conv_1_normal_left5_3
# 265 separable_conv_1_bn_normal_left1_3
# 266 separable_conv_1_bn_normal_right1_3
# 267 separable_conv_1_bn_normal_left2_3
# 268 separable_conv_1_bn_normal_right2_3
# 269 separable_conv_1_bn_normal_left5_3
# 270 activation_60
# 271 activation_62
# 272 activation_64
# 273 activation_66
# 274 activation_68
# 275 separable_conv_2_normal_left1_3
# 276 separable_conv_2_normal_right1_3
# 277 separable_conv_2_normal_left2_3
# 278 separable_conv_2_normal_right2_3
# 279 separable_conv_2_normal_left5_3
# 280 separable_conv_2_bn_normal_left1_3
# 281 separable_conv_2_bn_normal_right1_3
# 282 separable_conv_2_bn_normal_left2_3
# 283 separable_conv_2_bn_normal_right2_3
# 284 normal_left3_3
# 285 normal_left4_3
# 286 normal_right4_3
# 287 separable_conv_2_bn_normal_left5_3
# 288 normal_add_1_3
# 289 normal_add_2_3
# 290 normal_add_3_3
# 291 normal_add_4_3
# 292 normal_add_5_3
# 293 normal_concat_3
# 294 activation_69
# 295 activation_70
# 296 adjust_conv_projection_4
# 297 normal_conv_1_4
# 298 adjust_bn_4
# 299 normal_bn_1_4
# 300 activation_71
# 301 activation_73
# 302 activation_75
# 303 activation_77
# 304 activation_79
# 305 separable_conv_1_normal_left1_4
# 306 separable_conv_1_normal_right1_4
# 307 separable_conv_1_normal_left2_4
# 308 separable_conv_1_normal_right2_4
# 309 separable_conv_1_normal_left5_4
# 310 separable_conv_1_bn_normal_left1_4
# 311 separable_conv_1_bn_normal_right1_4
# 312 separable_conv_1_bn_normal_left2_4
# 313 separable_conv_1_bn_normal_right2_4
# 314 separable_conv_1_bn_normal_left5_4
# 315 activation_72
# 316 activation_74
# 317 activation_76
# 318 activation_78
# 319 activation_80
# 320 separable_conv_2_normal_left1_4
# 321 separable_conv_2_normal_right1_4
# 322 separable_conv_2_normal_left2_4
# 323 separable_conv_2_normal_right2_4
# 324 separable_conv_2_normal_left5_4
# 325 separable_conv_2_bn_normal_left1_4
# 326 separable_conv_2_bn_normal_right1_4
# 327 separable_conv_2_bn_normal_left2_4
# 328 separable_conv_2_bn_normal_right2_4
# 329 normal_left3_4
# 330 normal_left4_4
# 331 normal_right4_4
# 332 separable_conv_2_bn_normal_left5_4
# 333 normal_add_1_4
# 334 normal_add_2_4
# 335 normal_add_3_4
# 336 normal_add_4_4
# 337 normal_add_5_4
# 338 normal_concat_4
# 339 activation_81
# 340 activation_82
# 341 adjust_conv_projection_5
# 342 normal_conv_1_5
# 343 adjust_bn_5
# 344 normal_bn_1_5
# 345 activation_83
# 346 activation_85
# 347 activation_87
# 348 activation_89
# 349 activation_91
# 350 separable_conv_1_normal_left1_5
# 351 separable_conv_1_normal_right1_5
# 352 separable_conv_1_normal_left2_5
# 353 separable_conv_1_normal_right2_5
# 354 separable_conv_1_normal_left5_5
# 355 separable_conv_1_bn_normal_left1_5
# 356 separable_conv_1_bn_normal_right1_5
# 357 separable_conv_1_bn_normal_left2_5
# 358 separable_conv_1_bn_normal_right2_5
# 359 separable_conv_1_bn_normal_left5_5
# 360 activation_84
# 361 activation_86
# 362 activation_88
# 363 activation_90
# 364 activation_92
# 365 separable_conv_2_normal_left1_5
# 366 separable_conv_2_normal_right1_5
# 367 separable_conv_2_normal_left2_5
# 368 separable_conv_2_normal_right2_5
# 369 separable_conv_2_normal_left5_5
# 370 separable_conv_2_bn_normal_left1_5
# 371 separable_conv_2_bn_normal_right1_5
# 372 separable_conv_2_bn_normal_left2_5
# 373 separable_conv_2_bn_normal_right2_5
# 374 normal_left3_5
# 375 normal_left4_5
# 376 normal_right4_5
# 377 separable_conv_2_bn_normal_left5_5
# 378 normal_add_1_5
# 379 normal_add_2_5
# 380 normal_add_3_5
# 381 normal_add_4_5
# 382 normal_add_5_5
# 383 normal_concat_5
# 384 activation_94
# 385 activation_93
# 386 reduction_conv_1_reduce_6
# 387 adjust_conv_projection_reduce_6
# 388 reduction_bn_1_reduce_6
# 389 adjust_bn_reduce_6
# 390 activation_95
# 391 activation_97
# 392 separable_conv_1_pad_reduction_left1_reduce_6
# 393 separable_conv_1_pad_reduction_right1_reduce_6
# 394 separable_conv_1_reduction_left1_reduce_6
# 395 separable_conv_1_reduction_right1_reduce_6
# 396 separable_conv_1_bn_reduction_left1_reduce_6
# 397 separable_conv_1_bn_reduction_right1_reduce_6
# 398 activation_96
# 399 activation_98
# 400 separable_conv_2_reduction_left1_reduce_6
# 401 separable_conv_2_reduction_right1_reduce_6
# 402 activation_99
# 403 separable_conv_2_bn_reduction_left1_reduce_6
# 404 separable_conv_2_bn_reduction_right1_reduce_6
# 405 separable_conv_1_pad_reduction_right2_reduce_6
# 406 activation_101
# 407 reduction_add_1_reduce_6
# 408 separable_conv_1_reduction_right2_reduce_6
# 409 separable_conv_1_pad_reduction_right3_reduce_6
# 410 activation_103
# 411 separable_conv_1_bn_reduction_right2_reduce_6
# 412 separable_conv_1_reduction_right3_reduce_6
# 413 separable_conv_1_reduction_left4_reduce_6
# 414 activation_100
# 415 separable_conv_1_bn_reduction_right3_reduce_6
# 416 separable_conv_1_bn_reduction_left4_reduce_6
# 417 reduction_pad_1_reduce_6
# 418 separable_conv_2_reduction_right2_reduce_6
# 419 activation_102
# 420 activation_104
# 421 reduction_left2_reduce_6
# 422 separable_conv_2_bn_reduction_right2_reduce_6
# 423 separable_conv_2_reduction_right3_reduce_6
# 424 separable_conv_2_reduction_left4_reduce_6
# 425 adjust_relu_1_7
# 426 reduction_add_2_reduce_6
# 427 reduction_left3_reduce_6
# 428 separable_conv_2_bn_reduction_right3_reduce_6
# 429 reduction_left4_reduce_6
# 430 separable_conv_2_bn_reduction_left4_reduce_6
# 431 reduction_right5_reduce_6
# 432 zero_padding2d_2
# 433 reduction_add3_reduce_6
# 434 add_2
# 435 reduction_add4_reduce_6
# 436 cropping2d_2
# 437 reduction_concat_reduce_6
# 438 adjust_avg_pool_1_7
# 439 adjust_avg_pool_2_7
# 440 adjust_conv_1_7
# 441 adjust_conv_2_7
# 442 activation_105
# 443 concatenate_2
# 444 normal_conv_1_7
# 445 adjust_bn_7
# 446 normal_bn_1_7
# 447 activation_106
# 448 activation_108
# 449 activation_110
# 450 activation_112
# 451 activation_114
# 452 separable_conv_1_normal_left1_7
# 453 separable_conv_1_normal_right1_7
# 454 separable_conv_1_normal_left2_7
# 455 separable_conv_1_normal_right2_7
# 456 separable_conv_1_normal_left5_7
# 457 separable_conv_1_bn_normal_left1_7
# 458 separable_conv_1_bn_normal_right1_7
# 459 separable_conv_1_bn_normal_left2_7
# 460 separable_conv_1_bn_normal_right2_7
# 461 separable_conv_1_bn_normal_left5_7
# 462 activation_107
# 463 activation_109
# 464 activation_111
# 465 activation_113
# 466 activation_115
# 467 separable_conv_2_normal_left1_7
# 468 separable_conv_2_normal_right1_7
# 469 separable_conv_2_normal_left2_7
# 470 separable_conv_2_normal_right2_7
# 471 separable_conv_2_normal_left5_7
# 472 separable_conv_2_bn_normal_left1_7
# 473 separable_conv_2_bn_normal_right1_7
# 474 separable_conv_2_bn_normal_left2_7
# 475 separable_conv_2_bn_normal_right2_7
# 476 normal_left3_7
# 477 normal_left4_7
# 478 normal_right4_7
# 479 separable_conv_2_bn_normal_left5_7
# 480 normal_add_1_7
# 481 normal_add_2_7
# 482 normal_add_3_7
# 483 normal_add_4_7
# 484 normal_add_5_7
# 485 normal_concat_7
# 486 activation_116
# 487 activation_117
# 488 adjust_conv_projection_8
# 489 normal_conv_1_8
# 490 adjust_bn_8
# 491 normal_bn_1_8
# 492 activation_118
# 493 activation_120
# 494 activation_122
# 495 activation_124
# 496 activation_126
# 497 separable_conv_1_normal_left1_8
# 498 separable_conv_1_normal_right1_8
# 499 separable_conv_1_normal_left2_8
# 500 separable_conv_1_normal_right2_8
# 501 separable_conv_1_normal_left5_8
# 502 separable_conv_1_bn_normal_left1_8
# 503 separable_conv_1_bn_normal_right1_8
# 504 separable_conv_1_bn_normal_left2_8
# 505 separable_conv_1_bn_normal_right2_8
# 506 separable_conv_1_bn_normal_left5_8
# 507 activation_119
# 508 activation_121
# 509 activation_123
# 510 activation_125
# 511 activation_127
# 512 separable_conv_2_normal_left1_8
# 513 separable_conv_2_normal_right1_8
# 514 separable_conv_2_normal_left2_8
# 515 separable_conv_2_normal_right2_8
# 516 separable_conv_2_normal_left5_8
# 517 separable_conv_2_bn_normal_left1_8
# 518 separable_conv_2_bn_normal_right1_8
# 519 separable_conv_2_bn_normal_left2_8
# 520 separable_conv_2_bn_normal_right2_8
# 521 normal_left3_8
# 522 normal_left4_8
# 523 normal_right4_8
# 524 separable_conv_2_bn_normal_left5_8
# 525 normal_add_1_8
# 526 normal_add_2_8
# 527 normal_add_3_8
# 528 normal_add_4_8
# 529 normal_add_5_8
# 530 normal_concat_8
# 531 activation_128
# 532 activation_129
# 533 adjust_conv_projection_9
# 534 normal_conv_1_9
# 535 adjust_bn_9
# 536 normal_bn_1_9
# 537 activation_130
# 538 activation_132
# 539 activation_134
# 540 activation_136
# 541 activation_138
# 542 separable_conv_1_normal_left1_9
# 543 separable_conv_1_normal_right1_9
# 544 separable_conv_1_normal_left2_9
# 545 separable_conv_1_normal_right2_9
# 546 separable_conv_1_normal_left5_9
# 547 separable_conv_1_bn_normal_left1_9
# 548 separable_conv_1_bn_normal_right1_9
# 549 separable_conv_1_bn_normal_left2_9
# 550 separable_conv_1_bn_normal_right2_9
# 551 separable_conv_1_bn_normal_left5_9
# 552 activation_131
# 553 activation_133
# 554 activation_135
# 555 activation_137
# 556 activation_139
# 557 separable_conv_2_normal_left1_9
# 558 separable_conv_2_normal_right1_9
# 559 separable_conv_2_normal_left2_9
# 560 separable_conv_2_normal_right2_9
# 561 separable_conv_2_normal_left5_9
# 562 separable_conv_2_bn_normal_left1_9
# 563 separable_conv_2_bn_normal_right1_9
# 564 separable_conv_2_bn_normal_left2_9
# 565 separable_conv_2_bn_normal_right2_9
# 566 normal_left3_9
# 567 normal_left4_9
# 568 normal_right4_9
# 569 separable_conv_2_bn_normal_left5_9
# 570 normal_add_1_9
# 571 normal_add_2_9
# 572 normal_add_3_9
# 573 normal_add_4_9
# 574 normal_add_5_9
# 575 normal_concat_9
# 576 activation_140
# 577 activation_141
# 578 adjust_conv_projection_10
# 579 normal_conv_1_10
# 580 adjust_bn_10
# 581 normal_bn_1_10
# 582 activation_142
# 583 activation_144
# 584 activation_146
# 585 activation_148
# 586 activation_150
# 587 separable_conv_1_normal_left1_10
# 588 separable_conv_1_normal_right1_10
# 589 separable_conv_1_normal_left2_10
# 590 separable_conv_1_normal_right2_10
# 591 separable_conv_1_normal_left5_10
# 592 separable_conv_1_bn_normal_left1_10
# 593 separable_conv_1_bn_normal_right1_10
# 594 separable_conv_1_bn_normal_left2_10
# 595 separable_conv_1_bn_normal_right2_10
# 596 separable_conv_1_bn_normal_left5_10
# 597 activation_143
# 598 activation_145
# 599 activation_147
# 600 activation_149
# 601 activation_151
# 602 separable_conv_2_normal_left1_10
# 603 separable_conv_2_normal_right1_10
# 604 separable_conv_2_normal_left2_10
# 605 separable_conv_2_normal_right2_10
# 606 separable_conv_2_normal_left5_10
# 607 separable_conv_2_bn_normal_left1_10
# 608 separable_conv_2_bn_normal_right1_10
# 609 separable_conv_2_bn_normal_left2_10
# 610 separable_conv_2_bn_normal_right2_10
# 611 normal_left3_10
# 612 normal_left4_10
# 613 normal_right4_10
# 614 separable_conv_2_bn_normal_left5_10
# 615 normal_add_1_10
# 616 normal_add_2_10
# 617 normal_add_3_10
# 618 normal_add_4_10
# 619 normal_add_5_10
# 620 normal_concat_10
# 621 activation_152
# 622 activation_153
# 623 adjust_conv_projection_11
# 624 normal_conv_1_11
# 625 adjust_bn_11
# 626 normal_bn_1_11
# 627 activation_154
# 628 activation_156
# 629 activation_158
# 630 activation_160
# 631 activation_162
# 632 separable_conv_1_normal_left1_11
# 633 separable_conv_1_normal_right1_11
# 634 separable_conv_1_normal_left2_11
# 635 separable_conv_1_normal_right2_11
# 636 separable_conv_1_normal_left5_11
# 637 separable_conv_1_bn_normal_left1_11
# 638 separable_conv_1_bn_normal_right1_11
# 639 separable_conv_1_bn_normal_left2_11
# 640 separable_conv_1_bn_normal_right2_11
# 641 separable_conv_1_bn_normal_left5_11
# 642 activation_155
# 643 activation_157
# 644 activation_159
# 645 activation_161
# 646 activation_163
# 647 separable_conv_2_normal_left1_11
# 648 separable_conv_2_normal_right1_11
# 649 separable_conv_2_normal_left2_11
# 650 separable_conv_2_normal_right2_11
# 651 separable_conv_2_normal_left5_11
# 652 separable_conv_2_bn_normal_left1_11
# 653 separable_conv_2_bn_normal_right1_11
# 654 separable_conv_2_bn_normal_left2_11
# 655 separable_conv_2_bn_normal_right2_11
# 656 normal_left3_11
# 657 normal_left4_11
# 658 normal_right4_11
# 659 separable_conv_2_bn_normal_left5_11
# 660 normal_add_1_11
# 661 normal_add_2_11
# 662 normal_add_3_11
# 663 normal_add_4_11
# 664 normal_add_5_11
# 665 normal_concat_11
# 666 activation_164
# 667 activation_165
# 668 adjust_conv_projection_12
# 669 normal_conv_1_12
# 670 adjust_bn_12
# 671 normal_bn_1_12
# 672 activation_166
# 673 activation_168
# 674 activation_170
# 675 activation_172
# 676 activation_174
# 677 separable_conv_1_normal_left1_12
# 678 separable_conv_1_normal_right1_12
# 679 separable_conv_1_normal_left2_12
# 680 separable_conv_1_normal_right2_12
# 681 separable_conv_1_normal_left5_12
# 682 separable_conv_1_bn_normal_left1_12
# 683 separable_conv_1_bn_normal_right1_12
# 684 separable_conv_1_bn_normal_left2_12
# 685 separable_conv_1_bn_normal_right2_12
# 686 separable_conv_1_bn_normal_left5_12
# 687 activation_167
# 688 activation_169
# 689 activation_171
# 690 activation_173
# 691 activation_175
# 692 separable_conv_2_normal_left1_12
# 693 separable_conv_2_normal_right1_12
# 694 separable_conv_2_normal_left2_12
# 695 separable_conv_2_normal_right2_12
# 696 separable_conv_2_normal_left5_12
# 697 separable_conv_2_bn_normal_left1_12
# 698 separable_conv_2_bn_normal_right1_12
# 699 separable_conv_2_bn_normal_left2_12
# 700 separable_conv_2_bn_normal_right2_12
# 701 normal_left3_12
# 702 normal_left4_12
# 703 normal_right4_12
# 704 separable_conv_2_bn_normal_left5_12
# 705 normal_add_1_12
# 706 normal_add_2_12
# 707 normal_add_3_12
# 708 normal_add_4_12
# 709 normal_add_5_12
# 710 normal_concat_12
# 711 activation_177
# 712 activation_176
# 713 reduction_conv_1_reduce_12
# 714 adjust_conv_projection_reduce_12
# 715 reduction_bn_1_reduce_12
# 716 adjust_bn_reduce_12
# 717 activation_178
# 718 activation_180
# 719 separable_conv_1_pad_reduction_left1_reduce_12
# 720 separable_conv_1_pad_reduction_right1_reduce_12
# 721 separable_conv_1_reduction_left1_reduce_12
# 722 separable_conv_1_reduction_right1_reduce_12
# 723 separable_conv_1_bn_reduction_left1_reduce_12
# 724 separable_conv_1_bn_reduction_right1_reduce_12
# 725 activation_179
# 726 activation_181
# 727 separable_conv_2_reduction_left1_reduce_12
# 728 separable_conv_2_reduction_right1_reduce_12
# 729 activation_182
# 730 separable_conv_2_bn_reduction_left1_reduce_12
# 731 separable_conv_2_bn_reduction_right1_reduce_12
# 732 separable_conv_1_pad_reduction_right2_reduce_12
# 733 activation_184
# 734 reduction_add_1_reduce_12
# 735 separable_conv_1_reduction_right2_reduce_12
# 736 separable_conv_1_pad_reduction_right3_reduce_12
# 737 activation_186
# 738 separable_conv_1_bn_reduction_right2_reduce_12
# 739 separable_conv_1_reduction_right3_reduce_12
# 740 separable_conv_1_reduction_left4_reduce_12
# 741 activation_183
# 742 separable_conv_1_bn_reduction_right3_reduce_12
# 743 separable_conv_1_bn_reduction_left4_reduce_12
# 744 reduction_pad_1_reduce_12
# 745 separable_conv_2_reduction_right2_reduce_12
# 746 activation_185
# 747 activation_187
# 748 reduction_left2_reduce_12
# 749 separable_conv_2_bn_reduction_right2_reduce_12
# 750 separable_conv_2_reduction_right3_reduce_12
# 751 separable_conv_2_reduction_left4_reduce_12
# 752 adjust_relu_1_13
# 753 reduction_add_2_reduce_12
# 754 reduction_left3_reduce_12
# 755 separable_conv_2_bn_reduction_right3_reduce_12
# 756 reduction_left4_reduce_12
# 757 separable_conv_2_bn_reduction_left4_reduce_12
# 758 reduction_right5_reduce_12
# 759 zero_padding2d_3
# 760 reduction_add3_reduce_12
# 761 add_3
# 762 reduction_add4_reduce_12
# 763 cropping2d_3
# 764 reduction_concat_reduce_12
# 765 adjust_avg_pool_1_13
# 766 adjust_avg_pool_2_13
# 767 adjust_conv_1_13
# 768 adjust_conv_2_13
# 769 activation_188
# 770 concatenate_3
# 771 normal_conv_1_13
# 772 adjust_bn_13
# 773 normal_bn_1_13
# 774 activation_189
# 775 activation_191
# 776 activation_193
# 777 activation_195
# 778 activation_197
# 779 separable_conv_1_normal_left1_13
# 780 separable_conv_1_normal_right1_13
# 781 separable_conv_1_normal_left2_13
# 782 separable_conv_1_normal_right2_13
# 783 separable_conv_1_normal_left5_13
# 784 separable_conv_1_bn_normal_left1_13
# 785 separable_conv_1_bn_normal_right1_13
# 786 separable_conv_1_bn_normal_left2_13
# 787 separable_conv_1_bn_normal_right2_13
# 788 separable_conv_1_bn_normal_left5_13
# 789 activation_190
# 790 activation_192
# 791 activation_194
# 792 activation_196
# 793 activation_198
# 794 separable_conv_2_normal_left1_13
# 795 separable_conv_2_normal_right1_13
# 796 separable_conv_2_normal_left2_13
# 797 separable_conv_2_normal_right2_13
# 798 separable_conv_2_normal_left5_13
# 799 separable_conv_2_bn_normal_left1_13
# 800 separable_conv_2_bn_normal_right1_13
# 801 separable_conv_2_bn_normal_left2_13
# 802 separable_conv_2_bn_normal_right2_13
# 803 normal_left3_13
# 804 normal_left4_13
# 805 normal_right4_13
# 806 separable_conv_2_bn_normal_left5_13
# 807 normal_add_1_13
# 808 normal_add_2_13
# 809 normal_add_3_13
# 810 normal_add_4_13
# 811 normal_add_5_13
# 812 normal_concat_13
# 813 activation_199
# 814 activation_200
# 815 adjust_conv_projection_14
# 816 normal_conv_1_14
# 817 adjust_bn_14
# 818 normal_bn_1_14
# 819 activation_201
# 820 activation_203
# 821 activation_205
# 822 activation_207
# 823 activation_209
# 824 separable_conv_1_normal_left1_14
# 825 separable_conv_1_normal_right1_14
# 826 separable_conv_1_normal_left2_14
# 827 separable_conv_1_normal_right2_14
# 828 separable_conv_1_normal_left5_14
# 829 separable_conv_1_bn_normal_left1_14
# 830 separable_conv_1_bn_normal_right1_14
# 831 separable_conv_1_bn_normal_left2_14
# 832 separable_conv_1_bn_normal_right2_14
# 833 separable_conv_1_bn_normal_left5_14
# 834 activation_202
# 835 activation_204
# 836 activation_206
# 837 activation_208
# 838 activation_210
# 839 separable_conv_2_normal_left1_14
# 840 separable_conv_2_normal_right1_14
# 841 separable_conv_2_normal_left2_14
# 842 separable_conv_2_normal_right2_14
# 843 separable_conv_2_normal_left5_14
# 844 separable_conv_2_bn_normal_left1_14
# 845 separable_conv_2_bn_normal_right1_14
# 846 separable_conv_2_bn_normal_left2_14
# 847 separable_conv_2_bn_normal_right2_14
# 848 normal_left3_14
# 849 normal_left4_14
# 850 normal_right4_14
# 851 separable_conv_2_bn_normal_left5_14
# 852 normal_add_1_14
# 853 normal_add_2_14
# 854 normal_add_3_14
# 855 normal_add_4_14
# 856 normal_add_5_14
# 857 normal_concat_14
# 858 activation_211
# 859 activation_212
# 860 adjust_conv_projection_15
# 861 normal_conv_1_15
# 862 adjust_bn_15
# 863 normal_bn_1_15
# 864 activation_213
# 865 activation_215
# 866 activation_217
# 867 activation_219
# 868 activation_221
# 869 separable_conv_1_normal_left1_15
# 870 separable_conv_1_normal_right1_15
# 871 separable_conv_1_normal_left2_15
# 872 separable_conv_1_normal_right2_15
# 873 separable_conv_1_normal_left5_15
# 874 separable_conv_1_bn_normal_left1_15
# 875 separable_conv_1_bn_normal_right1_15
# 876 separable_conv_1_bn_normal_left2_15
# 877 separable_conv_1_bn_normal_right2_15
# 878 separable_conv_1_bn_normal_left5_15
# 879 activation_214
# 880 activation_216
# 881 activation_218
# 882 activation_220
# 883 activation_222
# 884 separable_conv_2_normal_left1_15
# 885 separable_conv_2_normal_right1_15
# 886 separable_conv_2_normal_left2_15
# 887 separable_conv_2_normal_right2_15
# 888 separable_conv_2_normal_left5_15
# 889 separable_conv_2_bn_normal_left1_15
# 890 separable_conv_2_bn_normal_right1_15
# 891 separable_conv_2_bn_normal_left2_15
# 892 separable_conv_2_bn_normal_right2_15
# 893 normal_left3_15
# 894 normal_left4_15
# 895 normal_right4_15
# 896 separable_conv_2_bn_normal_left5_15
# 897 normal_add_1_15
# 898 normal_add_2_15
# 899 normal_add_3_15
# 900 normal_add_4_15
# 901 normal_add_5_15
# 902 normal_concat_15
# 903 activation_223
# 904 activation_224
# 905 adjust_conv_projection_16
# 906 normal_conv_1_16
# 907 adjust_bn_16
# 908 normal_bn_1_16
# 909 activation_225
# 910 activation_227
# 911 activation_229
# 912 activation_231
# 913 activation_233
# 914 separable_conv_1_normal_left1_16
# 915 separable_conv_1_normal_right1_16
# 916 separable_conv_1_normal_left2_16
# 917 separable_conv_1_normal_right2_16
# 918 separable_conv_1_normal_left5_16
# 919 separable_conv_1_bn_normal_left1_16
# 920 separable_conv_1_bn_normal_right1_16
# 921 separable_conv_1_bn_normal_left2_16
# 922 separable_conv_1_bn_normal_right2_16
# 923 separable_conv_1_bn_normal_left5_16
# 924 activation_226
# 925 activation_228
# 926 activation_230
# 927 activation_232
# 928 activation_234
# 929 separable_conv_2_normal_left1_16
# 930 separable_conv_2_normal_right1_16
# 931 separable_conv_2_normal_left2_16
# 932 separable_conv_2_normal_right2_16
# 933 separable_conv_2_normal_left5_16
# 934 separable_conv_2_bn_normal_left1_16
# 935 separable_conv_2_bn_normal_right1_16
# 936 separable_conv_2_bn_normal_left2_16
# 937 separable_conv_2_bn_normal_right2_16
# 938 normal_left3_16
# 939 normal_left4_16
# 940 normal_right4_16
# 941 separable_conv_2_bn_normal_left5_16
# 942 normal_add_1_16
# 943 normal_add_2_16
# 944 normal_add_3_16
# 945 normal_add_4_16
# 946 normal_add_5_16
# 947 normal_concat_16
# 948 activation_235
# 949 activation_236
# 950 adjust_conv_projection_17
# 951 normal_conv_1_17
# 952 adjust_bn_17
# 953 normal_bn_1_17
# 954 activation_237
# 955 activation_239
# 956 activation_241
# 957 activation_243
# 958 activation_245
# 959 separable_conv_1_normal_left1_17
# 960 separable_conv_1_normal_right1_17
# 961 separable_conv_1_normal_left2_17
# 962 separable_conv_1_normal_right2_17
# 963 separable_conv_1_normal_left5_17
# 964 separable_conv_1_bn_normal_left1_17
# 965 separable_conv_1_bn_normal_right1_17
# 966 separable_conv_1_bn_normal_left2_17
# 967 separable_conv_1_bn_normal_right2_17
# 968 separable_conv_1_bn_normal_left5_17
# 969 activation_238
# 970 activation_240
# 971 activation_242
# 972 activation_244
# 973 activation_246
# 974 separable_conv_2_normal_left1_17
# 975 separable_conv_2_normal_right1_17
# 976 separable_conv_2_normal_left2_17
# 977 separable_conv_2_normal_right2_17
# 978 separable_conv_2_normal_left5_17
# 979 separable_conv_2_bn_normal_left1_17
# 980 separable_conv_2_bn_normal_right1_17
# 981 separable_conv_2_bn_normal_left2_17
# 982 separable_conv_2_bn_normal_right2_17
# 983 normal_left3_17
# 984 normal_left4_17
# 985 normal_right4_17
# 986 separable_conv_2_bn_normal_left5_17
# 987 normal_add_1_17
# 988 normal_add_2_17
# 989 normal_add_3_17
# 990 normal_add_4_17
# 991 normal_add_5_17
# 992 normal_concat_17
# 993 activation_247
# 994 activation_248
# 995 adjust_conv_projection_18
# 996 normal_conv_1_18
# 997 adjust_bn_18
# 998 normal_bn_1_18
# 999 activation_249
# 1000 activation_251
# 1001 activation_253
# 1002 activation_255
# 1003 activation_257
# 1004 separable_conv_1_normal_left1_18
# 1005 separable_conv_1_normal_right1_18
# 1006 separable_conv_1_normal_left2_18
# 1007 separable_conv_1_normal_right2_18
# 1008 separable_conv_1_normal_left5_18
# 1009 separable_conv_1_bn_normal_left1_18
# 1010 separable_conv_1_bn_normal_right1_18
# 1011 separable_conv_1_bn_normal_left2_18
# 1012 separable_conv_1_bn_normal_right2_18
# 1013 separable_conv_1_bn_normal_left5_18
# 1014 activation_250
# 1015 activation_252
# 1016 activation_254
# 1017 activation_256
# 1018 activation_258
# 1019 separable_conv_2_normal_left1_18
# 1020 separable_conv_2_normal_right1_18
# 1021 separable_conv_2_normal_left2_18
# 1022 separable_conv_2_normal_right2_18
# 1023 separable_conv_2_normal_left5_18
# 1024 separable_conv_2_bn_normal_left1_18
# 1025 separable_conv_2_bn_normal_right1_18
# 1026 separable_conv_2_bn_normal_left2_18
# 1027 separable_conv_2_bn_normal_right2_18
# 1028 normal_left3_18
# 1029 normal_left4_18
# 1030 normal_right4_18
# 1031 separable_conv_2_bn_normal_left5_18
# 1032 normal_add_1_18
# 1033 normal_add_2_18
# 1034 normal_add_3_18
# 1035 normal_add_4_18
# 1036 normal_add_5_18
# 1037 normal_concat_18
# 1038 activation_259
# layer input_1 is ---frozen
# layer stem_conv1 is ---frozen
# layer stem_bn1 is ---frozen
# layer activation is ---frozen
# layer reduction_conv_1_stem_1 is ---frozen
# layer reduction_bn_1_stem_1 is ---frozen
# layer activation_1 is ---frozen
# layer activation_3 is ---frozen
# layer separable_conv_1_pad_reduction_left1_stem_1 is ---frozen
# layer separable_conv_1_pad_reduction_right1_stem_1 is ---frozen
# layer separable_conv_1_reduction_left1_stem_1 is ---frozen
# layer separable_conv_1_reduction_right1_stem_1 is ---frozen
# layer separable_conv_1_bn_reduction_left1_stem_1 is ---frozen
# layer separable_conv_1_bn_reduction_right1_stem_1 is ---frozen
# layer activation_2 is ---frozen
# layer activation_4 is ---frozen
# layer separable_conv_2_reduction_left1_stem_1 is ---frozen
# layer separable_conv_2_reduction_right1_stem_1 is ---frozen
# layer activation_5 is ---frozen
# layer separable_conv_2_bn_reduction_left1_stem_1 is ---frozen
# layer separable_conv_2_bn_reduction_right1_stem_1 is ---frozen
# layer separable_conv_1_pad_reduction_right2_stem_1 is ---frozen
# layer activation_7 is ---frozen
# layer reduction_add_1_stem_1 is ---frozen
# layer separable_conv_1_reduction_right2_stem_1 is ---frozen
# layer separable_conv_1_pad_reduction_right3_stem_1 is ---frozen
# layer activation_9 is ---frozen
# layer separable_conv_1_bn_reduction_right2_stem_1 is ---frozen
# layer separable_conv_1_reduction_right3_stem_1 is ---frozen
# layer separable_conv_1_reduction_left4_stem_1 is ---frozen
# layer activation_6 is ---frozen
# layer separable_conv_1_bn_reduction_right3_stem_1 is ---frozen
# layer separable_conv_1_bn_reduction_left4_stem_1 is ---frozen
# layer reduction_pad_1_stem_1 is ---frozen
# layer separable_conv_2_reduction_right2_stem_1 is ---frozen
# layer activation_8 is ---frozen
# layer activation_10 is ---frozen
# layer reduction_left2_stem_1 is ---frozen
# layer separable_conv_2_bn_reduction_right2_stem_1 is ---frozen
# layer separable_conv_2_reduction_right3_stem_1 is ---frozen
# layer separable_conv_2_reduction_left4_stem_1 is ---frozen
# layer adjust_relu_1_stem_2 is ---frozen
# layer reduction_add_2_stem_1 is ---frozen
# layer reduction_left3_stem_1 is ---frozen
# layer separable_conv_2_bn_reduction_right3_stem_1 is ---frozen
# layer reduction_left4_stem_1 is ---frozen
# layer separable_conv_2_bn_reduction_left4_stem_1 is ---frozen
# layer reduction_right5_stem_1 is ---frozen
# layer zero_padding2d is ---frozen
# layer reduction_add3_stem_1 is ---frozen
# layer add is ---frozen
# layer reduction_add4_stem_1 is ---frozen
# layer cropping2d is ---frozen
# layer reduction_concat_stem_1 is ---frozen
# layer adjust_avg_pool_1_stem_2 is ---frozen
# layer adjust_avg_pool_2_stem_2 is ---frozen
# layer activation_11 is ---frozen
# layer adjust_conv_1_stem_2 is ---frozen
# layer adjust_conv_2_stem_2 is ---frozen
# layer reduction_conv_1_stem_2 is ---frozen
# layer concatenate is ---frozen
# layer reduction_bn_1_stem_2 is ---frozen
# layer adjust_bn_stem_2 is ---frozen
# layer activation_12 is ---frozen
# layer activation_14 is ---frozen
# layer separable_conv_1_pad_reduction_left1_stem_2 is ---frozen
# layer separable_conv_1_pad_reduction_right1_stem_2 is ---frozen
# layer separable_conv_1_reduction_left1_stem_2 is ---frozen
# layer separable_conv_1_reduction_right1_stem_2 is ---frozen
# layer separable_conv_1_bn_reduction_left1_stem_2 is ---frozen
# layer separable_conv_1_bn_reduction_right1_stem_2 is ---frozen
# layer activation_13 is ---frozen
# layer activation_15 is ---frozen
# layer separable_conv_2_reduction_left1_stem_2 is ---frozen
# layer separable_conv_2_reduction_right1_stem_2 is ---frozen
# layer activation_16 is ---frozen
# layer separable_conv_2_bn_reduction_left1_stem_2 is ---frozen
# layer separable_conv_2_bn_reduction_right1_stem_2 is ---frozen
# layer separable_conv_1_pad_reduction_right2_stem_2 is ---frozen
# layer activation_18 is ---frozen
# layer reduction_add_1_stem_2 is ---frozen
# layer separable_conv_1_reduction_right2_stem_2 is ---frozen
# layer separable_conv_1_pad_reduction_right3_stem_2 is ---frozen
# layer activation_20 is ---frozen
# layer separable_conv_1_bn_reduction_right2_stem_2 is ---frozen
# layer separable_conv_1_reduction_right3_stem_2 is ---frozen
# layer separable_conv_1_reduction_left4_stem_2 is ---frozen
# layer activation_17 is ---frozen
# layer separable_conv_1_bn_reduction_right3_stem_2 is ---frozen
# layer separable_conv_1_bn_reduction_left4_stem_2 is ---frozen
# layer reduction_pad_1_stem_2 is ---frozen
# layer separable_conv_2_reduction_right2_stem_2 is ---frozen
# layer activation_19 is ---frozen
# layer activation_21 is ---frozen
# layer reduction_left2_stem_2 is ---frozen
# layer separable_conv_2_bn_reduction_right2_stem_2 is ---frozen
# layer separable_conv_2_reduction_right3_stem_2 is ---frozen
# layer separable_conv_2_reduction_left4_stem_2 is ---frozen
# layer adjust_relu_1_0 is ---frozen
# layer reduction_add_2_stem_2 is ---frozen
# layer reduction_left3_stem_2 is ---frozen
# layer separable_conv_2_bn_reduction_right3_stem_2 is ---frozen
# layer reduction_left4_stem_2 is ---frozen
# layer separable_conv_2_bn_reduction_left4_stem_2 is ---frozen
# layer reduction_right5_stem_2 is ---frozen
# layer zero_padding2d_1 is ---frozen
# layer reduction_add3_stem_2 is ---frozen
# layer add_1 is ---frozen
# layer reduction_add4_stem_2 is ---frozen
# layer cropping2d_1 is ---frozen
# layer reduction_concat_stem_2 is ---frozen
# layer adjust_avg_pool_1_0 is ---frozen
# layer adjust_avg_pool_2_0 is ---frozen
# layer adjust_conv_1_0 is ---frozen
# layer adjust_conv_2_0 is ---frozen
# layer activation_22 is ---frozen
# layer concatenate_1 is ---frozen
# layer normal_conv_1_0 is ---frozen
# layer adjust_bn_0 is ---frozen
# layer normal_bn_1_0 is ---frozen
# layer activation_23 is ---frozen
# layer activation_25 is ---frozen
# layer activation_27 is ---frozen
# layer activation_29 is ---frozen
# layer activation_31 is ---frozen
# layer separable_conv_1_normal_left1_0 is ---frozen
# layer separable_conv_1_normal_right1_0 is ---frozen
# layer separable_conv_1_normal_left2_0 is ---frozen
# layer separable_conv_1_normal_right2_0 is ---frozen
# layer separable_conv_1_normal_left5_0 is ---frozen
# layer separable_conv_1_bn_normal_left1_0 is ---frozen
# layer separable_conv_1_bn_normal_right1_0 is ---frozen
# layer separable_conv_1_bn_normal_left2_0 is ---frozen
# layer separable_conv_1_bn_normal_right2_0 is ---frozen
# layer separable_conv_1_bn_normal_left5_0 is ---frozen
# layer activation_24 is ---frozen
# layer activation_26 is ---frozen
# layer activation_28 is ---frozen
# layer activation_30 is ---frozen
# layer activation_32 is ---frozen
# layer separable_conv_2_normal_left1_0 is ---frozen
# layer separable_conv_2_normal_right1_0 is ---frozen
# layer separable_conv_2_normal_left2_0 is ---frozen
# layer separable_conv_2_normal_right2_0 is ---frozen
# layer separable_conv_2_normal_left5_0 is ---frozen
# layer separable_conv_2_bn_normal_left1_0 is ---frozen
# layer separable_conv_2_bn_normal_right1_0 is ---frozen
# layer separable_conv_2_bn_normal_left2_0 is ---frozen
# layer separable_conv_2_bn_normal_right2_0 is ---frozen
# layer normal_left3_0 is ---frozen
# layer normal_left4_0 is ---frozen
# layer normal_right4_0 is ---frozen
# layer separable_conv_2_bn_normal_left5_0 is ---frozen
# layer normal_add_1_0 is ---frozen
# layer normal_add_2_0 is ---frozen
# layer normal_add_3_0 is ---frozen
# layer normal_add_4_0 is ---frozen
# layer normal_add_5_0 is ---frozen
# layer normal_concat_0 is ---frozen
# layer activation_33 is ---frozen
# layer activation_34 is ---frozen
# layer adjust_conv_projection_1 is ---frozen
# layer normal_conv_1_1 is ---frozen
# layer adjust_bn_1 is ---frozen
# layer normal_bn_1_1 is ---frozen
# layer activation_35 is ---frozen
# layer activation_37 is ---frozen
# layer activation_39 is ---frozen
# layer activation_41 is ---frozen
# layer activation_43 is ---frozen
# layer separable_conv_1_normal_left1_1 is ---frozen
# layer separable_conv_1_normal_right1_1 is ---frozen
# layer separable_conv_1_normal_left2_1 is ---frozen
# layer separable_conv_1_normal_right2_1 is ---frozen
# layer separable_conv_1_normal_left5_1 is ---frozen
# layer separable_conv_1_bn_normal_left1_1 is ---frozen
# layer separable_conv_1_bn_normal_right1_1 is ---frozen
# layer separable_conv_1_bn_normal_left2_1 is ---frozen
# layer separable_conv_1_bn_normal_right2_1 is ---frozen
# layer separable_conv_1_bn_normal_left5_1 is ---frozen
# layer activation_36 is ---frozen
# layer activation_38 is ---frozen
# layer activation_40 is ---frozen
# layer activation_42 is ---frozen
# layer activation_44 is ---frozen
# layer separable_conv_2_normal_left1_1 is ---frozen
# layer separable_conv_2_normal_right1_1 is ---frozen
# layer separable_conv_2_normal_left2_1 is ---frozen
# layer separable_conv_2_normal_right2_1 is ---frozen
# layer separable_conv_2_normal_left5_1 is ---frozen
# layer separable_conv_2_bn_normal_left1_1 is ---frozen
# layer separable_conv_2_bn_normal_right1_1 is ---frozen
# layer separable_conv_2_bn_normal_left2_1 is ---frozen
# layer separable_conv_2_bn_normal_right2_1 is ---frozen
# layer normal_left3_1 is ---frozen
# layer normal_left4_1 is ---frozen
# layer normal_right4_1 is ---frozen
# layer separable_conv_2_bn_normal_left5_1 is ---frozen
# layer normal_add_1_1 is ---frozen
# layer normal_add_2_1 is ---frozen
# layer normal_add_3_1 is ---frozen
# layer normal_add_4_1 is ---frozen
# layer normal_add_5_1 is ---frozen
# layer normal_concat_1 is ---frozen
# layer activation_45 is ---frozen
# layer activation_46 is ---frozen
# layer adjust_conv_projection_2 is ---frozen
# layer normal_conv_1_2 is ---frozen
# layer adjust_bn_2 is ---frozen
# layer normal_bn_1_2 is ---frozen
# layer activation_47 is ---frozen
# layer activation_49 is ---frozen
# layer activation_51 is ---frozen
# layer activation_53 is ---frozen
# layer activation_55 is ---frozen
# layer separable_conv_1_normal_left1_2 is ---frozen
# layer separable_conv_1_normal_right1_2 is ---frozen
# layer separable_conv_1_normal_left2_2 is ---frozen
# layer separable_conv_1_normal_right2_2 is ---frozen
# layer separable_conv_1_normal_left5_2 is ---frozen
# layer separable_conv_1_bn_normal_left1_2 is ---frozen
# layer separable_conv_1_bn_normal_right1_2 is ---frozen
# layer separable_conv_1_bn_normal_left2_2 is ---frozen
# layer separable_conv_1_bn_normal_right2_2 is ---frozen
# layer separable_conv_1_bn_normal_left5_2 is ---frozen
# layer activation_48 is ---frozen
# layer activation_50 is ---frozen
# layer activation_52 is ---frozen
# layer activation_54 is ---frozen
# layer activation_56 is ---frozen
# layer separable_conv_2_normal_left1_2 is ---frozen
# layer separable_conv_2_normal_right1_2 is ---frozen
# layer separable_conv_2_normal_left2_2 is ---frozen
# layer separable_conv_2_normal_right2_2 is ---frozen
# layer separable_conv_2_normal_left5_2 is ---frozen
# layer separable_conv_2_bn_normal_left1_2 is ---frozen
# layer separable_conv_2_bn_normal_right1_2 is ---frozen
# layer separable_conv_2_bn_normal_left2_2 is ---frozen
# layer separable_conv_2_bn_normal_right2_2 is ---frozen
# layer normal_left3_2 is ---frozen
# layer normal_left4_2 is ---frozen
# layer normal_right4_2 is ---frozen
# layer separable_conv_2_bn_normal_left5_2 is ---frozen
# layer normal_add_1_2 is ---frozen
# layer normal_add_2_2 is ---frozen
# layer normal_add_3_2 is ---frozen
# layer normal_add_4_2 is ---frozen
# layer normal_add_5_2 is ---frozen
# layer normal_concat_2 is ---frozen
# layer activation_57 is ---frozen
# layer activation_58 is ---frozen
# layer adjust_conv_projection_3 is ---frozen
# layer normal_conv_1_3 is ---frozen
# layer adjust_bn_3 is ---frozen
# layer normal_bn_1_3 is ---frozen
# layer activation_59 is ---frozen
# layer activation_61 is ---frozen
# layer activation_63 is ---frozen
# layer activation_65 is ---frozen
# layer activation_67 is ---frozen
# layer separable_conv_1_normal_left1_3 is ---frozen
# layer separable_conv_1_normal_right1_3 is ---frozen
# layer separable_conv_1_normal_left2_3 is ---frozen
# layer separable_conv_1_normal_right2_3 is ---frozen
# layer separable_conv_1_normal_left5_3 is ---frozen
# layer separable_conv_1_bn_normal_left1_3 is ---frozen
# layer separable_conv_1_bn_normal_right1_3 is ---frozen
# layer separable_conv_1_bn_normal_left2_3 is ---frozen
# layer separable_conv_1_bn_normal_right2_3 is ---frozen
# layer separable_conv_1_bn_normal_left5_3 is ---frozen
# layer activation_60 is ---frozen
# layer activation_62 is ---frozen
# layer activation_64 is ---frozen
# layer activation_66 is ---frozen
# layer activation_68 is ---frozen
# layer separable_conv_2_normal_left1_3 is ---frozen
# layer separable_conv_2_normal_right1_3 is ---frozen
# layer separable_conv_2_normal_left2_3 is ---frozen
# layer separable_conv_2_normal_right2_3 is ---frozen
# layer separable_conv_2_normal_left5_3 is ---frozen
# layer separable_conv_2_bn_normal_left1_3 is ---frozen
# layer separable_conv_2_bn_normal_right1_3 is ---frozen
# layer separable_conv_2_bn_normal_left2_3 is ---frozen
# layer separable_conv_2_bn_normal_right2_3 is ---frozen
# layer normal_left3_3 is ---frozen
# layer normal_left4_3 is ---frozen
# layer normal_right4_3 is ---frozen
# layer separable_conv_2_bn_normal_left5_3 is ---frozen
# layer normal_add_1_3 is ---frozen
# layer normal_add_2_3 is ---frozen
# layer normal_add_3_3 is ---frozen
# layer normal_add_4_3 is ---frozen
# layer normal_add_5_3 is ---frozen
# layer normal_concat_3 is ---frozen
# layer activation_69 is ---frozen
# layer activation_70 is ---frozen
# layer adjust_conv_projection_4 is ---frozen
# layer normal_conv_1_4 is ---frozen
# layer adjust_bn_4 is ---frozen
# layer normal_bn_1_4 is ---frozen
# layer activation_71 is ---frozen
# layer activation_73 is ---frozen
# layer activation_75 is ---frozen
# layer activation_77 is ---frozen
# layer activation_79 is ---frozen
# layer separable_conv_1_normal_left1_4 is ---frozen
# layer separable_conv_1_normal_right1_4 is ---frozen
# layer separable_conv_1_normal_left2_4 is ---frozen
# layer separable_conv_1_normal_right2_4 is ---frozen
# layer separable_conv_1_normal_left5_4 is ---frozen
# layer separable_conv_1_bn_normal_left1_4 is ---frozen
# layer separable_conv_1_bn_normal_right1_4 is ---frozen
# layer separable_conv_1_bn_normal_left2_4 is ---frozen
# layer separable_conv_1_bn_normal_right2_4 is ---frozen
# layer separable_conv_1_bn_normal_left5_4 is ---frozen
# layer activation_72 is ---frozen
# layer activation_74 is ---frozen
# layer activation_76 is ---frozen
# layer activation_78 is ---frozen
# layer activation_80 is ---frozen
# layer separable_conv_2_normal_left1_4 is ---frozen
# layer separable_conv_2_normal_right1_4 is ---frozen
# layer separable_conv_2_normal_left2_4 is ---frozen
# layer separable_conv_2_normal_right2_4 is ---frozen
# layer separable_conv_2_normal_left5_4 is ---frozen
# layer separable_conv_2_bn_normal_left1_4 is ---frozen
# layer separable_conv_2_bn_normal_right1_4 is ---frozen
# layer separable_conv_2_bn_normal_left2_4 is ---frozen
# layer separable_conv_2_bn_normal_right2_4 is ---frozen
# layer normal_left3_4 is ---frozen
# layer normal_left4_4 is ---frozen
# layer normal_right4_4 is ---frozen
# layer separable_conv_2_bn_normal_left5_4 is ---frozen
# layer normal_add_1_4 is ---frozen
# layer normal_add_2_4 is ---frozen
# layer normal_add_3_4 is ---frozen
# layer normal_add_4_4 is ---frozen
# layer normal_add_5_4 is ---frozen
# layer normal_concat_4 is ---frozen
# layer activation_81 is ---frozen
# layer activation_82 is ---frozen
# layer adjust_conv_projection_5 is ---frozen
# layer normal_conv_1_5 is ---frozen
# layer adjust_bn_5 is ---frozen
# layer normal_bn_1_5 is ---frozen
# layer activation_83 is ---frozen
# layer activation_85 is ---frozen
# layer activation_87 is ---frozen
# layer activation_89 is ---frozen
# layer activation_91 is ---frozen
# layer separable_conv_1_normal_left1_5 is ---frozen
# layer separable_conv_1_normal_right1_5 is ---frozen
# layer separable_conv_1_normal_left2_5 is ---frozen
# layer separable_conv_1_normal_right2_5 is ---frozen
# layer separable_conv_1_normal_left5_5 is ---frozen
# layer separable_conv_1_bn_normal_left1_5 is ---frozen
# layer separable_conv_1_bn_normal_right1_5 is ---frozen
# layer separable_conv_1_bn_normal_left2_5 is ---frozen
# layer separable_conv_1_bn_normal_right2_5 is ---frozen
# layer separable_conv_1_bn_normal_left5_5 is ---frozen
# layer activation_84 is ---frozen
# layer activation_86 is ---frozen
# layer activation_88 is ---frozen
# layer activation_90 is ---frozen
# layer activation_92 is ---frozen
# layer separable_conv_2_normal_left1_5 is ---frozen
# layer separable_conv_2_normal_right1_5 is ---frozen
# layer separable_conv_2_normal_left2_5 is ---frozen
# layer separable_conv_2_normal_right2_5 is ---frozen
# layer separable_conv_2_normal_left5_5 is ---frozen
# layer separable_conv_2_bn_normal_left1_5 is ---frozen
# layer separable_conv_2_bn_normal_right1_5 is ---frozen
# layer separable_conv_2_bn_normal_left2_5 is ---frozen
# layer separable_conv_2_bn_normal_right2_5 is ---frozen
# layer normal_left3_5 is ---frozen
# layer normal_left4_5 is ---frozen
# layer normal_right4_5 is ---frozen
# layer separable_conv_2_bn_normal_left5_5 is ---frozen
# layer normal_add_1_5 is ---frozen
# layer normal_add_2_5 is ---frozen
# layer normal_add_3_5 is ---frozen
# layer normal_add_4_5 is ---frozen
# layer normal_add_5_5 is ---frozen
# layer normal_concat_5 is ---frozen
# layer activation_94 is ---frozen
# layer activation_93 is ---frozen
# layer reduction_conv_1_reduce_6 is ---frozen
# layer adjust_conv_projection_reduce_6 is ---frozen
# layer reduction_bn_1_reduce_6 is ---frozen
# layer adjust_bn_reduce_6 is ---frozen
# layer activation_95 is ---frozen
# layer activation_97 is ---frozen
# layer separable_conv_1_pad_reduction_left1_reduce_6 is ---frozen
# layer separable_conv_1_pad_reduction_right1_reduce_6 is ---frozen
# layer separable_conv_1_reduction_left1_reduce_6 is ---frozen
# layer separable_conv_1_reduction_right1_reduce_6 is ---frozen
# layer separable_conv_1_bn_reduction_left1_reduce_6 is ---frozen
# layer separable_conv_1_bn_reduction_right1_reduce_6 is ---frozen
# layer activation_96 is ---frozen
# layer activation_98 is ---frozen
# layer separable_conv_2_reduction_left1_reduce_6 is ---frozen
# layer separable_conv_2_reduction_right1_reduce_6 is ---frozen
# layer activation_99 is ---frozen
# layer separable_conv_2_bn_reduction_left1_reduce_6 is ---frozen
# layer separable_conv_2_bn_reduction_right1_reduce_6 is ---frozen
# ...
# layer separable_conv_2_reduction_left1_reduce_12 is ---frozen
# layer separable_conv_2_reduction_right1_reduce_12 is ---frozen
# layer activation_182 is ---frozen
# layer separable_conv_2_bn_reduction_left1_reduce_12 is ---frozen
# layer separable_conv_2_bn_reduction_right1_reduce_12 is ---frozen
# layer separable_conv_1_pad_reduction_right2_reduce_12 is ---frozen
# layer activation_184 is ---frozen
# layer reduction_add_1_reduce_12 is ---frozen
# layer separable_conv_1_reduction_right2_reduce_12 is ---frozen
# layer separable_conv_1_pad_reduction_right3_reduce_12 is ---frozen
# layer activation_186 is ---frozen
# layer separable_conv_1_bn_reduction_right2_reduce_12 is ---frozen
# layer separable_conv_1_reduction_right3_reduce_12 is ---frozen
# layer separable_conv_1_reduction_left4_reduce_12 is ---frozen
# layer activation_183 is ---frozen
# layer separable_conv_1_bn_reduction_right3_reduce_12 is ---frozen
# layer separable_conv_1_bn_reduction_left4_reduce_12 is ---frozen
# layer reduction_pad_1_reduce_12 is ---frozen
# layer separable_conv_2_reduction_right2_reduce_12 is ---frozen
# layer activation_185 is ---frozen
# layer activation_187 is ---frozen
# layer reduction_left2_reduce_12 is ---frozen
# layer separable_conv_2_bn_reduction_right2_reduce_12 is ---frozen
# layer separable_conv_2_reduction_right3_reduce_12 is ---frozen
# layer separable_conv_2_reduction_left4_reduce_12 is ---frozen
# layer adjust_relu_1_13 is ---frozen
# layer reduction_add_2_reduce_12 is ---frozen
# layer reduction_left3_reduce_12 is ---frozen
# layer separable_conv_2_bn_reduction_right3_reduce_12 is ---frozen
# layer reduction_left4_reduce_12 is ---frozen
# layer separable_conv_2_bn_reduction_left4_reduce_12 is ---frozen
# layer reduction_right5_reduce_12 is ---frozen
# layer zero_padding2d_3 is ---frozen
# layer reduction_add3_reduce_12 is ---frozen
# layer add_3 is ---frozen
# layer reduction_add4_reduce_12 is ---frozen
# layer cropping2d_3 is ---frozen
# layer reduction_concat_reduce_12 is ---frozen
# layer adjust_avg_pool_1_13 is ---frozen
# layer adjust_avg_pool_2_13 is ---frozen
# layer adjust_conv_1_13 is ---frozen
# layer adjust_conv_2_13 is ---frozen
# layer activation_188 is ---frozen
# layer concatenate_3 is ---frozen
# layer normal_conv_1_13 is ---frozen
# layer adjust_bn_13 is ---frozen
# layer normal_bn_1_13 is ---frozen
# layer activation_189 is ---frozen
# layer activation_191 is ---frozen
# layer activation_193 is ---frozen
# layer activation_195 is ---frozen
# layer activation_197 is ---frozen
# layer separable_conv_1_normal_left1_13 is ---frozen
# layer separable_conv_1_normal_right1_13 is ---frozen
# layer separable_conv_1_normal_left2_13 is ---frozen
# layer separable_conv_1_normal_right2_13 is ---frozen
# layer separable_conv_1_normal_left5_13 is ---frozen
# layer separable_conv_1_bn_normal_left1_13 is ---frozen
# layer separable_conv_1_bn_normal_right1_13 is ---frozen
# layer separable_conv_1_bn_normal_left2_13 is ---frozen
# layer separable_conv_1_bn_normal_right2_13 is ---frozen
# layer separable_conv_1_bn_normal_left5_13 is ---frozen
# layer activation_190 is ---frozen
# layer activation_192 is ---frozen
# layer activation_194 is ---frozen
# layer activation_196 is ---frozen
# layer activation_198 is ---frozen
# layer separable_conv_2_normal_left1_13 is ---frozen
# layer separable_conv_2_normal_right1_13 is ---frozen
# layer separable_conv_2_normal_left2_13 is ---frozen
# layer separable_conv_2_normal_right2_13 is ---frozen
# layer separable_conv_2_normal_left5_13 is ---frozen
# layer separable_conv_2_bn_normal_left1_13 is ---frozen
# layer separable_conv_2_bn_normal_right1_13 is ---frozen
# layer separable_conv_2_bn_normal_left2_13 is ---frozen
# layer separable_conv_2_bn_normal_right2_13 is ---frozen
# layer normal_left3_13 is ---frozen
# layer normal_left4_13 is ---frozen
# layer normal_right4_13 is ---frozen
# layer separable_conv_2_bn_normal_left5_13 is ---frozen
# layer normal_add_1_13 is ---frozen
# layer normal_add_2_13 is ---frozen
# layer normal_add_3_13 is ---frozen
# layer normal_add_4_13 is ---frozen
# layer normal_add_5_13 is ---frozen
# layer normal_concat_13 is ---frozen
# layer activation_199 is ---frozen
# layer activation_200 is ---frozen
# layer adjust_conv_projection_14 is ---frozen
# layer normal_conv_1_14 is ---frozen
# layer adjust_bn_14 is ---frozen
# layer normal_bn_1_14 is ---frozen
# layer activation_201 is ---frozen
# layer activation_203 is ---frozen
# layer activation_205 is ---frozen
# layer activation_207 is ---frozen
# layer activation_209 is ---frozen
# layer separable_conv_1_normal_left1_14 is ---frozen
# layer separable_conv_1_normal_right1_14 is ---frozen
# layer separable_conv_1_normal_left2_14 is ---frozen
# layer separable_conv_1_normal_right2_14 is ---frozen
# layer separable_conv_1_normal_left5_14 is ---frozen
# layer separable_conv_1_bn_normal_left1_14 is ---frozen
# layer separable_conv_1_bn_normal_right1_14 is ---frozen
# layer separable_conv_1_bn_normal_left2_14 is ---frozen
# layer separable_conv_1_bn_normal_right2_14 is ---frozen
# layer separable_conv_1_bn_normal_left5_14 is ---frozen
# layer activation_202 is ---frozen
# layer activation_204 is ---frozen
# layer activation_206 is ---frozen
# layer activation_208 is ---frozen
# layer activation_210 is ---frozen
# layer separable_conv_2_normal_left1_14 is ---frozen
# layer separable_conv_2_normal_right1_14 is ---frozen
# layer separable_conv_2_normal_left2_14 is ---frozen
# layer separable_conv_2_normal_right2_14 is ---frozen
# layer separable_conv_2_normal_left5_14 is ---frozen
# layer separable_conv_2_bn_normal_left1_14 is ---frozen
# layer separable_conv_2_bn_normal_right1_14 is ---frozen
# layer separable_conv_2_bn_normal_left2_14 is ---frozen
# layer separable_conv_2_bn_normal_right2_14 is ---frozen
# layer normal_left3_14 is ---frozen
# layer normal_left4_14 is ---frozen
# layer normal_right4_14 is ---frozen
# layer separable_conv_2_bn_normal_left5_14 is ---frozen
# layer normal_add_1_14 is ---frozen
# layer normal_add_2_14 is ---frozen
# layer normal_add_3_14 is ---frozen
# layer normal_add_4_14 is ---frozen
# layer normal_add_5_14 is ---frozen
# layer normal_concat_14 is ---frozen
# layer activation_211 is ---frozen
# layer activation_212 is ---frozen
# layer adjust_conv_projection_15 is ---frozen
# layer normal_conv_1_15 is ---frozen
# layer adjust_bn_15 is ---frozen
# layer normal_bn_1_15 is ---frozen
# layer activation_213 is ---frozen
# layer activation_215 is ---frozen
# layer activation_217 is ---frozen
# layer activation_219 is ---frozen
# layer activation_221 is ---frozen
# layer separable_conv_1_normal_left1_15 is ---frozen
# layer separable_conv_1_normal_right1_15 is ---frozen
# layer separable_conv_1_normal_left2_15 is ---frozen
# layer separable_conv_1_normal_right2_15 is ---frozen
# layer separable_conv_1_normal_left5_15 is ---frozen
# layer separable_conv_1_bn_normal_left1_15 is ---frozen
# layer separable_conv_1_bn_normal_right1_15 is ---frozen
# layer separable_conv_1_bn_normal_left2_15 is ---frozen
# layer separable_conv_1_bn_normal_right2_15 is ---frozen
# layer separable_conv_1_bn_normal_left5_15 is ---frozen
# layer activation_214 is ---frozen
# layer activation_216 is ---frozen
# layer activation_218 is ---frozen
# layer activation_220 is ---frozen
# layer activation_222 is ---frozen
# layer separable_conv_2_normal_left1_15 is ---frozen
# layer separable_conv_2_normal_right1_15 is ---frozen
# layer separable_conv_2_normal_left2_15 is ---frozen
# layer separable_conv_2_normal_right2_15 is ---frozen
# layer separable_conv_2_normal_left5_15 is ---frozen
# layer separable_conv_2_bn_normal_left1_15 is ---frozen
# layer separable_conv_2_bn_normal_right1_15 is ---frozen
# layer separable_conv_2_bn_normal_left2_15 is ---frozen
# layer separable_conv_2_bn_normal_right2_15 is ---frozen
# layer normal_left3_15 is ---frozen
# layer normal_left4_15 is ---frozen
# layer normal_right4_15 is ---frozen
# layer separable_conv_2_bn_normal_left5_15 is ---frozen
# layer normal_add_1_15 is ---frozen
# layer normal_add_2_15 is ---frozen
# layer normal_add_3_15 is ---frozen
# layer normal_add_4_15 is ---frozen
# layer normal_add_5_15 is ---frozen
# layer normal_concat_15 is ---frozen
# layer activation_223 is ---frozen
# layer activation_224 is ---frozen
# layer adjust_conv_projection_16 is ---frozen
# layer normal_conv_1_16 is ---frozen
# layer adjust_bn_16 is ---frozen
# layer normal_bn_1_16 is ---frozen
# layer activation_225 is ---frozen
# layer activation_227 is ---frozen
# layer activation_229 is ---frozen
# layer activation_231 is ---frozen
# layer activation_233 is ---frozen
# layer separable_conv_1_normal_left1_16 is ---frozen
# layer separable_conv_1_normal_right1_16 is ---frozen
# layer separable_conv_1_normal_left2_16 is ---frozen
# layer separable_conv_1_normal_right2_16 is ---frozen
# layer separable_conv_1_normal_left5_16 is ---frozen
# layer separable_conv_1_bn_normal_left1_16 is ---frozen
# layer separable_conv_1_bn_normal_right1_16 is ---frozen
# layer separable_conv_1_bn_normal_left2_16 is ---frozen
# layer separable_conv_1_bn_normal_right2_16 is ---frozen
# layer separable_conv_1_bn_normal_left5_16 is ---frozen
# layer activation_226 is ---frozen
# layer activation_228 is ---frozen
# layer activation_230 is ---frozen
# layer activation_232 is ---frozen
# layer activation_234 is ---frozen
# layer separable_conv_2_normal_left1_16 is ---frozen
# layer separable_conv_2_normal_right1_16 is ---frozen
# layer separable_conv_2_normal_left2_16 is ---frozen
# layer separable_conv_2_normal_right2_16 is ---frozen
# layer separable_conv_2_normal_left5_16 is ---frozen
# layer separable_conv_2_bn_normal_left1_16 is ---frozen
# layer separable_conv_2_bn_normal_right1_16 is ---frozen
# layer separable_conv_2_bn_normal_left2_16 is ---frozen
# layer separable_conv_2_bn_normal_right2_16 is ---frozen
# layer normal_left3_16 is ---frozen
# layer normal_left4_16 is ---frozen
# layer normal_right4_16 is ---frozen
# layer separable_conv_2_bn_normal_left5_16 is ---frozen
# layer normal_add_1_16 is ---frozen
# layer normal_add_2_16 is ---frozen
# layer normal_add_3_16 is ---frozen
# layer normal_add_4_16 is ---frozen
# layer normal_add_5_16 is ---frozen
# layer normal_concat_16 is ---frozen
# layer activation_235 is ---frozen
# layer activation_236 is ---frozen
# layer adjust_conv_projection_17 is ---frozen
# layer normal_conv_1_17 is ---frozen
# layer adjust_bn_17 is ---frozen
# layer normal_bn_1_17 is ---frozen
# layer activation_237 is ---frozen
# layer activation_239 is ---frozen
# layer activation_241 is ---frozen
# layer activation_243 is ---frozen
# layer activation_245 is ---frozen
# layer separable_conv_1_normal_left1_17 is ---frozen
# layer separable_conv_1_normal_right1_17 is ---frozen
# layer separable_conv_1_normal_left2_17 is ---frozen
# layer separable_conv_1_normal_right2_17 is ---frozen
# layer separable_conv_1_normal_left5_17 is ---frozen
# layer separable_conv_1_bn_normal_left1_17 is ---frozen
# layer separable_conv_1_bn_normal_right1_17 is ---frozen
# layer separable_conv_1_bn_normal_left2_17 is ---frozen
# layer separable_conv_1_bn_normal_right2_17 is ---frozen
# layer separable_conv_1_bn_normal_left5_17 is ---frozen
# layer activation_238 is ---frozen
# layer activation_240 is ---frozen
# layer activation_242 is ---frozen
# layer activation_244 is ---frozen
# layer activation_246 is ---frozen
# layer separable_conv_2_normal_left1_17 is ---frozen
# layer separable_conv_2_normal_right1_17 is ---frozen
# layer separable_conv_2_normal_left2_17 is ---frozen
# layer separable_conv_2_normal_right2_17 is ---frozen
# layer separable_conv_2_normal_left5_17 is ---frozen
# layer separable_conv_2_bn_normal_left1_17 is ---frozen
# layer separable_conv_2_bn_normal_right1_17 is ---frozen
# layer separable_conv_2_bn_normal_left2_17 is ---frozen
# layer separable_conv_2_bn_normal_right2_17 is ---frozen
# layer normal_left3_17 is ---frozen
# layer normal_left4_17 is ---frozen
# layer normal_right4_17 is ---frozen
# layer separable_conv_2_bn_normal_left5_17 is ---frozen
# layer normal_add_1_17 is ---frozen
# layer normal_add_2_17 is ---frozen
# layer normal_add_3_17 is ---frozen
# layer normal_add_4_17 is ---frozen
# layer normal_add_5_17 is ---frozen
# layer normal_concat_17 is ---frozen
# layer activation_247 is ---frozen
# layer activation_248 is ---frozen
# layer adjust_conv_projection_18 is ---frozen
# layer normal_conv_1_18 is ---frozen
# layer adjust_bn_18 is ---frozen
# layer normal_bn_1_18 is ---frozen
# layer activation_249 is +++trainable
# layer activation_251 is +++trainable
# layer activation_253 is +++trainable
# layer activation_255 is +++trainable
# layer activation_257 is +++trainable
# layer separable_conv_1_normal_left1_18 is +++trainable
# layer separable_conv_1_normal_right1_18 is +++trainable
# layer separable_conv_1_normal_left2_18 is +++trainable
# layer separable_conv_1_normal_right2_18 is +++trainable
# layer separable_conv_1_normal_left5_18 is +++trainable
# layer separable_conv_1_bn_normal_left1_18 is +++trainable
# layer separable_conv_1_bn_normal_right1_18 is +++trainable
# layer separable_conv_1_bn_normal_left2_18 is +++trainable
# layer separable_conv_1_bn_normal_right2_18 is +++trainable
# layer separable_conv_1_bn_normal_left5_18 is +++trainable
# layer activation_250 is +++trainable
# layer activation_252 is +++trainable
# layer activation_254 is +++trainable
# layer activation_256 is +++trainable
# layer activation_258 is +++trainable
# layer separable_conv_2_normal_left1_18 is +++trainable
# layer separable_conv_2_normal_right1_18 is +++trainable
# layer separable_conv_2_normal_left2_18 is +++trainable
# layer separable_conv_2_normal_right2_18 is +++trainable
# layer separable_conv_2_normal_left5_18 is +++trainable
# layer separable_conv_2_bn_normal_left1_18 is +++trainable
# layer separable_conv_2_bn_normal_right1_18 is +++trainable
# layer separable_conv_2_bn_normal_left2_18 is +++trainable
# layer separable_conv_2_bn_normal_right2_18 is +++trainable
# layer normal_left3_18 is +++trainable
# layer normal_left4_18 is +++trainable
# layer normal_right4_18 is +++trainable
# layer separable_conv_2_bn_normal_left5_18 is +++trainable
# layer normal_add_1_18 is +++trainable
# layer normal_add_2_18 is +++trainable
# layer normal_add_3_18 is +++trainable
# layer normal_add_4_18 is +++trainable
# layer normal_add_5_18 is +++trainable
# layer normal_concat_18 is +++trainable
# layer activation_259 is +++trainable
# layer global_average_pooling2d is +++trainable
# layer dense is +++trainable
# layer dense_1 is +++trainable
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-4bf037d6f57e> in <module>()
#      91                                                  batch_size=30,
#      92                                                  class_mode='categorical',
# ---> 93                                                  shuffle=True)
#      94
#      95 val_datagen=ImageDataGenerator()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     957         follow_links=follow_links,
#     958         subset=subset,
# --> 959         interpolation=interpolation)
#     960
#     961   def flow_from_dataframe(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/preprocessing/image.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, dtype)
#     395         subset=subset,
#     396         interpolation=interpolation,
# --> 397         **kwargs)
#     398
#     399
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/directory_iterator.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, dtype)
#     113         if not classes:
#     114             classes = []
# --> 115             for subdir in sorted(os.listdir(directory)):
#     116                 if os.path.isdir(os.path.join(directory, subdir)):
#     117                     classes.append(subdir)
#
# FileNotFoundError: [Errno 2] No such file or directory: './IDH/train'

# %%
model.save('./3epochtester',save_format='tf')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ./MyModel_tf/assets

# %%
# next cell to save model including newly trained weights
# model.save('myLGGtestmodel.h5') # rename it how you like, it will show up in your directory. I have explained above using a hastag how and where to load the model.

# %%
import numpy as np
import tensorflow as tf
# !pip install tensornets
import tensornets as nets
import tensorflow_hub as hub
import keras
import tensorflow.keras 
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense,GlobalAveragePooling2D,Dropout,Flatten
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.nasnet import NASNetLarge, NASNetMobile, preprocess_input
directory = "./content"
# Out:
# Requirement already satisfied: tensornets in /usr/local/lib/python3.6/dist-packages (0.4.6)

# %%
# loading the saved model
loaded_model = tf.keras.models.load_model('./MyModel_tf')

# %%
train_datagen=ImageDataGenerator(rotation_range=10, zoom_range=0.1, width_shift_range=0.1, height_shift_range=0.1, shear_range=0, brightness_range=[0.01,100], fill_mode='nearest', horizontal_flip=True, data_format='channels_last', validation_split=0.0, dtype='float32') #included in our dependencies
# add the directory below very important ##########################

train=train_datagen.flow_from_directory('./IDH/train',
                                                 target_size=(331,331),
                                                 color_mode='rgb',
                                                 batch_size=30,
                                                 class_mode='categorical',
                                                 shuffle=True)

val_datagen=ImageDataGenerator()

val=val_datagen.flow_from_directory('./IDH/validate',
                                                 target_size=(331,331),
                                                 color_mode='rgb',
                                                 batch_size=30,
                                                 class_mode='categorical',
                                                 shuffle=False)

loaded_model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])


# Adam optimizer
# loss function will be categorical cross entropy
# evaluation metric will be accuracy

step_size_train=train.n//train.batch_size
step_size_val=val.n//val.batch_size
#model.fit_generator(generator=train_generator,
#                   steps_per_epoch=step_size_train,
#                   epochs=3)

history = loaded_model.fit(train, steps_per_epoch=step_size_train, epochs=3,
                              validation_data=val, validation_steps=step_size_val, 
                              verbose=1)
# Out:
# Found 19968 images belonging to 2 classes.
# Found 4212 images belonging to 2 classes.
# Epoch 1/3
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-4-fbd389c09e0d> in <module>()
#      33 history = loaded_model.fit(train, steps_per_epoch=step_size_train, epochs=3,
#      34                               validation_data=val, validation_steps=step_size_val,
# ---> 35                               verbose=1)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     838         # Lifting succeeded, so variables are initialized and we can run the
#     839         # stateless function.
# --> 840         return self._stateless_fn(*args, **kwds)
#     841     else:
#     842       canon_args, canon_kwds = \
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[30,336,42,42] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node functional_1/reduction_conv_1_reduce_6/Conv2D (defined at <ipython-input-4-fbd389c09e0d>:35) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_train_function_206488]
#
# Function call stack:
# train_function

# %%
x_train = '/content/IDH/train/mut'
y_train = '/content/IDH/train/wt'
x_val = '/content/IDH/validate/mut'
y_val = '/content/IDH/validate/wt'

# %%
# retraining the model
loaded_model.fit(x_train, y_train, epochs = 3, validation_data = (x_val, y_val),verbose=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-0789296f162a> in <module>()
#       1 # retraining the model
# ----> 2 loaded_model.fit(x_train, y_train, epochs = 3, validation_data = (x_val, y_val),verbose=1)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1061           use_multiprocessing=use_multiprocessing,
#    1062           model=self,
# -> 1063           steps_per_execution=self._steps_per_execution)
#    1064
#    1065       # Container that configures and calls `tf.keras.Callback`s.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1115         use_multiprocessing=use_multiprocessing,
#    1116         distribution_strategy=ds_context.get_strategy(),
# -> 1117         model=model)
#    1118
#    1119     strategy = ds_context.get_strategy()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, shuffle, **kwargs)
#     655         batch_size=batch_size,
#     656         shuffle=shuffle,
# --> 657         **kwargs)
#     658
#     659   def get_dataset(self):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     273     inputs = pack_x_y_sample_weight(x, y, sample_weights)
#     274
# --> 275     num_samples = set(int(i.shape[0]) for i in nest.flatten(inputs))
#     276     if len(num_samples) > 1:
#     277       msg = "Data cardinality is ambiguous:\n"
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/data_adapter.py in <genexpr>(.0)
#     273     inputs = pack_x_y_sample_weight(x, y, sample_weights)
#     274
# --> 275     num_samples = set(int(i.shape[0]) for i in nest.flatten(inputs))
#     276     if len(num_samples) > 1:
#     277       msg = "Data cardinality is ambiguous:\n"
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/tensor_shape.py in __getitem__(self, key)
#     885       else:
#     886         if self._v2_behavior:
# --> 887           return self._dims[key].value
#     888         else:
#     889           return self._dims[key]
#
# IndexError: list index out of range

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic CNN Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,4))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 4, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 4, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-d99948c19940> in <module>()
#       4
#       5 epoch_list = list(range(1,4))
# ----> 6 ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
#       7 ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
#       8 ax1.set_xticks(np.arange(0, 4, 5))
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (3,) and (2,)

# %%
# this cell is to evaluate loss and accuracy on an external test set

model.evaluate(val, verbose=1, sample_weight=None, steps=step_size_val, callbacks=None, max_queue_size=10, workers=1, use_multiprocessing=False)

# %%
# this cell is to predict image classes

predictions=model.predict(val, verbose=1, steps=step_size_val, callbacks=None, max_queue_size=10, workers=1, use_multiprocessing=False)
# Out:
# 22/22 [==============================] - 12s 535ms/step

# %%
print([sum(x)/len(x) for x in zip(*predictions)])
#this gets you the averages for each position in the array!!!
# Out:
# [0.5863971998491748, 0.41360280180180614]
