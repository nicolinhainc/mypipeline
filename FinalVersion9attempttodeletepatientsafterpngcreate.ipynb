# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolinhainc/mypipeline/blob/master/FinalVersion9attempttodeletepatientsafterpngcreate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd '/content/'
# Out:
# /content

# %%
# !wget --no-check-certificate 'https://drive.google.com/uc?export=download&id=1XdwGEqKXeKH1NRhZXxCZo5T8mncwYHCC' -O ./Bet-n-dcm2nii.zip
# !unzip -q ./Bet-n-dcm2nii.zip
# !rm -rf images
# Out:
# --2020-04-09 20:22:31--  https://drive.google.com/uc?export=download&id=1XdwGEqKXeKH1NRhZXxCZo5T8mncwYHCC
# Resolving drive.google.com (drive.google.com)... 172.217.4.174, 2607:f8b0:4007:801::200e
# Connecting to drive.google.com (drive.google.com)|172.217.4.174|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0k-60-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/8988dqjic6m1p2a4ugun2b519hgtjegh/1586463750000/07380574639032097336/*/1XdwGEqKXeKH1NRhZXxCZo5T8mncwYHCC?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-04-09 20:22:43--  https://doc-0k-60-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/8988dqjic6m1p2a4ugun2b519hgtjegh/1586463750000/07380574639032097336/*/1XdwGEqKXeKH1NRhZXxCZo5T8mncwYHCC?e=download
# Resolving doc-0k-60-docs.googleusercontent.com (doc-0k-60-docs.googleusercontent.com)... 172.217.14.65, 2607:f8b0:4007:803::2001
# Connecting to doc-0k-60-docs.googleusercontent.com (doc-0k-60-docs.googleusercontent.com)|172.217.14.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘./Bet-n-dcm2nii.zip’
#
# ./Bet-n-dcm2nii.zip     [    <=>             ]  12.52M  8.58MB/s    in 1.5s
#
# 2020-04-09 20:22:45 (8.58 MB/s) - ‘./Bet-n-dcm2nii.zip’ saved [13126916]

# %%
# upload the zip file yourself

# %%
# !unzip -q ./adnitest10.zip
# Out:
# replace __MACOSX/adnitest10/._.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
# !rm -rf './adnitest10/AD/.DS_Store'
# !rm -rf './adnitest10/CN/.DS_Store'

# %%
# !wget --no-check-certificate 'https://www.dropbox.com/s/78omroebht50042/icbm_avg_152_t1_tal_lin.nii.zip?dl=1' -O ./icbm152t1.zip
# !unzip -q ./icbm152t1.zip
# Out:
# --2020-04-09 20:25:25--  https://www.dropbox.com/s/78omroebht50042/icbm_avg_152_t1_tal_lin.nii.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.1, 2620:100:601b:1::a27d:801
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/78omroebht50042/icbm_avg_152_t1_tal_lin.nii.zip [following]
# --2020-04-09 20:25:26--  https://www.dropbox.com/s/dl/78omroebht50042/icbm_avg_152_t1_tal_lin.nii.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce4c68b92afe110df5d9bccb460.dl.dropboxusercontent.com/cd/0/get/A1jFKl1n1JFV_CtuxEy6W8P6hgkJ9H_XzYt7OYLTJEMCPTVzdyD_IeM8Tm698evaPnMPERAVfacIVUmi_j5vXdCNHa-rrIqNeYUfWfhQ5WHO05LKSDycLym99P6CtkdPTb0/file?dl=1# [following]
# --2020-04-09 20:25:26--  https://uce4c68b92afe110df5d9bccb460.dl.dropboxusercontent.com/cd/0/get/A1jFKl1n1JFV_CtuxEy6W8P6hgkJ9H_XzYt7OYLTJEMCPTVzdyD_IeM8Tm698evaPnMPERAVfacIVUmi_j5vXdCNHa-rrIqNeYUfWfhQ5WHO05LKSDycLym99P6CtkdPTb0/file?dl=1
# Resolving uce4c68b92afe110df5d9bccb460.dl.dropboxusercontent.com (uce4c68b92afe110df5d9bccb460.dl.dropboxusercontent.com)... 162.125.8.6, 2620:100:601b:6::a27d:806
# Connecting to uce4c68b92afe110df5d9bccb460.dl.dropboxusercontent.com (uce4c68b92afe110df5d9bccb460.dl.dropboxusercontent.com)|162.125.8.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14475752 (14M) [application/binary]
# Saving to: ‘./icbm152t1.zip’
#
# ./icbm152t1.zip     100%[===================>]  13.80M  39.5MB/s    in 0.3s
#
# 2020-04-09 20:25:27 (39.5 MB/s) - ‘./icbm152t1.zip’ saved [14475752/14475752]
#
# replace __MACOSX/._icbm_avg_152_t1_tal_lin.nii? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
NIFTI_PATH = 'adnitest10/AD/'

# %%
import gzip
import shutil
import os
import fnmatch

# %%
os.environ['FSLOUTPUTTYPE'] = 'NIFTI_GZ'

# %%
for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    print ("Working on " + subj_path)
    series = fnmatch.filter(os.listdir(subj_path), '*.nii')
    for ser in ['T1.nii']: 
      nativenii_file = os.path.join (subj_path, ser)
      newniigz_file = os.path.join (subj_path, ser)
      with open(nativenii_file, 'rb') as f_in:
        with gzip.open(newniigz_file + '.gz', 'wb') as f_out:
          shutil.copyfileobj(f_in, f_out)
# Out:
# Working on adnitest10/AD/Patient1
# Working on adnitest10/AD/Patient5
# Working on adnitest10/AD/Patient4
# Working on adnitest10/AD/Patient2
# Working on adnitest10/AD/Patient3

# %%
for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    print ("Working on " + subj_path)
    series = fnmatch.filter(os.listdir(subj_path), '*.nii')
    for ser in ['T1.nii']: 
        niinative_file = os.path.join (subj_path, ser)
# removes old files
        
        cmd = os.remove(niinative_file)
        
        print (cmd)
# Out:
# Working on adnitest10/AD/Patient1
# None
# Working on adnitest10/AD/Patient5
# None
# Working on adnitest10/AD/Patient4
# None
# Working on adnitest10/AD/Patient2
# None
# Working on adnitest10/AD/Patient3
# None

# %%
NIFTI_PATH = 'adnitest10/CN/'

# %%
for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    print ("Working on " + subj_path)
    series = fnmatch.filter(os.listdir(subj_path), '*.nii')
    for ser in ['T1.nii']: 
      nativenii_file = os.path.join (subj_path, ser)
      newniigz_file = os.path.join (subj_path, ser)
      with open(nativenii_file, 'rb') as f_in:
        with gzip.open(newniigz_file + '.gz', 'wb') as f_out:
          shutil.copyfileobj(f_in, f_out)
# Out:
# Working on adnitest10/CN/Patient1
# Working on adnitest10/CN/Patient5
# Working on adnitest10/CN/Patient4
# Working on adnitest10/CN/Patient2
# Working on adnitest10/CN/Patient3

# %%
for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    print ("Working on " + subj_path)
    series = fnmatch.filter(os.listdir(subj_path), '*.nii')
    for ser in ['T1.nii']: 
        niinative_file = os.path.join (subj_path, ser)
# removes old files
        
        cmd = os.remove(niinative_file)
        
        print (cmd)
# Out:
# Working on adnitest10/CN/Patient1
# None
# Working on adnitest10/CN/Patient5
# None
# Working on adnitest10/CN/Patient4
# None
# Working on adnitest10/CN/Patient2
# None
# Working on adnitest10/CN/Patient3
# None

# %%
NIFTI_PATH = 'adnitest10/AD/'

# %%
for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    print ("Working on " + subj_path)
    series = fnmatch.filter(os.listdir(subj_path), '*.nii.gz')
    for ser in ['T1']: #not sure why I had to add the star here but this was the only way it worked
        nii_file = os.path.join (subj_path, ser)
# First, perform N4 bias correction. Not required, but may improve results. Also must track new names
        new_file = os.path.join (subj_path, 'N4-' + ser)
        cmd = "./N4BiasFieldCorrection -i %s.nii.gz -o %s.nii.gz" % (nii_file, new_file)
        os.system(cmd)
        print (cmd)
# Out:
# Working on adnitest10/AD/Patient1
# ./N4BiasFieldCorrection -i adnitest10/AD/Patient1/T1.nii.gz -o adnitest10/AD/Patient1/N4-T1.nii.gz
# Working on adnitest10/AD/Patient5
# ./N4BiasFieldCorrection -i adnitest10/AD/Patient5/T1.nii.gz -o adnitest10/AD/Patient5/N4-T1.nii.gz
# Working on adnitest10/AD/Patient4
# ./N4BiasFieldCorrection -i adnitest10/AD/Patient4/T1.nii.gz -o adnitest10/AD/Patient4/N4-T1.nii.gz
# Working on adnitest10/AD/Patient2
# ./N4BiasFieldCorrection -i adnitest10/AD/Patient2/T1.nii.gz -o adnitest10/AD/Patient2/N4-T1.nii.gz
# Working on adnitest10/AD/Patient3
# ./N4BiasFieldCorrection -i adnitest10/AD/Patient3/T1.nii.gz -o adnitest10/AD/Patient3/N4-T1.nii.gz

# %%
for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    print ("Working on " + subj_path)
    series = fnmatch.filter(os.listdir(subj_path), '*.nii.gz')
    for ser in ['T1.nii.gz']: #not sure why I had to add the star here but this was the only way it worked
        nii_file = os.path.join (subj_path, ser)
# removes old files
        
        cmd = os.remove(nii_file)
        
        print (cmd)
# Out:
# Working on adnitest10/AD/Patient1
# None
# Working on adnitest10/AD/Patient5
# None
# Working on adnitest10/AD/Patient4
# None
# Working on adnitest10/AD/Patient2
# None
# Working on adnitest10/AD/Patient3
# None

# %%
NIFTI_PATH = 'adnitest10/CN/'

# %%
for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    print ("Working on " + subj_path)
    series = fnmatch.filter(os.listdir(subj_path), '*.nii.gz')
    for ser in ['T1']: #not sure why I had to add the star here but this was the only way it worked
        nii_file = os.path.join (subj_path, ser)
# First, perform N4 bias correction. Not required, but may improve results. Also must track new names
        new_file = os.path.join (subj_path, 'N4-' + ser)
        cmd = "./N4BiasFieldCorrection -i %s.nii.gz -o %s.nii.gz" % (nii_file, new_file)
        os.system(cmd)
        print (cmd)
# Out:
# Working on adnitest10/CN/Patient1
# ./N4BiasFieldCorrection -i adnitest10/CN/Patient1/T1.nii.gz -o adnitest10/CN/Patient1/N4-T1.nii.gz
# Working on adnitest10/CN/Patient5
# ./N4BiasFieldCorrection -i adnitest10/CN/Patient5/T1.nii.gz -o adnitest10/CN/Patient5/N4-T1.nii.gz
# Working on adnitest10/CN/Patient4
# ./N4BiasFieldCorrection -i adnitest10/CN/Patient4/T1.nii.gz -o adnitest10/CN/Patient4/N4-T1.nii.gz
# Working on adnitest10/CN/Patient2
# ./N4BiasFieldCorrection -i adnitest10/CN/Patient2/T1.nii.gz -o adnitest10/CN/Patient2/N4-T1.nii.gz
# Working on adnitest10/CN/Patient3
# ./N4BiasFieldCorrection -i adnitest10/CN/Patient3/T1.nii.gz -o adnitest10/CN/Patient3/N4-T1.nii.gz

# %%
for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    print ("Working on " + subj_path)
    series = fnmatch.filter(os.listdir(subj_path), '*.nii.gz')
    for ser in ['T1.nii.gz']: #not sure why I had to add the star here but this was the only way it worked
        nii_file = os.path.join (subj_path, ser)
# removes old files
        
        cmd = os.remove(nii_file)
        
        print (cmd)
# Out:
# Working on adnitest10/CN/Patient1
# None
# Working on adnitest10/CN/Patient5
# None
# Working on adnitest10/CN/Patient4
# None
# Working on adnitest10/CN/Patient2
# None
# Working on adnitest10/CN/Patient3
# None

# %%
NIFTI_PATH = 'adnitest10/AD/'

# %%
# Next, Register the images to the avg 152 t1 image from MNI
for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    print ("Working on " + subj_path)
    series = fnmatch.filter(os.listdir(subj_path), 'N4-*')
    for ser in ['T1']:   
        MNI_file = './icbm_avg_152_t1_tal_lin.nii'
        T1_file =  os.path.join (subj_path, 'N4-T1*.nii.gz')
        new_file = os.path.join (subj_path, 'Reg-N4-T1.nii.gz')
        cmd = "./flirt -in %s -ref %s  -out %s" % (T1_file, MNI_file, new_file)
        os.system(cmd)
        print (cmd)
# Out:
# Working on adnitest10/AD/Patient1
# ./flirt -in adnitest10/AD/Patient1/N4-T1*.nii.gz -ref ./icbm_avg_152_t1_tal_lin.nii  -out adnitest10/AD/Patient1/Reg-N4-T1.nii.gz
# Working on adnitest10/AD/Patient5
# ./flirt -in adnitest10/AD/Patient5/N4-T1*.nii.gz -ref ./icbm_avg_152_t1_tal_lin.nii  -out adnitest10/AD/Patient5/Reg-N4-T1.nii.gz
# Working on adnitest10/AD/Patient4
# ./flirt -in adnitest10/AD/Patient4/N4-T1*.nii.gz -ref ./icbm_avg_152_t1_tal_lin.nii  -out adnitest10/AD/Patient4/Reg-N4-T1.nii.gz
# Working on adnitest10/AD/Patient2
# ./flirt -in adnitest10/AD/Patient2/N4-T1*.nii.gz -ref ./icbm_avg_152_t1_tal_lin.nii  -out adnitest10/AD/Patient2/Reg-N4-T1.nii.gz
# Working on adnitest10/AD/Patient3
# ./flirt -in adnitest10/AD/Patient3/N4-T1*.nii.gz -ref ./icbm_avg_152_t1_tal_lin.nii  -out adnitest10/AD/Patient3/Reg-N4-T1.nii.gz

# %%
# Next, remove the unnecessary N4-T1 files
for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    print ("Working on " + subj_path)
    series = fnmatch.filter(os.listdir(subj_path), 'N4-*')
    for ser in ['T1']:   
        MNI_file = './icbm_avg_152_t1_tal_lin.nii'
        T1_file =  os.path.join (subj_path, 'N4-T1.nii.gz')
        new_file = os.path.join (subj_path, 'Reg-N4-T1.nii.gz')
        cmd = os.remove(T1_file)
        
        print (cmd)
# Out:
# Working on adnitest10/AD/Patient1
# None
# Working on adnitest10/AD/Patient5
# None
# Working on adnitest10/AD/Patient4
# None
# Working on adnitest10/AD/Patient2
# None
# Working on adnitest10/AD/Patient3
# None

# %%
NIFTI_PATH = 'adnitest10/CN/'

# %%
# Next, Register the images to the avg 152 t1 image from MNI
for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    print ("Working on " + subj_path)
    series = fnmatch.filter(os.listdir(subj_path), 'N4-*')
    for ser in ['T1']:   
        MNI_file = './icbm_avg_152_t1_tal_lin.nii'
        T1_file =  os.path.join (subj_path, 'N4-T1*.nii.gz')
        new_file = os.path.join (subj_path, 'Reg-N4-T1.nii.gz')
        cmd = "./flirt -in %s -ref %s  -out %s" % (T1_file, MNI_file, new_file)
        os.system(cmd)
        print (cmd)
# Out:
# Working on adnitest10/CN/Patient1
# ./flirt -in adnitest10/CN/Patient1/N4-T1*.nii.gz -ref ./icbm_avg_152_t1_tal_lin.nii  -out adnitest10/CN/Patient1/Reg-N4-T1.nii.gz
# Working on adnitest10/CN/Patient5
# ./flirt -in adnitest10/CN/Patient5/N4-T1*.nii.gz -ref ./icbm_avg_152_t1_tal_lin.nii  -out adnitest10/CN/Patient5/Reg-N4-T1.nii.gz
# Working on adnitest10/CN/Patient4
# ./flirt -in adnitest10/CN/Patient4/N4-T1*.nii.gz -ref ./icbm_avg_152_t1_tal_lin.nii  -out adnitest10/CN/Patient4/Reg-N4-T1.nii.gz
# Working on adnitest10/CN/Patient2
# ./flirt -in adnitest10/CN/Patient2/N4-T1*.nii.gz -ref ./icbm_avg_152_t1_tal_lin.nii  -out adnitest10/CN/Patient2/Reg-N4-T1.nii.gz
# Working on adnitest10/CN/Patient3
# ./flirt -in adnitest10/CN/Patient3/N4-T1*.nii.gz -ref ./icbm_avg_152_t1_tal_lin.nii  -out adnitest10/CN/Patient3/Reg-N4-T1.nii.gz

# %%
# Next, remove the unnecessary N4-T1 files
for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    print ("Working on " + subj_path)
    series = fnmatch.filter(os.listdir(subj_path), 'N4-*')
    for ser in ['T1']:   
        MNI_file = './icbm_avg_152_t1_tal_lin.nii'
        T1_file =  os.path.join (subj_path, 'N4-T1.nii.gz')
        new_file = os.path.join (subj_path, 'Reg-N4-T1.nii.gz')
        cmd = os.remove(T1_file)
        
        print (cmd)
# Out:
# Working on adnitest10/CN/Patient1
# None
# Working on adnitest10/CN/Patient5
# None
# Working on adnitest10/CN/Patient4
# None
# Working on adnitest10/CN/Patient2
# None
# Working on adnitest10/CN/Patient3
# None

# %%
#manually create the valc1 and valc2 folders to make sure it works
#below ref https://stackoverflow.com/questions/46717742/split-data-directory-into-training-and-test-directory-with-sub-directory-structu

# %%
   import os
   import shutil
   import numpy as np
   base_dir = '/content/adnitest10'

   # !mkdir /content/adnitest10/ADval
   # !mkdir /content/adnitest10/CNval
# Out:
# mkdir: cannot create directory ‘/content/adnitest10/ADval’: File exists
# mkdir: cannot create directory ‘/content/adnitest10/CNval’: File exists

# %%
sourceN = base_dir + "/AD"
destN = base_dir + "/ADval"
sourceP = base_dir + "/CN"
destP = base_dir + "/CNval"

filesN = os.listdir(sourceN)
filesP = os.listdir(sourceP)       

for f in filesN:
  if np.random.rand(1) < 0.3: #is this a 70 30 split? what does it mean exactly?
    shutil.move(sourceN + '/'+ f, destN + '/'+ f)

for i in filesP:
  if np.random.rand(1) < 0.3:
    shutil.move(sourceP + '/'+ i, destP + '/'+ i)

print(len(os.listdir(sourceN)))
print(len(os.listdir(sourceP)))
print(len(os.listdir(destN)))
print(len(os.listdir(destP)))
# Out:
# 3
# 4
# 2
# 1

# %%
# !rm -rf ./LGG/valc2/.ipynb_checkpoints
# !rm -rf ./LGG/valc1/.ipynb_checkpoints

# !rm -rf './adnitest10/ADval/.ipynb_checkpoints'
# !rm -rf './adnitest10/CNval/.ipynb_checkpoints'

# %%
#make a huge list of thousands of patients here
import pandas as pd

# !wget --no-check-certificate 'https://drive.google.com/uc?export=download&id=1z2GmRDDVMbcb1x26jlA9X0M4WAv4-kvA' -O ./TumorSlices.csv
df = pd.read_csv ('./TumorSlices.csv')
print (df)
# Out:
# --2020-04-09 21:23:07--  https://drive.google.com/uc?export=download&id=1z2GmRDDVMbcb1x26jlA9X0M4WAv4-kvA
# Resolving drive.google.com (drive.google.com)... 172.217.14.78, 2607:f8b0:4007:803::200e
# Connecting to drive.google.com (drive.google.com)|172.217.14.78|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-10-60-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/26ehk2he17be5thfs1hi8cuvsto3u5au/1586467350000/07380574639032097336/*/1z2GmRDDVMbcb1x26jlA9X0M4WAv4-kvA?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-04-09 21:23:07--  https://doc-10-60-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/26ehk2he17be5thfs1hi8cuvsto3u5au/1586467350000/07380574639032097336/*/1z2GmRDDVMbcb1x26jlA9X0M4WAv4-kvA?e=download
# Resolving doc-10-60-docs.googleusercontent.com (doc-10-60-docs.googleusercontent.com)... 172.217.14.65, 2607:f8b0:4007:803::2001
# Connecting to doc-10-60-docs.googleusercontent.com (doc-10-60-docs.googleusercontent.com)|172.217.14.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 188 [text/csv]
# Saving to: ‘./TumorSlices.csv’
#
# ./TumorSlices.csv   100%[===================>]     188  --.-KB/s    in 0s
#
# 2020-04-09 21:23:07 (13.4 MB/s) - ‘./TumorSlices.csv’ saved [188/188]
#
#      Subject  StartSlice  EndSlice
# 0   Patient1           0       300
# 1   Patient2           0       300
# 2   Patient3           0       300
# 3   Patient4           0       300
# 4   Patient5           0       300
# 5   Patient6           0       300
# 6   Patient7           0       300
# 7   Patient8           0       300
# 8   Patient9           0       300
# 9  Patient10           0       300

# %%
# Cell #5
# create new versions of the T1, GAD, and T2 images that range from 0 to 255, and where the 0 intensity value maps to the 5th percentile value 
# and 255 maps to the 95th percentile value.
import imageio
import nibabel as nib
import numpy as np

MIN_MR = 20

def rescale_5_95_percentile(image):
    dims = np.shape(image)
    image_1d = image.reshape(1, image.size)
    above = np.where(image_1d>MIN_MR, image_1d, image_1d)
    if above.size < image_1d.size/2:
        above = image_1d # avoid bad MIN_MR thresholds
    sorted_im = np.sort(above, axis = None)
    
    start = int(sorted_im.size / 20)  # 20 = 5%
    end = int(sorted_im.size * 19 / 20) # 95%
    start_val = sorted_im[start]
    end_val = sorted_im[end]
    
    image = np.maximum(image, start_val) # map values below the start_val to start_val
    image = np.minimum(image, end_val)   # map values above the end_val to end_val
    image = image - start_val # subtract the starting intensity

 #   print ("rescaling range " + str(newmin) + " to " + str(histo[1][index]))
    image = (np.maximum(image, 0) / image.max()) * 255.0
    return image

def nifti_to_img(red_file, green_file, blue_file, not_dir, yes_dir, startSlice, endSlice, subject):
### red_ green_ and blue_files are the nifit files that will be combined to go into the PNG
### not_dir is the direcotry where PNGs are stored if they are not in the (inclusive)
### range set by startSlice/endSlice
### yes_dir is where they are stored when they ARE in the range
### subject is the ID so that we can track where images came from

    try:
        nifti = nib.load(red_file)
        nif_header = nifti.header
        red_image = nifti.get_fdata()
    except:
        return 0

    try:
        if os.path.isfile(green_file):
            nifti = nib.load(green_file)
            nif_header = nifti.header
            green_image = nifti.get_fdata()
        else:
            pass
    except:  # if can't load, then use red image
        green_image = red_image
    
    try:
        if os.path.isfile(blue_file):
            nifti = nib.load(blue_file)

            nif_header = nifti.header
            blue_image = nifti.get_fdata()
        else:
            pass
    except:  # if can't load, then use red image
        blue_image = red_image
        
# now scale the intensity for each image        
    red_image = rescale_5_95_percentile(red_image)
    green_image = rescale_5_95_percentile(green_image)
    blue_image = rescale_5_95_percentile(blue_image)
# then convert to 8 bits
    red_image = red_image.astype(np.uint8)     
    green_image = green_image.astype(np.uint8)     
    blue_image = blue_image.astype(np.uint8)   
    
# get the number of slices
    dims = np.shape(red_image)
    zd = dims[2]

    for z in range(0, zd):
        outname = subject + "-{0:04d}".format(z) + '.png'
        if z >= startSlice and z <= endSlice:  # this is enhancing
            out_dir = yes_dir
        else:
            out_dir = not_dir
        outname = os.path.join(out_dir, outname)
        if not os.path.exists(out_dir):
            os.makedirs(out_dir)
        combined = np.dstack((red_image[:,:,z],green_image[:,:,z],
                              blue_image[:,:,z]))
## . images come in rotated
        combined = np.rot90(combined, k=1)
#        print ('Name: ' + outname)
        imageio.imwrite(outname, combined)
    return zd

# %%
NIFTI_PATH = 'adnitest10/AD/'

# %%
# Cell #6
# take the GAD nii, scale it to 0-255 and store that into the red channel
# same for T1 (green) and T2 (blue)
# PNG files are stored in enh / nonenh folders based on the csv file

# store the png files into enhancing or nonenhancing folders after making sure they are cleared

# !rm -rf classified

# !mkdir classified

for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    red_f = os.path.join(subj_path, 'Reg-N4-T1.nii.gz')
    startSlice = df.loc[df.Subject == subj, 'StartSlice'].values[0]
    endSlice = df.loc[df.Subject == subj, 'EndSlice'].values[0]
    print ("Making PNG file for " + subj + " start: " + str(startSlice) + " end: " + str(endSlice))
    count = nifti_to_img(red_f, red_f, red_f, NIFTI_PATH, NIFTI_PATH, startSlice, endSlice, subj)
# Out:
# Making PNG file for Patient1 start: 0 end: 300
# Making PNG file for Patient5 start: 0 end: 300
# Making PNG file for Patient2 start: 0 end: 300

# %%
NIFTI_PATH = 'adnitest10/CN/'

# %%
# Cell #6
# take the GAD nii, scale it to 0-255 and store that into the red channel
# same for T1 (green) and T2 (blue)
# PNG files are stored in enh / nonenh folders based on the csv file

# store the png files into enhancing or nonenhancing folders after making sure they are cleared

# !rm -rf classified

# !mkdir classified

for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    red_f = os.path.join(subj_path, 'Reg-N4-T1.nii.gz')
    startSlice = df.loc[df.Subject == subj, 'StartSlice'].values[0]
    endSlice = df.loc[df.Subject == subj, 'EndSlice'].values[0]
    print ("Making PNG file for " + subj + " start: " + str(startSlice) + " end: " + str(endSlice))
    count = nifti_to_img(red_f, red_f, red_f, NIFTI_PATH, NIFTI_PATH, startSlice, endSlice, subj)
# Out:
# Making PNG file for Patient1 start: 0 end: 300
# Making PNG file for Patient5 start: 0 end: 300
# Making PNG file for Patient4 start: 0 end: 300
# Making PNG file for Patient2 start: 0 end: 300

# %%
NIFTI_PATH = 'adnitest10/ADval/'

# %%
# Cell #6
# take the GAD nii, scale it to 0-255 and store that into the red channel
# same for T1 (green) and T2 (blue)
# PNG files are stored in enh / nonenh folders based on the csv file

# store the png files into enhancing or nonenhancing folders after making sure they are cleared

# !rm -rf classified

# !mkdir classified

for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    red_f = os.path.join(subj_path, 'Reg-N4-T1.nii.gz')
    startSlice = df.loc[df.Subject == subj, 'StartSlice'].values[0]
    endSlice = df.loc[df.Subject == subj, 'EndSlice'].values[0]
    print ("Making PNG file for " + subj + " start: " + str(startSlice) + " end: " + str(endSlice))
    count = nifti_to_img(red_f, red_f, red_f, NIFTI_PATH, NIFTI_PATH, startSlice, endSlice, subj)
# Out:
# Making PNG file for Patient4 start: 0 end: 300
# Making PNG file for Patient3 start: 0 end: 300

# %%
NIFTI_PATH = 'adnitest10/CNval/'

# %%
# Cell #6
# take the GAD nii, scale it to 0-255 and store that into the red channel
# same for T1 (green) and T2 (blue)
# PNG files are stored in enh / nonenh folders based on the csv file

# store the png files into enhancing or nonenhancing folders after making sure they are cleared

# !rm -rf classified

# !mkdir classified

for subj in os.listdir(NIFTI_PATH):
    subj_path = os.path.join(NIFTI_PATH, subj)
    red_f = os.path.join(subj_path, 'Reg-N4-T1.nii.gz')
    startSlice = df.loc[df.Subject == subj, 'StartSlice'].values[0]
    endSlice = df.loc[df.Subject == subj, 'EndSlice'].values[0]
    print ("Making PNG file for " + subj + " start: " + str(startSlice) + " end: " + str(endSlice))
    count = nifti_to_img(red_f, red_f, red_f, NIFTI_PATH, NIFTI_PATH, startSlice, endSlice, subj)
    # !rm -rf red_f
    # !rm -rf subj_path
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-99ec6c9fb2e6> in <module>()
#       7     subj_path = os.path.join(NIFTI_PATH, subj)
#       8     red_f = os.path.join(subj_path, 'Reg-N4-T1.nii.gz')
# ----> 9     startSlice = df.loc[df.Subject == subj, 'StartSlice'].values[0]
#      10     endSlice = df.loc[df.Subject == subj, 'EndSlice'].values[0]
#      11     print ("Making PNG file for " + subj + " start: " + str(startSlice) + " end: " + str(endSlice))
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# %cd '/content'
# Out:
# /content

# %%
#below code is from https://towardsdatascience.com/keras-transfer-learning-for-beginners-6c9b8b7143e
#and https://towardsdatascience.com/a-comprehensive-hands-on-guide-to-transfer-learning-with-real-world-applications-in-deep-learning-212bf3b2f27a
#get the githubs for the refs in the paper

# %%
# Cell #7
# now we are ready to load data and train classifier
# while we did this in separate cells before, we will do it all in one
# this should look familiar.
import numpy as np
import tensorflow as tf
# !pip install tensornets
import tensornets as nets
import tensorflow_hub as hub
import keras
import tensorflow.keras 
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense,GlobalAveragePooling2D
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.nasnet import NASNetLarge, NASNetMobile, preprocess_input
directory = "./content"

base_model=tensorflow.keras.applications.nasnet.NASNetLarge(input_shape=(331, 331, 3), include_top=False, weights='imagenet', input_tensor=None, pooling=None) #imports the nasnet large model and discards the last 1000 neuron layer.

x=base_model.output
x=GlobalAveragePooling2D()(x)
x=Dense(1024,activation='relu')(x) #we add dense layers so that the model can learn more complex functions and classify for better results.
x=Dense(1024,activation='relu')(x) #dense layer 2
x=Dense(512,activation='relu')(x) #dense layer 3
preds=Dense(2,activation='softmax')(x) #final layer with softmax activation, for 2 classes

model=Model(inputs=base_model.input,outputs=preds) # to load saved model with weights use model= tensorflow.keras.models.load_model('myLGGtestmodel.h5')
#specify the inputs
#specify the outputs
#now a model has been created based on our architecture

for i,layer in enumerate(model.layers):
  print(i,layer.name)

for layer in model.layers:
    layer.trainable=False
# or if we want to set the first 20 layers of the network to be non-trainable
for layer in model.layers[:1039]:
    layer.trainable=False
for layer in model.layers[1039:]:
    layer.trainable=True

train_datagen=ImageDataGenerator(rotation_range=20, zoom_range=0.15, width_shift_range=0.2, height_shift_range=0.2, shear_range=0, fill_mode='nearest', horizontal_flip=False, data_format='channels_last', validation_split=0.0, dtype='float32') #included in our dependencies
# add the directory below very important ##########################

train=train_datagen.flow_from_directory('./train',
                                                 target_size=(331,331),
                                                 color_mode='rgb',
                                                 batch_size=32,
                                                 class_mode='categorical',
                                                 shuffle=True)

val_datagen=ImageDataGenerator()

val=val_datagen.flow_from_directory('./validate',
                                                 target_size=(331,331),
                                                 color_mode='rgb',
                                                 batch_size=32,
                                                 class_mode='categorical',
                                                 shuffle=False)

model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
# Adam optimizer
# loss function will be categorical cross entropy
# evaluation metric will be accuracy

step_size_train=train.n//train.batch_size
step_size_val=val.n//val.batch_size
#model.fit_generator(generator=train_generator,
#                   steps_per_epoch=step_size_train,
#                   epochs=3)

history = model.fit(train, steps_per_epoch=step_size_train, epochs=3,
                              validation_data=val, validation_steps=step_size_val, 
                              verbose=1)       


    
# next cell to save model including newly trained weights
# model.save('myLGGtestmodel.h5') # rename it how you like, it will show up in your directory. I have explained above using a hastag how and where to load the model.
# Out:
# Requirement already satisfied: tensornets in /usr/local/lib/python3.6/dist-packages (0.4.6)
# Using TensorFlow backend.
# 0 input_1
# 1 stem_conv1
# 2 stem_bn1
# 3 activation
# 4 reduction_conv_1_stem_1
# 5 reduction_bn_1_stem_1
# 6 activation_1
# 7 activation_3
# 8 separable_conv_1_pad_reduction_left1_stem_1
# 9 separable_conv_1_pad_reduction_right1_stem_1
# 10 separable_conv_1_reduction_left1_stem_1
# 11 separable_conv_1_reduction_right1_stem_1
# 12 separable_conv_1_bn_reduction_left1_stem_1
# 13 separable_conv_1_bn_reduction_right1_stem_1
# 14 activation_2
# 15 activation_4
# 16 separable_conv_2_reduction_left1_stem_1
# 17 separable_conv_2_reduction_right1_stem_1
# 18 activation_5
# 19 separable_conv_2_bn_reduction_left1_stem_1
# 20 separable_conv_2_bn_reduction_right1_stem_1
# 21 separable_conv_1_pad_reduction_right2_stem_1
# 22 activation_7
# 23 reduction_add_1_stem_1
# 24 separable_conv_1_reduction_right2_stem_1
# 25 separable_conv_1_pad_reduction_right3_stem_1
# 26 activation_9
# 27 separable_conv_1_bn_reduction_right2_stem_1
# 28 separable_conv_1_reduction_right3_stem_1
# 29 separable_conv_1_reduction_left4_stem_1
# 30 activation_6
# 31 separable_conv_1_bn_reduction_right3_stem_1
# 32 separable_conv_1_bn_reduction_left4_stem_1
# 33 reduction_pad_1_stem_1
# 34 separable_conv_2_reduction_right2_stem_1
# 35 activation_8
# 36 activation_10
# 37 reduction_left2_stem_1
# 38 separable_conv_2_bn_reduction_right2_stem_1
# 39 separable_conv_2_reduction_right3_stem_1
# 40 separable_conv_2_reduction_left4_stem_1
# 41 adjust_relu_1_stem_2
# 42 reduction_add_2_stem_1
# 43 reduction_left3_stem_1
# 44 separable_conv_2_bn_reduction_right3_stem_1
# 45 reduction_left4_stem_1
# 46 separable_conv_2_bn_reduction_left4_stem_1
# 47 reduction_right5_stem_1
# 48 zero_padding2d
# 49 reduction_add3_stem_1
# 50 add
# 51 reduction_add4_stem_1
# 52 cropping2d
# 53 reduction_concat_stem_1
# 54 adjust_avg_pool_1_stem_2
# 55 adjust_avg_pool_2_stem_2
# 56 activation_11
# 57 adjust_conv_1_stem_2
# 58 adjust_conv_2_stem_2
# 59 reduction_conv_1_stem_2
# 60 concatenate
# 61 reduction_bn_1_stem_2
# 62 adjust_bn_stem_2
# 63 activation_12
# 64 activation_14
# 65 separable_conv_1_pad_reduction_left1_stem_2
# 66 separable_conv_1_pad_reduction_right1_stem_2
# 67 separable_conv_1_reduction_left1_stem_2
# 68 separable_conv_1_reduction_right1_stem_2
# 69 separable_conv_1_bn_reduction_left1_stem_2
# 70 separable_conv_1_bn_reduction_right1_stem_2
# 71 activation_13
# 72 activation_15
# 73 separable_conv_2_reduction_left1_stem_2
# 74 separable_conv_2_reduction_right1_stem_2
# 75 activation_16
# 76 separable_conv_2_bn_reduction_left1_stem_2
# 77 separable_conv_2_bn_reduction_right1_stem_2
# 78 separable_conv_1_pad_reduction_right2_stem_2
# 79 activation_18
# 80 reduction_add_1_stem_2
# 81 separable_conv_1_reduction_right2_stem_2
# 82 separable_conv_1_pad_reduction_right3_stem_2
# 83 activation_20
# 84 separable_conv_1_bn_reduction_right2_stem_2
# 85 separable_conv_1_reduction_right3_stem_2
# 86 separable_conv_1_reduction_left4_stem_2
# 87 activation_17
# 88 separable_conv_1_bn_reduction_right3_stem_2
# 89 separable_conv_1_bn_reduction_left4_stem_2
# 90 reduction_pad_1_stem_2
# 91 separable_conv_2_reduction_right2_stem_2
# 92 activation_19
# 93 activation_21
# 94 reduction_left2_stem_2
# 95 separable_conv_2_bn_reduction_right2_stem_2
# 96 separable_conv_2_reduction_right3_stem_2
# 97 separable_conv_2_reduction_left4_stem_2
# 98 adjust_relu_1_0
# 99 reduction_add_2_stem_2
# 100 reduction_left3_stem_2
# 101 separable_conv_2_bn_reduction_right3_stem_2
# 102 reduction_left4_stem_2
# 103 separable_conv_2_bn_reduction_left4_stem_2
# 104 reduction_right5_stem_2
# 105 zero_padding2d_1
# 106 reduction_add3_stem_2
# 107 add_1
# 108 reduction_add4_stem_2
# 109 cropping2d_1
# 110 reduction_concat_stem_2
# 111 adjust_avg_pool_1_0
# 112 adjust_avg_pool_2_0
# 113 adjust_conv_1_0
# 114 adjust_conv_2_0
# 115 activation_22
# 116 concatenate_1
# 117 normal_conv_1_0
# 118 adjust_bn_0
# 119 normal_bn_1_0
# 120 activation_23
# 121 activation_25
# 122 activation_27
# 123 activation_29
# 124 activation_31
# 125 separable_conv_1_normal_left1_0
# 126 separable_conv_1_normal_right1_0
# 127 separable_conv_1_normal_left2_0
# 128 separable_conv_1_normal_right2_0
# 129 separable_conv_1_normal_left5_0
# 130 separable_conv_1_bn_normal_left1_0
# 131 separable_conv_1_bn_normal_right1_0
# 132 separable_conv_1_bn_normal_left2_0
# 133 separable_conv_1_bn_normal_right2_0
# 134 separable_conv_1_bn_normal_left5_0
# 135 activation_24
# 136 activation_26
# 137 activation_28
# 138 activation_30
# 139 activation_32
# 140 separable_conv_2_normal_left1_0
# 141 separable_conv_2_normal_right1_0
# 142 separable_conv_2_normal_left2_0
# 143 separable_conv_2_normal_right2_0
# 144 separable_conv_2_normal_left5_0
# 145 separable_conv_2_bn_normal_left1_0
# 146 separable_conv_2_bn_normal_right1_0
# 147 separable_conv_2_bn_normal_left2_0
# 148 separable_conv_2_bn_normal_right2_0
# 149 normal_left3_0
# 150 normal_left4_0
# 151 normal_right4_0
# 152 separable_conv_2_bn_normal_left5_0
# 153 normal_add_1_0
# 154 normal_add_2_0
# 155 normal_add_3_0
# 156 normal_add_4_0
# 157 normal_add_5_0
# 158 normal_concat_0
# 159 activation_33
# 160 activation_34
# 161 adjust_conv_projection_1
# 162 normal_conv_1_1
# 163 adjust_bn_1
# 164 normal_bn_1_1
# 165 activation_35
# 166 activation_37
# 167 activation_39
# 168 activation_41
# 169 activation_43
# 170 separable_conv_1_normal_left1_1
# 171 separable_conv_1_normal_right1_1
# 172 separable_conv_1_normal_left2_1
# 173 separable_conv_1_normal_right2_1
# 174 separable_conv_1_normal_left5_1
# 175 separable_conv_1_bn_normal_left1_1
# 176 separable_conv_1_bn_normal_right1_1
# 177 separable_conv_1_bn_normal_left2_1
# 178 separable_conv_1_bn_normal_right2_1
# 179 separable_conv_1_bn_normal_left5_1
# 180 activation_36
# 181 activation_38
# 182 activation_40
# 183 activation_42
# 184 activation_44
# 185 separable_conv_2_normal_left1_1
# 186 separable_conv_2_normal_right1_1
# 187 separable_conv_2_normal_left2_1
# 188 separable_conv_2_normal_right2_1
# 189 separable_conv_2_normal_left5_1
# 190 separable_conv_2_bn_normal_left1_1
# 191 separable_conv_2_bn_normal_right1_1
# 192 separable_conv_2_bn_normal_left2_1
# 193 separable_conv_2_bn_normal_right2_1
# 194 normal_left3_1
# 195 normal_left4_1
# 196 normal_right4_1
# 197 separable_conv_2_bn_normal_left5_1
# 198 normal_add_1_1
# 199 normal_add_2_1
# 200 normal_add_3_1
# 201 normal_add_4_1
# 202 normal_add_5_1
# 203 normal_concat_1
# 204 activation_45
# 205 activation_46
# 206 adjust_conv_projection_2
# 207 normal_conv_1_2
# 208 adjust_bn_2
# 209 normal_bn_1_2
# 210 activation_47
# 211 activation_49
# 212 activation_51
# 213 activation_53
# 214 activation_55
# 215 separable_conv_1_normal_left1_2
# 216 separable_conv_1_normal_right1_2
# 217 separable_conv_1_normal_left2_2
# 218 separable_conv_1_normal_right2_2
# 219 separable_conv_1_normal_left5_2
# 220 separable_conv_1_bn_normal_left1_2
# 221 separable_conv_1_bn_normal_right1_2
# 222 separable_conv_1_bn_normal_left2_2
# 223 separable_conv_1_bn_normal_right2_2
# 224 separable_conv_1_bn_normal_left5_2
# 225 activation_48
# 226 activation_50
# 227 activation_52
# 228 activation_54
# 229 activation_56
# 230 separable_conv_2_normal_left1_2
# 231 separable_conv_2_normal_right1_2
# 232 separable_conv_2_normal_left2_2
# 233 separable_conv_2_normal_right2_2
# 234 separable_conv_2_normal_left5_2
# 235 separable_conv_2_bn_normal_left1_2
# 236 separable_conv_2_bn_normal_right1_2
# 237 separable_conv_2_bn_normal_left2_2
# 238 separable_conv_2_bn_normal_right2_2
# 239 normal_left3_2
# 240 normal_left4_2
# 241 normal_right4_2
# 242 separable_conv_2_bn_normal_left5_2
# 243 normal_add_1_2
# 244 normal_add_2_2
# 245 normal_add_3_2
# 246 normal_add_4_2
# 247 normal_add_5_2
# 248 normal_concat_2
# 249 activation_57
# 250 activation_58
# 251 adjust_conv_projection_3
# 252 normal_conv_1_3
# 253 adjust_bn_3
# 254 normal_bn_1_3
# 255 activation_59
# 256 activation_61
# 257 activation_63
# 258 activation_65
# 259 activation_67
# 260 separable_conv_1_normal_left1_3
# 261 separable_conv_1_normal_right1_3
# 262 separable_conv_1_normal_left2_3
# 263 separable_conv_1_normal_right2_3
# 264 separable_conv_1_normal_left5_3
# 265 separable_conv_1_bn_normal_left1_3
# 266 separable_conv_1_bn_normal_right1_3
# 267 separable_conv_1_bn_normal_left2_3
# 268 separable_conv_1_bn_normal_right2_3
# 269 separable_conv_1_bn_normal_left5_3
# 270 activation_60
# 271 activation_62
# 272 activation_64
# 273 activation_66
# 274 activation_68
# 275 separable_conv_2_normal_left1_3
# 276 separable_conv_2_normal_right1_3
# 277 separable_conv_2_normal_left2_3
# 278 separable_conv_2_normal_right2_3
# 279 separable_conv_2_normal_left5_3
# 280 separable_conv_2_bn_normal_left1_3
# 281 separable_conv_2_bn_normal_right1_3
# 282 separable_conv_2_bn_normal_left2_3
# 283 separable_conv_2_bn_normal_right2_3
# 284 normal_left3_3
# 285 normal_left4_3
# 286 normal_right4_3
# 287 separable_conv_2_bn_normal_left5_3
# 288 normal_add_1_3
# 289 normal_add_2_3
# 290 normal_add_3_3
# 291 normal_add_4_3
# 292 normal_add_5_3
# 293 normal_concat_3
# 294 activation_69
# 295 activation_70
# 296 adjust_conv_projection_4
# 297 normal_conv_1_4
# 298 adjust_bn_4
# 299 normal_bn_1_4
# 300 activation_71
# 301 activation_73
# 302 activation_75
# 303 activation_77
# 304 activation_79
# 305 separable_conv_1_normal_left1_4
# 306 separable_conv_1_normal_right1_4
# 307 separable_conv_1_normal_left2_4
# 308 separable_conv_1_normal_right2_4
# 309 separable_conv_1_normal_left5_4
# 310 separable_conv_1_bn_normal_left1_4
# 311 separable_conv_1_bn_normal_right1_4
# 312 separable_conv_1_bn_normal_left2_4
# 313 separable_conv_1_bn_normal_right2_4
# 314 separable_conv_1_bn_normal_left5_4
# 315 activation_72
# 316 activation_74
# 317 activation_76
# 318 activation_78
# 319 activation_80
# 320 separable_conv_2_normal_left1_4
# 321 separable_conv_2_normal_right1_4
# 322 separable_conv_2_normal_left2_4
# 323 separable_conv_2_normal_right2_4
# 324 separable_conv_2_normal_left5_4
# 325 separable_conv_2_bn_normal_left1_4
# 326 separable_conv_2_bn_normal_right1_4
# 327 separable_conv_2_bn_normal_left2_4
# 328 separable_conv_2_bn_normal_right2_4
# 329 normal_left3_4
# 330 normal_left4_4
# 331 normal_right4_4
# 332 separable_conv_2_bn_normal_left5_4
# 333 normal_add_1_4
# 334 normal_add_2_4
# 335 normal_add_3_4
# 336 normal_add_4_4
# 337 normal_add_5_4
# 338 normal_concat_4
# 339 activation_81
# 340 activation_82
# 341 adjust_conv_projection_5
# 342 normal_conv_1_5
# 343 adjust_bn_5
# 344 normal_bn_1_5
# 345 activation_83
# 346 activation_85
# 347 activation_87
# 348 activation_89
# 349 activation_91
# 350 separable_conv_1_normal_left1_5
# 351 separable_conv_1_normal_right1_5
# 352 separable_conv_1_normal_left2_5
# 353 separable_conv_1_normal_right2_5
# 354 separable_conv_1_normal_left5_5
# 355 separable_conv_1_bn_normal_left1_5
# 356 separable_conv_1_bn_normal_right1_5
# 357 separable_conv_1_bn_normal_left2_5
# 358 separable_conv_1_bn_normal_right2_5
# 359 separable_conv_1_bn_normal_left5_5
# 360 activation_84
# 361 activation_86
# 362 activation_88
# 363 activation_90
# 364 activation_92
# 365 separable_conv_2_normal_left1_5
# 366 separable_conv_2_normal_right1_5
# 367 separable_conv_2_normal_left2_5
# 368 separable_conv_2_normal_right2_5
# 369 separable_conv_2_normal_left5_5
# 370 separable_conv_2_bn_normal_left1_5
# 371 separable_conv_2_bn_normal_right1_5
# 372 separable_conv_2_bn_normal_left2_5
# 373 separable_conv_2_bn_normal_right2_5
# 374 normal_left3_5
# 375 normal_left4_5
# 376 normal_right4_5
# 377 separable_conv_2_bn_normal_left5_5
# 378 normal_add_1_5
# 379 normal_add_2_5
# 380 normal_add_3_5
# 381 normal_add_4_5
# 382 normal_add_5_5
# 383 normal_concat_5
# 384 activation_94
# 385 activation_93
# 386 reduction_conv_1_reduce_6
# 387 adjust_conv_projection_reduce_6
# 388 reduction_bn_1_reduce_6
# 389 adjust_bn_reduce_6
# 390 activation_95
# 391 activation_97
# 392 separable_conv_1_pad_reduction_left1_reduce_6
# 393 separable_conv_1_pad_reduction_right1_reduce_6
# 394 separable_conv_1_reduction_left1_reduce_6
# 395 separable_conv_1_reduction_right1_reduce_6
# 396 separable_conv_1_bn_reduction_left1_reduce_6
# 397 separable_conv_1_bn_reduction_right1_reduce_6
# 398 activation_96
# 399 activation_98
# 400 separable_conv_2_reduction_left1_reduce_6
# 401 separable_conv_2_reduction_right1_reduce_6
# 402 activation_99
# 403 separable_conv_2_bn_reduction_left1_reduce_6
# 404 separable_conv_2_bn_reduction_right1_reduce_6
# 405 separable_conv_1_pad_reduction_right2_reduce_6
# 406 activation_101
# 407 reduction_add_1_reduce_6
# 408 separable_conv_1_reduction_right2_reduce_6
# 409 separable_conv_1_pad_reduction_right3_reduce_6
# 410 activation_103
# 411 separable_conv_1_bn_reduction_right2_reduce_6
# 412 separable_conv_1_reduction_right3_reduce_6
# 413 separable_conv_1_reduction_left4_reduce_6
# 414 activation_100
# 415 separable_conv_1_bn_reduction_right3_reduce_6
# 416 separable_conv_1_bn_reduction_left4_reduce_6
# 417 reduction_pad_1_reduce_6
# 418 separable_conv_2_reduction_right2_reduce_6
# 419 activation_102
# 420 activation_104
# 421 reduction_left2_reduce_6
# 422 separable_conv_2_bn_reduction_right2_reduce_6
# 423 separable_conv_2_reduction_right3_reduce_6
# 424 separable_conv_2_reduction_left4_reduce_6
# 425 adjust_relu_1_7
# 426 reduction_add_2_reduce_6
# 427 reduction_left3_reduce_6
# 428 separable_conv_2_bn_reduction_right3_reduce_6
# 429 reduction_left4_reduce_6
# 430 separable_conv_2_bn_reduction_left4_reduce_6
# 431 reduction_right5_reduce_6
# 432 zero_padding2d_2
# 433 reduction_add3_reduce_6
# 434 add_2
# 435 reduction_add4_reduce_6
# 436 cropping2d_2
# 437 reduction_concat_reduce_6
# 438 adjust_avg_pool_1_7
# 439 adjust_avg_pool_2_7
# 440 adjust_conv_1_7
# 441 adjust_conv_2_7
# 442 activation_105
# 443 concatenate_2
# 444 normal_conv_1_7
# 445 adjust_bn_7
# 446 normal_bn_1_7
# 447 activation_106
# 448 activation_108
# 449 activation_110
# 450 activation_112
# 451 activation_114
# 452 separable_conv_1_normal_left1_7
# 453 separable_conv_1_normal_right1_7
# 454 separable_conv_1_normal_left2_7
# 455 separable_conv_1_normal_right2_7
# 456 separable_conv_1_normal_left5_7
# 457 separable_conv_1_bn_normal_left1_7
# 458 separable_conv_1_bn_normal_right1_7
# 459 separable_conv_1_bn_normal_left2_7
# 460 separable_conv_1_bn_normal_right2_7
# 461 separable_conv_1_bn_normal_left5_7
# 462 activation_107
# 463 activation_109
# 464 activation_111
# 465 activation_113
# 466 activation_115
# 467 separable_conv_2_normal_left1_7
# 468 separable_conv_2_normal_right1_7
# 469 separable_conv_2_normal_left2_7
# 470 separable_conv_2_normal_right2_7
# 471 separable_conv_2_normal_left5_7
# 472 separable_conv_2_bn_normal_left1_7
# 473 separable_conv_2_bn_normal_right1_7
# 474 separable_conv_2_bn_normal_left2_7
# 475 separable_conv_2_bn_normal_right2_7
# 476 normal_left3_7
# 477 normal_left4_7
# 478 normal_right4_7
# 479 separable_conv_2_bn_normal_left5_7
# 480 normal_add_1_7
# 481 normal_add_2_7
# 482 normal_add_3_7
# 483 normal_add_4_7
# 484 normal_add_5_7
# 485 normal_concat_7
# 486 activation_116
# 487 activation_117
# 488 adjust_conv_projection_8
# 489 normal_conv_1_8
# 490 adjust_bn_8
# 491 normal_bn_1_8
# 492 activation_118
# 493 activation_120
# 494 activation_122
# 495 activation_124
# 496 activation_126
# 497 separable_conv_1_normal_left1_8
# 498 separable_conv_1_normal_right1_8
# 499 separable_conv_1_normal_left2_8
# 500 separable_conv_1_normal_right2_8
# 501 separable_conv_1_normal_left5_8
# 502 separable_conv_1_bn_normal_left1_8
# 503 separable_conv_1_bn_normal_right1_8
# 504 separable_conv_1_bn_normal_left2_8
# 505 separable_conv_1_bn_normal_right2_8
# 506 separable_conv_1_bn_normal_left5_8
# 507 activation_119
# 508 activation_121
# 509 activation_123
# 510 activation_125
# 511 activation_127
# 512 separable_conv_2_normal_left1_8
# 513 separable_conv_2_normal_right1_8
# 514 separable_conv_2_normal_left2_8
# 515 separable_conv_2_normal_right2_8
# 516 separable_conv_2_normal_left5_8
# 517 separable_conv_2_bn_normal_left1_8
# 518 separable_conv_2_bn_normal_right1_8
# 519 separable_conv_2_bn_normal_left2_8
# 520 separable_conv_2_bn_normal_right2_8
# 521 normal_left3_8
# 522 normal_left4_8
# 523 normal_right4_8
# 524 separable_conv_2_bn_normal_left5_8
# 525 normal_add_1_8
# 526 normal_add_2_8
# 527 normal_add_3_8
# 528 normal_add_4_8
# 529 normal_add_5_8
# 530 normal_concat_8
# 531 activation_128
# 532 activation_129
# 533 adjust_conv_projection_9
# 534 normal_conv_1_9
# 535 adjust_bn_9
# 536 normal_bn_1_9
# 537 activation_130
# 538 activation_132
# 539 activation_134
# 540 activation_136
# 541 activation_138
# 542 separable_conv_1_normal_left1_9
# 543 separable_conv_1_normal_right1_9
# 544 separable_conv_1_normal_left2_9
# 545 separable_conv_1_normal_right2_9
# 546 separable_conv_1_normal_left5_9
# 547 separable_conv_1_bn_normal_left1_9
# 548 separable_conv_1_bn_normal_right1_9
# 549 separable_conv_1_bn_normal_left2_9
# 550 separable_conv_1_bn_normal_right2_9
# 551 separable_conv_1_bn_normal_left5_9
# 552 activation_131
# 553 activation_133
# 554 activation_135
# 555 activation_137
# 556 activation_139
# 557 separable_conv_2_normal_left1_9
# 558 separable_conv_2_normal_right1_9
# 559 separable_conv_2_normal_left2_9
# 560 separable_conv_2_normal_right2_9
# 561 separable_conv_2_normal_left5_9
# 562 separable_conv_2_bn_normal_left1_9
# 563 separable_conv_2_bn_normal_right1_9
# 564 separable_conv_2_bn_normal_left2_9
# 565 separable_conv_2_bn_normal_right2_9
# 566 normal_left3_9
# 567 normal_left4_9
# 568 normal_right4_9
# 569 separable_conv_2_bn_normal_left5_9
# 570 normal_add_1_9
# 571 normal_add_2_9
# 572 normal_add_3_9
# 573 normal_add_4_9
# 574 normal_add_5_9
# 575 normal_concat_9
# 576 activation_140
# 577 activation_141
# 578 adjust_conv_projection_10
# 579 normal_conv_1_10
# 580 adjust_bn_10
# 581 normal_bn_1_10
# 582 activation_142
# 583 activation_144
# 584 activation_146
# 585 activation_148
# 586 activation_150
# 587 separable_conv_1_normal_left1_10
# 588 separable_conv_1_normal_right1_10
# 589 separable_conv_1_normal_left2_10
# 590 separable_conv_1_normal_right2_10
# 591 separable_conv_1_normal_left5_10
# 592 separable_conv_1_bn_normal_left1_10
# 593 separable_conv_1_bn_normal_right1_10
# 594 separable_conv_1_bn_normal_left2_10
# 595 separable_conv_1_bn_normal_right2_10
# 596 separable_conv_1_bn_normal_left5_10
# 597 activation_143
# 598 activation_145
# 599 activation_147
# 600 activation_149
# 601 activation_151
# 602 separable_conv_2_normal_left1_10
# 603 separable_conv_2_normal_right1_10
# 604 separable_conv_2_normal_left2_10
# 605 separable_conv_2_normal_right2_10
# 606 separable_conv_2_normal_left5_10
# 607 separable_conv_2_bn_normal_left1_10
# 608 separable_conv_2_bn_normal_right1_10
# 609 separable_conv_2_bn_normal_left2_10
# 610 separable_conv_2_bn_normal_right2_10
# 611 normal_left3_10
# 612 normal_left4_10
# 613 normal_right4_10
# 614 separable_conv_2_bn_normal_left5_10
# 615 normal_add_1_10
# 616 normal_add_2_10
# 617 normal_add_3_10
# 618 normal_add_4_10
# 619 normal_add_5_10
# 620 normal_concat_10
# 621 activation_152
# 622 activation_153
# 623 adjust_conv_projection_11
# 624 normal_conv_1_11
# 625 adjust_bn_11
# 626 normal_bn_1_11
# 627 activation_154
# 628 activation_156
# 629 activation_158
# 630 activation_160
# 631 activation_162
# 632 separable_conv_1_normal_left1_11
# 633 separable_conv_1_normal_right1_11
# 634 separable_conv_1_normal_left2_11
# 635 separable_conv_1_normal_right2_11
# 636 separable_conv_1_normal_left5_11
# 637 separable_conv_1_bn_normal_left1_11
# 638 separable_conv_1_bn_normal_right1_11
# 639 separable_conv_1_bn_normal_left2_11
# 640 separable_conv_1_bn_normal_right2_11
# 641 separable_conv_1_bn_normal_left5_11
# 642 activation_155
# 643 activation_157
# 644 activation_159
# 645 activation_161
# 646 activation_163
# 647 separable_conv_2_normal_left1_11
# 648 separable_conv_2_normal_right1_11
# 649 separable_conv_2_normal_left2_11
# 650 separable_conv_2_normal_right2_11
# 651 separable_conv_2_normal_left5_11
# 652 separable_conv_2_bn_normal_left1_11
# 653 separable_conv_2_bn_normal_right1_11
# 654 separable_conv_2_bn_normal_left2_11
# 655 separable_conv_2_bn_normal_right2_11
# 656 normal_left3_11
# 657 normal_left4_11
# 658 normal_right4_11
# 659 separable_conv_2_bn_normal_left5_11
# 660 normal_add_1_11
# 661 normal_add_2_11
# 662 normal_add_3_11
# 663 normal_add_4_11
# 664 normal_add_5_11
# 665 normal_concat_11
# 666 activation_164
# 667 activation_165
# 668 adjust_conv_projection_12
# 669 normal_conv_1_12
# 670 adjust_bn_12
# 671 normal_bn_1_12
# 672 activation_166
# 673 activation_168
# 674 activation_170
# 675 activation_172
# 676 activation_174
# 677 separable_conv_1_normal_left1_12
# 678 separable_conv_1_normal_right1_12
# 679 separable_conv_1_normal_left2_12
# 680 separable_conv_1_normal_right2_12
# 681 separable_conv_1_normal_left5_12
# 682 separable_conv_1_bn_normal_left1_12
# 683 separable_conv_1_bn_normal_right1_12
# 684 separable_conv_1_bn_normal_left2_12
# 685 separable_conv_1_bn_normal_right2_12
# 686 separable_conv_1_bn_normal_left5_12
# 687 activation_167
# 688 activation_169
# 689 activation_171
# 690 activation_173
# 691 activation_175
# 692 separable_conv_2_normal_left1_12
# 693 separable_conv_2_normal_right1_12
# 694 separable_conv_2_normal_left2_12
# 695 separable_conv_2_normal_right2_12
# 696 separable_conv_2_normal_left5_12
# 697 separable_conv_2_bn_normal_left1_12
# 698 separable_conv_2_bn_normal_right1_12
# 699 separable_conv_2_bn_normal_left2_12
# 700 separable_conv_2_bn_normal_right2_12
# 701 normal_left3_12
# 702 normal_left4_12
# 703 normal_right4_12
# 704 separable_conv_2_bn_normal_left5_12
# 705 normal_add_1_12
# 706 normal_add_2_12
# 707 normal_add_3_12
# 708 normal_add_4_12
# 709 normal_add_5_12
# 710 normal_concat_12
# 711 activation_177
# 712 activation_176
# 713 reduction_conv_1_reduce_12
# 714 adjust_conv_projection_reduce_12
# 715 reduction_bn_1_reduce_12
# 716 adjust_bn_reduce_12
# 717 activation_178
# 718 activation_180
# 719 separable_conv_1_pad_reduction_left1_reduce_12
# 720 separable_conv_1_pad_reduction_right1_reduce_12
# 721 separable_conv_1_reduction_left1_reduce_12
# 722 separable_conv_1_reduction_right1_reduce_12
# 723 separable_conv_1_bn_reduction_left1_reduce_12
# 724 separable_conv_1_bn_reduction_right1_reduce_12
# 725 activation_179
# 726 activation_181
# 727 separable_conv_2_reduction_left1_reduce_12
# 728 separable_conv_2_reduction_right1_reduce_12
# 729 activation_182
# 730 separable_conv_2_bn_reduction_left1_reduce_12
# 731 separable_conv_2_bn_reduction_right1_reduce_12
# 732 separable_conv_1_pad_reduction_right2_reduce_12
# 733 activation_184
# 734 reduction_add_1_reduce_12
# 735 separable_conv_1_reduction_right2_reduce_12
# 736 separable_conv_1_pad_reduction_right3_reduce_12
# 737 activation_186
# 738 separable_conv_1_bn_reduction_right2_reduce_12
# 739 separable_conv_1_reduction_right3_reduce_12
# 740 separable_conv_1_reduction_left4_reduce_12
# 741 activation_183
# 742 separable_conv_1_bn_reduction_right3_reduce_12
# 743 separable_conv_1_bn_reduction_left4_reduce_12
# 744 reduction_pad_1_reduce_12
# 745 separable_conv_2_reduction_right2_reduce_12
# 746 activation_185
# 747 activation_187
# 748 reduction_left2_reduce_12
# 749 separable_conv_2_bn_reduction_right2_reduce_12
# 750 separable_conv_2_reduction_right3_reduce_12
# 751 separable_conv_2_reduction_left4_reduce_12
# 752 adjust_relu_1_13
# 753 reduction_add_2_reduce_12
# 754 reduction_left3_reduce_12
# 755 separable_conv_2_bn_reduction_right3_reduce_12
# 756 reduction_left4_reduce_12
# 757 separable_conv_2_bn_reduction_left4_reduce_12
# 758 reduction_right5_reduce_12
# 759 zero_padding2d_3
# 760 reduction_add3_reduce_12
# 761 add_3
# 762 reduction_add4_reduce_12
# 763 cropping2d_3
# 764 reduction_concat_reduce_12
# 765 adjust_avg_pool_1_13
# 766 adjust_avg_pool_2_13
# 767 adjust_conv_1_13
# 768 adjust_conv_2_13
# 769 activation_188
# 770 concatenate_3
# 771 normal_conv_1_13
# 772 adjust_bn_13
# 773 normal_bn_1_13
# 774 activation_189
# 775 activation_191
# 776 activation_193
# 777 activation_195
# 778 activation_197
# 779 separable_conv_1_normal_left1_13
# 780 separable_conv_1_normal_right1_13
# 781 separable_conv_1_normal_left2_13
# 782 separable_conv_1_normal_right2_13
# 783 separable_conv_1_normal_left5_13
# 784 separable_conv_1_bn_normal_left1_13
# 785 separable_conv_1_bn_normal_right1_13
# 786 separable_conv_1_bn_normal_left2_13
# 787 separable_conv_1_bn_normal_right2_13
# 788 separable_conv_1_bn_normal_left5_13
# 789 activation_190
# 790 activation_192
# 791 activation_194
# 792 activation_196
# 793 activation_198
# 794 separable_conv_2_normal_left1_13
# 795 separable_conv_2_normal_right1_13
# 796 separable_conv_2_normal_left2_13
# 797 separable_conv_2_normal_right2_13
# 798 separable_conv_2_normal_left5_13
# 799 separable_conv_2_bn_normal_left1_13
# 800 separable_conv_2_bn_normal_right1_13
# 801 separable_conv_2_bn_normal_left2_13
# 802 separable_conv_2_bn_normal_right2_13
# 803 normal_left3_13
# 804 normal_left4_13
# 805 normal_right4_13
# 806 separable_conv_2_bn_normal_left5_13
# 807 normal_add_1_13
# 808 normal_add_2_13
# 809 normal_add_3_13
# 810 normal_add_4_13
# 811 normal_add_5_13
# 812 normal_concat_13
# 813 activation_199
# 814 activation_200
# 815 adjust_conv_projection_14
# 816 normal_conv_1_14
# 817 adjust_bn_14
# 818 normal_bn_1_14
# 819 activation_201
# 820 activation_203
# 821 activation_205
# 822 activation_207
# 823 activation_209
# 824 separable_conv_1_normal_left1_14
# 825 separable_conv_1_normal_right1_14
# 826 separable_conv_1_normal_left2_14
# 827 separable_conv_1_normal_right2_14
# 828 separable_conv_1_normal_left5_14
# 829 separable_conv_1_bn_normal_left1_14
# 830 separable_conv_1_bn_normal_right1_14
# 831 separable_conv_1_bn_normal_left2_14
# 832 separable_conv_1_bn_normal_right2_14
# 833 separable_conv_1_bn_normal_left5_14
# 834 activation_202
# 835 activation_204
# 836 activation_206
# 837 activation_208
# 838 activation_210
# 839 separable_conv_2_normal_left1_14
# 840 separable_conv_2_normal_right1_14
# 841 separable_conv_2_normal_left2_14
# 842 separable_conv_2_normal_right2_14
# 843 separable_conv_2_normal_left5_14
# 844 separable_conv_2_bn_normal_left1_14
# 845 separable_conv_2_bn_normal_right1_14
# 846 separable_conv_2_bn_normal_left2_14
# 847 separable_conv_2_bn_normal_right2_14
# 848 normal_left3_14
# 849 normal_left4_14
# 850 normal_right4_14
# 851 separable_conv_2_bn_normal_left5_14
# 852 normal_add_1_14
# 853 normal_add_2_14
# 854 normal_add_3_14
# 855 normal_add_4_14
# 856 normal_add_5_14
# 857 normal_concat_14
# 858 activation_211
# 859 activation_212
# 860 adjust_conv_projection_15
# 861 normal_conv_1_15
# 862 adjust_bn_15
# 863 normal_bn_1_15
# 864 activation_213
# 865 activation_215
# 866 activation_217
# 867 activation_219
# 868 activation_221
# 869 separable_conv_1_normal_left1_15
# 870 separable_conv_1_normal_right1_15
# 871 separable_conv_1_normal_left2_15
# 872 separable_conv_1_normal_right2_15
# 873 separable_conv_1_normal_left5_15
# 874 separable_conv_1_bn_normal_left1_15
# 875 separable_conv_1_bn_normal_right1_15
# 876 separable_conv_1_bn_normal_left2_15
# 877 separable_conv_1_bn_normal_right2_15
# 878 separable_conv_1_bn_normal_left5_15
# 879 activation_214
# 880 activation_216
# 881 activation_218
# 882 activation_220
# 883 activation_222
# 884 separable_conv_2_normal_left1_15
# 885 separable_conv_2_normal_right1_15
# 886 separable_conv_2_normal_left2_15
# 887 separable_conv_2_normal_right2_15
# 888 separable_conv_2_normal_left5_15
# 889 separable_conv_2_bn_normal_left1_15
# 890 separable_conv_2_bn_normal_right1_15
# 891 separable_conv_2_bn_normal_left2_15
# 892 separable_conv_2_bn_normal_right2_15
# 893 normal_left3_15
# 894 normal_left4_15
# 895 normal_right4_15
# 896 separable_conv_2_bn_normal_left5_15
# 897 normal_add_1_15
# 898 normal_add_2_15
# 899 normal_add_3_15
# 900 normal_add_4_15
# 901 normal_add_5_15
# 902 normal_concat_15
# 903 activation_223
# 904 activation_224
# 905 adjust_conv_projection_16
# 906 normal_conv_1_16
# 907 adjust_bn_16
# 908 normal_bn_1_16
# 909 activation_225
# 910 activation_227
# 911 activation_229
# 912 activation_231
# 913 activation_233
# 914 separable_conv_1_normal_left1_16
# 915 separable_conv_1_normal_right1_16
# 916 separable_conv_1_normal_left2_16
# 917 separable_conv_1_normal_right2_16
# 918 separable_conv_1_normal_left5_16
# 919 separable_conv_1_bn_normal_left1_16
# 920 separable_conv_1_bn_normal_right1_16
# 921 separable_conv_1_bn_normal_left2_16
# 922 separable_conv_1_bn_normal_right2_16
# 923 separable_conv_1_bn_normal_left5_16
# 924 activation_226
# 925 activation_228
# 926 activation_230
# 927 activation_232
# 928 activation_234
# 929 separable_conv_2_normal_left1_16
# 930 separable_conv_2_normal_right1_16
# 931 separable_conv_2_normal_left2_16
# 932 separable_conv_2_normal_right2_16
# 933 separable_conv_2_normal_left5_16
# 934 separable_conv_2_bn_normal_left1_16
# 935 separable_conv_2_bn_normal_right1_16
# 936 separable_conv_2_bn_normal_left2_16
# 937 separable_conv_2_bn_normal_right2_16
# 938 normal_left3_16
# 939 normal_left4_16
# 940 normal_right4_16
# 941 separable_conv_2_bn_normal_left5_16
# 942 normal_add_1_16
# 943 normal_add_2_16
# 944 normal_add_3_16
# 945 normal_add_4_16
# 946 normal_add_5_16
# 947 normal_concat_16
# 948 activation_235
# 949 activation_236
# 950 adjust_conv_projection_17
# 951 normal_conv_1_17
# 952 adjust_bn_17
# 953 normal_bn_1_17
# 954 activation_237
# 955 activation_239
# 956 activation_241
# 957 activation_243
# 958 activation_245
# 959 separable_conv_1_normal_left1_17
# 960 separable_conv_1_normal_right1_17
# 961 separable_conv_1_normal_left2_17
# 962 separable_conv_1_normal_right2_17
# 963 separable_conv_1_normal_left5_17
# 964 separable_conv_1_bn_normal_left1_17
# 965 separable_conv_1_bn_normal_right1_17
# 966 separable_conv_1_bn_normal_left2_17
# 967 separable_conv_1_bn_normal_right2_17
# 968 separable_conv_1_bn_normal_left5_17
# 969 activation_238
# 970 activation_240
# 971 activation_242
# 972 activation_244
# 973 activation_246
# 974 separable_conv_2_normal_left1_17
# 975 separable_conv_2_normal_right1_17
# 976 separable_conv_2_normal_left2_17
# 977 separable_conv_2_normal_right2_17
# 978 separable_conv_2_normal_left5_17
# 979 separable_conv_2_bn_normal_left1_17
# 980 separable_conv_2_bn_normal_right1_17
# 981 separable_conv_2_bn_normal_left2_17
# 982 separable_conv_2_bn_normal_right2_17
# 983 normal_left3_17
# 984 normal_left4_17
# 985 normal_right4_17
# 986 separable_conv_2_bn_normal_left5_17
# 987 normal_add_1_17
# 988 normal_add_2_17
# 989 normal_add_3_17
# 990 normal_add_4_17
# 991 normal_add_5_17
# 992 normal_concat_17
# 993 activation_247
# 994 activation_248
# 995 adjust_conv_projection_18
# 996 normal_conv_1_18
# 997 adjust_bn_18
# 998 normal_bn_1_18
# 999 activation_249
# 1000 activation_251
# 1001 activation_253
# 1002 activation_255
# 1003 activation_257
# 1004 separable_conv_1_normal_left1_18
# 1005 separable_conv_1_normal_right1_18
# 1006 separable_conv_1_normal_left2_18
# 1007 separable_conv_1_normal_right2_18
# 1008 separable_conv_1_normal_left5_18
# 1009 separable_conv_1_bn_normal_left1_18
# 1010 separable_conv_1_bn_normal_right1_18
# 1011 separable_conv_1_bn_normal_left2_18
# 1012 separable_conv_1_bn_normal_right2_18
# 1013 separable_conv_1_bn_normal_left5_18
# 1014 activation_250
# 1015 activation_252
# 1016 activation_254
# 1017 activation_256
# 1018 activation_258
# 1019 separable_conv_2_normal_left1_18
# 1020 separable_conv_2_normal_right1_18
# 1021 separable_conv_2_normal_left2_18
# 1022 separable_conv_2_normal_right2_18
# 1023 separable_conv_2_normal_left5_18
# 1024 separable_conv_2_bn_normal_left1_18
# 1025 separable_conv_2_bn_normal_right1_18
# 1026 separable_conv_2_bn_normal_left2_18
# 1027 separable_conv_2_bn_normal_right2_18
# 1028 normal_left3_18
# 1029 normal_left4_18
# 1030 normal_right4_18
# 1031 separable_conv_2_bn_normal_left5_18
# 1032 normal_add_1_18
# 1033 normal_add_2_18
# 1034 normal_add_3_18
# 1035 normal_add_4_18
# 1036 normal_add_5_18
# 1037 normal_concat_18
# 1038 activation_259
# 1039 global_average_pooling2d
# 1040 dense
# 1041 dense_1
# 1042 dense_2
# 1043 dense_3
# Found 1086 images belonging to 2 classes.
# Found 724 images belonging to 2 classes.
# Epoch 1/3
# 33/33 [==============================] - 47s 1s/step - loss: 0.9889 - accuracy: 0.4905 - val_loss: 0.7133 - val_accuracy: 0.5085
# Epoch 2/3
# 33/33 [==============================] - 42s 1s/step - loss: 0.7036 - accuracy: 0.4915 - val_loss: 0.7111 - val_accuracy: 0.4787
# Epoch 3/3
# 33/33 [==============================] - 43s 1s/step - loss: 0.6915 - accuracy: 0.5550 - val_loss: 0.7055 - val_accuracy: 0.4517

# %%
#above tips for the graph function: list range has to be 1 to #epochs+1
#np.arrange has to be 0, #epochs +1 and no clue what the last number is.

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic CNN Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,4))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 4, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 4, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
# this cell is to evaluate loss and accuracy on an external test set

model.evaluate(val, verbose=1, sample_weight=None, steps=step_size_val, callbacks=None, max_queue_size=10, workers=1, use_multiprocessing=False)
# Out:
# 22/22 [==============================] - 12s 541ms/step - loss: 0.6990 - accuracy: 0.4844
# [0.6989785432815552, 0.484375]

# %%
# this cell is to predict smaller numbers of images and so... it returns an array which I havent figured out yet...

yhat = model.predict(val, verbose=1, steps=step_size_val, callbacks=None, max_queue_size=10, workers=1, use_multiprocessing=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-83ab58f10cea> in <module>()
#       1
# ----> 2 yhat = model.predict(val, verbose=1, steps=step_size_val, callbacks=None, max_queue_size=10, workers=1, use_multiprocessing=False)
#       3
#       4
#
# TypeError: predict() got an unexpected keyword argument 'verbose'

# %%
# make predictions on your choice of numbers in dataset, just change the range https://machinelearningmastery.com/how-to-make-classification-and-regression-predictions-for-deep-learning-models-in-keras/

	
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_blobs
# create the inputs and outputs
X, y = make_blobs(n_samples=5000, centers=2, n_features=2, random_state=2)
# define model
model = LogisticRegression(solver='lbfgs')
# fit model
model.fit(X, y)
# make predictions on the entire training dataset
yhat = model.predict(X)
# connect predictions with outputs
for i in range(5000):
  print (X[i], yhat[i])
# Out:
# Streaming output truncated to the last 5000 lines.
# [-1.87306867 -9.16987138] 0
# [ -1.45927789 -10.59328108] 0
# [-1.18197081 -9.89426559] 0
# [ 1.16903784 -1.97792171] 1
# [-1.37606023 -8.8505038 ] 0
# [-1.88324275 -9.43951773] 0
# [-0.83384511 -1.80809682] 1
# [ 1.78701319 -1.67624807] 1
# [ -1.34173704 -10.43437252] 0
# [ 0.11699858 -1.85026817] 1
# [-2.80948505 -9.61623644] 0
# [ 8.6674497e-03 -9.3465499e+00] 0
# [ -0.69715683 -10.69283391] 0
# [ 0.27899228 -0.42315602] 1
# [-2.10923725 -9.39376515] 0
# [ 1.49922646 -0.70803027] 1
# [-0.52594098 -9.44555008] 0
# [ 0.61984697 -8.2000112 ] 0
# [-0.22611544 -1.2098058 ] 1
# [ 1.76297632 -2.08037062] 1
# [ 2.69009124 -2.8363177 ] 1
# [ 1.36210612 -1.23880907] 1
# [ 0.93007415 -0.17491265] 1
# [ -1.00734732 -11.2823404 ] 0
# [ 0.77293004 -1.57267336] 1
# [-2.92947737 -8.09826425] 0
# [ 0.62070232 -1.07191387] 1
# [-0.07064947 -2.73096133] 1
# [-1.42969331 -9.72391596] 0
# [-1.0155792  -8.75561304] 0
# [-0.19341293 -1.52738723] 1
# [ 0.76666972 -1.00240879] 1
# [ -0.1397782  -10.35003007] 0
# [ 1.75400084 -1.82071972] 1
# [ 1.13176706 -9.39425203] 0
# [-1.73872662 -0.8624052 ] 1
# [ -0.29817563 -10.34198812] 0
# [ 1.19027412 -0.94570651] 1
# [ -0.95303492 -10.93683481] 0
# [ 0.50236233 -2.891425  ] 1
# [-1.47694751 -9.77358693] 0
# [ -0.17095868 -11.24639309] 0
# [-2.03562658 -9.71764941] 0
# [ -1.68179015 -10.2089463 ] 0
# [ 1.66691989 -0.9903331 ] 1
# [-2.70670214 -9.80900354] 0
# [ 2.0317282  -1.77122952] 1
# [ 0.10688816 -9.68737975] 0
# [ 0.49170966 -2.81142404] 1
# [-1.55721725 -9.25394366] 0
# [-0.51734264 -8.47174973] 0
# [ 1.74432721 -1.68406603] 1
# [ 2.12565084 -1.24302369] 1
# [-1.77512761 -9.14396065] 0
# [ 2.10527199 -2.2867097 ] 1
# [-3.32596864 -8.9869815 ] 0
# [ 0.41731164 -2.26899344] 1
# [-0.01786127 -9.36097603] 0
# [ -1.95437065 -11.78961527] 0
# [ -1.73741079 -10.21711589] 0
# [ -1.26099986 -10.05856917] 0
# [ -1.40485168 -11.21142558] 0
# [-1.0849427  -8.35741562] 0
# [1.06017447 0.80254493] 1
# [-0.13300201 -9.38591838] 0
# [  0.57226744 -10.67077131] 0
# [ -3.6932403  -10.19417997] 0
# [-2.69468061 -9.93990355] 0
# [0.17684183 0.66594555] 1
# [-0.1809548  -1.62522652] 1
# [-0.03084617 -8.27466429] 0
# [ 2.06744283 -0.60242517] 1
# [ 1.75776364 -2.81337011] 1
# [ 0.78186456 -0.42181498] 1
# [ 0.13970264 -1.73313357] 1
# [ 0.80946354 -0.23061864] 1
# [-1.25406683 -8.83885182] 0
# [-0.38354752 -0.69098201] 1
# [ 2.05660925 -2.80117057] 1
# [ -1.4789955  -10.34073588] 0
# [ 0.12442158 -2.17173765] 1
# [ 0.38376564 -1.78553978] 1
# [-1.12890478 -8.71640588] 0
# [ 1.24057155 -1.21394644] 1
# [-1.46824735 -9.25551429] 0
# [ -1.95354126 -10.32548684] 0
# [ 0.90847142 -1.46177838] 1
# [-2.33760709 -9.41104148] 0
# [0.72103402 0.87807608] 1
# [-1.95927385 -8.11634602] 0
# [-0.39975304 -0.19617979] 1
# [ 1.44871766 -1.30428757] 1
# [-0.5142345 -9.7477121] 0
# [-0.62530456 -8.75543656] 0
# [ 1.0424699  -2.00030262] 1
# [-2.61720534 -7.79139826] 0
# [-0.76057098 -0.50398844] 1
# [-0.40441303 -9.49225101] 0
# [ 1.88127924 -0.86437768] 1
# [-2.26285762 -7.39479264] 0
# [-0.30951571 -0.76759808] 1
# [-0.96416533 -9.67464586] 0
# [ -1.76008707 -10.50112446] 0
# [-0.20854591 -2.69779047] 1
# [-0.16221522 -9.75571745] 0
# [ 0.79927469 -9.993969  ] 0
# [ 0.76965651 -2.05975635] 1
# [ -1.2096332  -11.18443109] 0
# [-1.50146491 -9.84043057] 0
# [-0.23662956 -1.25363197] 1
# [-0.20052929 -0.3628128 ] 1
# [ 1.53301923 -1.37856713] 1
# [-0.43950343 -0.84971028] 1
# [ 0.0662583  -1.28312998] 1
# [ -0.46676584 -10.07012393] 0
# [ -1.19410832 -10.08200385] 0
# [-0.32744122 -9.86519989] 0
# [ 0.77315943 -9.80610825] 0
# [-0.72306502 -6.39162536] 0
# [-1.85786996 -8.58974687] 0
# [ 0.19897357 -2.55403084] 1
# [-1.57940795 -9.53777893] 0
# [-1.47330593 -9.27947758] 0
# [-0.03598989 -2.7636862 ] 1
# [-2.0485718 -8.0224759] 0
# [-0.33884293 -0.76141074] 1
# [ 0.18726232 -2.9444203 ] 1
# [-0.31921828 -9.66386062] 0
# [ 0.38224786 -7.75071048] 0
# [-0.45796209 -8.71276424] 0
# [-0.85150188 -0.37095507] 1
# [ 1.38300889 -2.41151626] 1
# [-1.30332337 -9.30589985] 0
# [0.95468417 0.04884654] 1
# [-1.1991302  -8.59916663] 0
# [ 1.02916121 -2.87620338] 1
# [ 1.22033844 -1.50691903] 1
# [ -3.4233718  -11.34137604] 0
# [ 0.06074865 -2.64330301] 1
# [ 2.51706403 -1.62659233] 1
# [-1.05363779 -8.95682333] 0
# [ 1.35894986 -0.46777447] 1
# [-2.4311049  -9.90799783] 0
# [ 0.7959579  -2.55009936] 1
# [-1.03747601 -9.52922247] 0
# [ 2.13697461 -1.84647901] 1
# [ 1.40200415 -2.18122793] 1
# [-0.95498085 -9.32721723] 0
# [ 0.38819578 -1.01927674] 1
# [ 1.5266073  -2.52736854] 1
# [-1.2823084  -9.62076725] 0
# [-0.60476024 -0.38853552] 1
# [-0.76549338 -8.77810058] 0
# [ 0.59807124 -1.17615964] 1
# [-1.74020499 -1.43225899] 1
# [ 0.48042566 -1.19711758] 1
# [ -1.23398353 -10.33191416] 0
# [ 1.23777043 -1.78704305] 1
# [ 1.08172344 -1.4078124 ] 1
# [-1.27807486 -9.73570878] 0
# [ -0.93878127 -10.90427174] 0
# [-2.86017148 -9.30719168] 0
# [ -0.83536566 -10.91376664] 0
# [  1.1003825  -10.35705669] 0
# [ 0.12704037 -1.52861433] 1
# [-1.36234733 -9.78614195] 0
# [ 0.15091987 -2.55192573] 1
# [ 0.33693041 -0.71564818] 1
# [ 0.21419308 -9.11291436] 0
# [-0.39950856 -9.26594311] 0
# [ 0.45676119 -0.4156641 ] 1
# [-0.14153752 -0.21514668] 1
# [ 0.88995904 -2.54616437] 1
# [ 1.20723636 -0.21283781] 1
# [ 0.81867412 -1.38086907] 1
# [ -2.5997531 -10.610272 ] 0
# [-2.57239205 -8.31822442] 0
# [ 1.32910196 -0.89885475] 1
# [-0.19961603  0.08472232] 1
# [ 0.49563457 -0.28184991] 1
# [-0.46343426 -1.05765964] 1
# [-0.07589191 -8.8980521 ] 0
# [-1.48627221 -9.42210777] 0
# [-1.6912113  -9.58856416] 0
# [-0.40226451 -0.94408644] 1
# [ 1.12358696 -2.78942822] 1
# [ 3.43722337 -0.73531933] 1
# [-0.19856381 -9.01498914] 0
# [ 0.01631419 -1.43963977] 1
# [-0.50474587 -0.68031073] 1
# [ -1.17015094 -11.39499858] 0
# [ 2.24849834 -1.27023734] 1
# [ 0.70448848 -1.59393583] 1
# [ -0.99218358 -10.35972379] 0
# [ -0.98848845 -10.36867263] 0
# [ -0.80383386 -11.01956914] 0
# [-1.859779   -9.58371822] 0
# [-1.43693271 -9.61190791] 0
# [-1.2853474  -0.98347626] 1
# [ 1.49499983 -1.21882527] 1
# [-2.03972536 -9.32067701] 0
# [-0.05071715 -2.06184726] 1
# [ 1.63335541 -0.85562708] 1
# [-3.35642276 -9.08417427] 0
# [0.00877767 0.50600679] 1
# [ 0.46247946 -2.06597212] 1
# [ 0.96958489 -8.86255743] 0
# [ 1.24630404 -8.72981815] 0
# [-1.07384002 -9.81045117] 0
# [0.02869094 0.43410605] 1
# [ 0.39077209 -1.67025665] 1
# [ 2.55970142 -3.97056903] 1
# [-0.31360297 -9.19864894] 0
# [ 0.84286644 -1.00324282] 1
# [ 0.36190708 -2.76478511] 1
# [ 0.48335676 -1.47024285] 1
# [ 0.91982633 -1.89854484] 1
# [-0.96742028 -7.41749074] 0
# [ 2.79889683 -0.75584954] 1
# [-0.29558359 -3.14411433] 1
# [1.39439501 0.29227306] 1
# [-0.83497508 -9.83374126] 0
# [ 1.41648629 -0.32921889] 1
# [-2.7417212 -8.6855893] 0
# [-1.24952208 -9.47304259] 0
# [ 0.36735243 -0.31316732] 1
# [-1.61089658 -8.37963433] 0
# [ 0.44942502 -0.14387212] 1
# [-0.79934953 -9.08715874] 0
# [-2.55047528 -9.4560982 ] 0
# [ -0.26566532 -10.8661714 ] 0
# [ -1.5150322  -11.65132567] 0
# [ 0.40201255 -1.532146  ] 1
# [-1.34551164 -8.71535946] 0
# [-1.17856209 -5.34811305] 0
# [-0.66876118 -9.43350477] 0
# [ 2.09004294 -0.99411173] 1
# [0.93793783 0.38466392] 1
# [ -1.66618273 -10.10267545] 0
# [-1.20938071 -9.94643367] 0
# [-1.59361015 -8.71046363] 0
# [-0.19322965 -1.18286466] 1
# [-0.05855741 -1.55037106] 1
# [-1.94162208 -9.33936905] 0
# [ -1.1038559  -10.04051435] 0
# [ -2.4692359  -10.03991117] 0
# [-0.88271539 -9.02110697] 0
# [ 0.09283374 -0.89551233] 1
# [-1.43166734 -9.9543303 ] 0
# [-2.58910896 -2.40666133] 1
# [-2.34772752 -9.95626407] 0
# [ -0.97686752 -10.31135021] 0
# [1.48138212 0.40930119] 1
# [-2.34090099 -8.88980884] 0
# [ 1.50505898 -2.89412761] 1
# [-1.56780567 -9.45141531] 0
# [ 1.47787495 -2.09475825] 1
# [ -1.5799357  -10.38865854] 0
# [ 3.30469972 -0.90732374] 1
# [-1.85148357 -9.1890433 ] 0
# [ 1.27103616 -8.53738552] 0
# [-2.65785989 -8.29542669] 0
# [-2.34319034 -8.94938784] 0
# [ 2.72316672 -0.79474459] 1
# [ -0.76567636 -10.15637497] 0
# [-1.13426188 -9.88158142] 0
# [ 1.45451997 -1.12369068] 1
# [ 0.92644725 -0.82340239] 1
# [-0.94106448 -9.48830286] 0
# [-0.27973607 -9.86256788] 0
# [0.7430581  0.45678191] 1
# [-3.65450464 -9.42295543] 0
# [ -2.64538483 -11.15302185] 0
# [ 1.25089715 -0.89350628] 1
# [ 0.15869018 -1.6743654 ] 1
# [-1.94532908 -9.98885178] 0
# [-1.55924707 -9.06377302] 0
# [ 0.7967749  -0.81500698] 1
# [ 1.54626878 -0.52375998] 1
# [ 0.55523077 -9.04078549] 0
# [-1.42073086 -9.72756312] 0
# [-1.38313998 -1.87446966] 1
# [-2.09900116 -9.81411463] 0
# [ 2.25980521 -0.45432831] 1
# [-0.06434826 -0.84928507] 1
# [ 0.88368261 -1.98179906] 1
# [-0.65564831 -9.3755248 ] 0
# [-0.38110789 -2.5887463 ] 1
# [2.00257039 0.69624548] 1
# [ 0.06321454 -9.22483822] 0
# [-0.04625635 -9.4048811 ] 0
# [-1.1577499  -9.80552773] 0
# [ 0.28329489 -1.51966096] 1
# [-0.10953371 -9.18094088] 0
# [-1.14562208 -9.44617695] 0
# [ -2.07364892 -10.92989109] 0
# [ 2.49519416 -1.50510503] 1
# [ 0.25248873 -1.97140989] 1
# [-1.04132756 -9.23210293] 0
# [ -1.01419384 -10.10626471] 0
# [ 1.47851638 -2.62064216] 1
# [ -0.55722868 -10.55319897] 0
# [ 0.92011511 -2.24942327] 1
# [ 2.17265207 -0.96853003] 1
# [ 0.30780664 -9.65388558] 0
# [ 0.42233317 -2.5492577 ] 1
# [-2.2327116  -7.38370499] 0
# [-0.66866558 -8.09031921] 0
# [  0.16588006 -10.34310583] 0
# [ 0.72917212 -1.94789919] 1
# [  0.51100169 -11.65799028] 0
# [-0.92747528 -0.92118515] 1
# [ 1.31915906 -1.06627341] 1
# [ 2.43885508 -0.65218495] 1
# [ 3.3406893 -0.4384288] 1
# [ 0.62375799 -1.49724633] 1
# [-2.3414677  -9.58999219] 0
# [-0.99084942 -9.08117788] 0
# [ -2.09115114 -10.37542314] 0
# [-3.26347147 -8.19424717] 0
# [ -0.58010976 -10.10091278] 0
# [-0.10467212 -8.26181991] 0
# [-2.31982615 -9.13517817] 0
# [ -0.35939825 -10.58268684] 0
# [-1.14114624 -9.3620252 ] 0
# [0.43963708 0.10465458] 1
# [ 1.6194841  -0.80868467] 1
# [ 0.42922757 -0.47704398] 1
# [ -2.13101603 -10.43060731] 0
# [-1.54026476 -9.85159697] 0
# [-0.32392505 -2.11000331] 1
# [-1.19583789 -9.57030694] 0
# [-0.12185624 -9.58794244] 0
# [-0.14927927 -1.2618029 ] 1
# [-0.61845609 -2.92093472] 1
# [-1.13010119 -9.07267547] 0
# [-0.50890926 -9.59625232] 0
# [-0.24360541 -1.61675345] 1
# [-1.04243844 -8.56193152] 0
# [-1.70769677 -8.83159355] 0
# [-0.57919032 -9.54667772] 0
# [  0.02101847 -10.48278052] 0
# [ -1.74844822 -10.73619567] 0
# [-0.91504844 -8.70739333] 0
# [ -0.70906844 -10.04247396] 0
# [-2.2090509  -8.50144452] 0
# [-1.6639118 -8.2596251] 0
# [-1.32267036 -9.1711825 ] 0
# [  2.0305781  -10.89834278] 0
# [ 2.1441937  -1.31571789] 1
# [ 1.16289553 -1.76285847] 1
# [-1.59712066 -9.2207774 ] 0
# [ 0.65422387 -8.88628633] 0
# [-0.51050756 -1.25402513] 1
# [ -2.7427803  -10.09831983] 0
# [-0.03679779 -8.71322769] 0
# [ 2.62611735 -0.78933021] 1
# [ 0.89008361 -0.55900249] 1
# [ 1.21840254 -1.67781908] 1
# [ 0.28057921 -0.11316723] 1
# [ 0.16266052 -1.01974629] 1
# [ -2.23509836 -10.01864556] 0
# [-0.95008515 -8.7351474 ] 0
# [ 1.83544311 -0.4226893 ] 1
# [ 0.35126304 -1.73944504] 1
# [ 0.34579956 -0.84706198] 1
# [ 0.24544446 -1.67452385] 1
# [ -0.87677257 -10.25474011] 0
# [-0.5496113  -0.10842898] 1
# [-2.19182658 -8.61631345] 0
# [-2.14251885 -9.66599312] 0
# [ 0.40977932 -9.86046315] 0
# [-2.74892385 -9.34855131] 0
# [ 1.83906728 -2.08195371] 1
# [-1.88340269 -9.26825949] 0
# [-0.01795892 -8.65748115] 0
# [ 0.98456909 -0.91825923] 1
# [-1.42869675 -7.84933667] 0
# [-0.68211542 -9.65412546] 0
# [ 1.85132342 -2.1107325 ] 1
# [-2.70131918 -9.63497056] 0
# [-0.58992103 -8.59578386] 0
# [ -1.68148166 -10.23672426] 0
# [ 1.42335952 -1.65558735] 1
# [-0.43067152 -2.05187428] 1
# [-3.71127115 -9.90126646] 0
# [ 2.58606691 -2.25271995] 1
# [ 0.47521654 -2.68438896] 1
# [ 3.61141968 -2.22654967] 1
# [  0.25863404 -10.28944035] 0
# [-1.26227073 -8.91283356] 0
# [-2.02990113 -8.06304372] 0
# [ 1.41460266 -0.27711726] 1
# [-1.5841884 -6.8961805] 0
# [ 0.02766583 -2.97172504] 1
# [2.69268904 0.89777518] 1
# [-1.89879577 -9.93601287] 0
# [ 1.12849702 -2.79350075] 1
# [-0.03918291 -8.24439896] 0
# [ -0.37081902 -10.66358073] 0
# [-0.89820499 -8.91678364] 0
# [-0.03803041 -1.86643506] 1
# [ -0.51658785 -11.22830704] 0
# [ -2.75311558 -10.3119768 ] 0
# [-0.48873353 -0.59222875] 1
# [ 0.30174921 -1.68198948] 1
# [ 0.32580313 -0.93162624] 1
# [ -0.90047377 -10.40043565] 0
# [ 0.32097529 -1.78003386] 1
# [ 1.1883586  -0.90618877] 1
# [ 0.29025649 -2.3660725 ] 1
# [ 0.84630812 -2.99470835] 1
# [-1.38249648 -8.9829529 ] 0
# [ 0.72947716 -1.43146775] 1
# [-2.74720898 -9.20210216] 0
# [-1.58059835 -7.9572924 ] 0
# [ 2.00535135 -1.00137271] 1
# [ 2.42094234 -0.10791072] 1
# [ 2.46361241 -1.79562216] 1
# [-0.85543114 -9.42114805] 0
# [-1.36583677 -8.88852069] 0
# [-0.85581986 -9.92679329] 0
# [2.19325839 0.78260538] 1
# [-0.78355869 -0.42900904] 1
# [ 1.95414939 -0.26215429] 1
# [-1.77949116 -8.98111786] 0
# [-1.62704249 -9.07003185] 0
# [ 1.0656981  -2.22634839] 1
# [ 0.2442606  -0.63724494] 1
# [-0.84935045 -1.5244676 ] 1
# [-0.88593691 -9.5244045 ] 0
# [-1.81034471 -9.40104496] 0
# [-1.25884111 -8.57055785] 0
# [ -4.09937045 -10.6043366 ] 0
# [-0.89268384 -8.41667124] 0
# [-0.89412264 -9.21755607] 0
# [-1.90564035 -8.98928488] 0
# [-2.52834713 -8.48805321] 0
# [-1.82807885 -8.161944  ] 0
# [-1.00523554 -7.84602369] 0
# [ 1.24191915 -2.1310649 ] 1
# [-1.18281635 -7.30272685] 0
# [-0.84660563 -8.20309613] 0
# [ 0.40081684 -2.19970846] 1
# [ 0.5418788  -1.17223416] 1
# [ -1.21963951 -10.82006424] 0
# [ -2.33501763 -10.66423257] 0
# [ 0.15177925 -0.51382048] 1
# [ 1.57592727 -1.72569626] 1
# [ 0.18757957 -0.34277613] 1
# [-1.49471987 -8.72471564] 0
# [-0.93615923 -9.64347872] 0
# [ -2.61380146 -10.03387446] 0
# [-0.68137435 -9.7171089 ] 0
# [ -2.88109852 -10.03113119] 0
# [-0.31619418 -0.06529775] 1
# [ 0.95469091 -1.3830685 ] 1
# [-0.40221073 -8.63757033] 0
# [ -0.75899253 -10.18966974] 0
# [-3.03423077 -8.23676345] 0
# [-0.31495899  0.19855143] 1
# [ 1.31277841 -0.37894197] 1
# [ 0.24256955 -1.80297639] 1
# [-0.96390191 -9.83764622] 0
# [ -0.94497693 -10.34183165] 0
# [ -1.42606637 -10.42577364] 0
# [ 0.37067743 -1.90843087] 1
# [ 0.21746605 -1.24007587] 1
# [-2.1072437 -8.280915 ] 0
# [ -1.5014229  -10.65463098] 0
# [-0.39662907  0.14014422] 1
# [1.58815862 0.00864918] 1
# [ 0.48015634 -2.70980699] 1
# [ -2.58424617 -10.78419247] 0
# [ 2.28707899 -2.32122695] 1
# [ -1.74082934 -11.42451375] 0
# [ 2.39285339 -0.678887  ] 1
# [ 1.93205924 -0.89168411] 1
# [ 0.49552397 -0.58587609] 1
# [-0.52134267 -9.60613193] 0
# [-0.93465259 -9.86427846] 0
# [-0.65554791 -8.61205435] 0
# [ 0.44492813 -1.21684686] 1
# [ 0.06981622 -0.82549058] 1
# [-0.69257731 -9.64429369] 0
# [-2.42390279 -9.18478023] 0
# [-1.89346818 -1.40026296] 1
# [-0.03760578 -0.74447761] 1
# [ 0.86715585 -0.72361213] 1
# [ 1.56697564 -0.33932918] 1
# [-0.88595493 -2.6343656 ] 1
# [ 1.00272741 -1.49428942] 1
# [ 0.33420601 -8.4825679 ] 0
# [ -2.86420163 -11.036272  ] 0
# [ 0.644721   -2.25123919] 1
# [ 0.14655958 -1.93606814] 1
# [-0.45488686 -7.44813992] 0
# [ 2.9876005  -0.46283762] 1
# [-1.93187383 -9.44982592] 0
# [-2.11703441 -9.88893179] 0
# [-1.34314384 -8.71503312] 0
# [ 0.05636855 -1.70264264] 1
# [-1.08235204 -9.14463923] 0
# [-0.00534397 -1.50398473] 1
# [-0.14710692 -8.08751076] 0
# [-0.36913007 -2.64906636] 1
# [ 0.1773888  -3.03605594] 1
# [ 2.05650241 -1.25274165] 1
# [-0.03250702 -7.89467314] 0
# [ 0.3892533  -1.65489158] 1
# [ -1.83841839 -10.94905679] 0
# [ 0.92673257 -0.72765751] 1
# [ 1.39095447 -0.46282422] 1
# [ -0.5662671  -10.85139728] 0
# [-2.22290677 -8.53379179] 0
# [ -0.75052036 -10.52937404] 0
# [1.16958921 0.52484209] 1
# [-1.69632364 -9.41981809] 0
# [ 0.20776798 -1.08278493] 1
# [ 0.01971339 -9.42788089] 0
# [ 1.31495924 -0.29086979] 1
# [-1.87984719 -9.43496469] 0
# [ 0.42887392 -1.20150911] 1
# [ 1.57139849 -0.92041164] 1
# [ -1.60357577 -10.52695354] 0
# [ 1.19472787 -0.69142615] 1
# [ 0.05722405 -1.9837008 ] 1
# [ 1.15603339 -0.8392686 ] 1
# [-1.28884765 -9.06503415] 0
# [-1.89847744 -9.1026809 ] 0
# [ 2.08808032 -0.71052873] 1
# [ 0.38926571 -3.0258562 ] 1
# [ 1.17073324 -0.24083245] 1
# [-1.33820583 -9.21232165] 0
# [ 0.26464932 -1.37842593] 1
# [-3.11987603 -9.96977374] 0
# [ -2.06998961 -10.10900775] 0
# [-1.63130291 -9.73974245] 0
# [-1.9002707  -8.27916796] 0
# [ -0.13713622 -11.63741261] 0
# [ 2.25876416 -1.92982564] 1
# [-0.45781444 -2.16491109] 1
# [ 2.61190783 -1.36763014] 1
# [-0.85696596 -9.99703423] 0
# [ -3.2047805  -11.93880467] 0
# [ 2.28537352 -3.00276986] 1
# [ 1.23979459 -3.27754185] 1
# [ 0.02258359 -1.29887617] 1
# [ -1.87255585 -10.77140878] 0
# [ 1.79424718 -0.36679162] 1
# [ -0.99278507 -10.6828412 ] 0
# [ 0.93717958 -0.66430217] 1
# [ 1.54786752 -1.31390389] 1
# [ 2.18448017 -1.50145384] 1
# [ 0.32025806 -0.30290836] 1
# [ 2.24655081 -1.87819317] 1
# [-2.00613423 -9.15465816] 0
# [-1.88027018 -7.78332578] 0
# [ 2.28538075 -2.04570855] 1
# [ 1.14073755 -1.45858434] 1
# [-3.14819261 -7.7502907 ] 0
# [ -1.06398595 -11.34008775] 0
# [ -3.31058665 -10.39532089] 0
# [-0.88083563 -7.334585  ] 0
# [-2.10102483 -9.43400234] 0
# [ 1.71437558 -1.42436885] 1
# [ 0.37713504 -0.63269592] 1
# [-1.98894388 -9.57861763] 0
# [-1.06476763 -9.67504284] 0
# [ 1.60376891 -2.59242251] 1
# [-1.06603169  0.3498587 ] 1
# [ 1.91987065 -0.40579613] 1
# [ 0.17575417 -9.32317141] 0
# [-2.30917404 -8.89354577] 0
# [-0.11566302 -2.99624729] 1
# [ 2.22805467 -3.93952001] 1
# [ 1.93834595 -1.83315262] 1
# [-2.81597657 -9.42492079] 0
# [-1.68422109 -8.62151188] 0
# [0.60135523 0.00516778] 1
# [ 3.83512282 -1.79084997] 1
# [0.79296338 0.82763792] 1
# [-3.54058872 -9.59873867] 0
# [-0.69178314 -8.7569513 ] 0
# [ 0.92568121 -1.71774059] 1
# [ 0.34934533 -0.76618616] 1
# [-0.95457988  0.96175998] 1
# [-0.20432041 -0.81633179] 1
# [-0.76674211 -8.08703917] 0
# [ 0.59263617 -3.03768065] 1
# [-1.08025551 -9.55515799] 0
# [ 1.75894013 -1.45969561] 1
# [-3.04474786 -9.49502058] 0
# [ 1.38770567 -1.25547584] 1
# [ 1.45971184 -0.19468333] 1
# [ 0.05005748 -2.62205672] 1
# [-0.41398558 -9.8823915 ] 0
# [-0.14805797 -1.85236702] 1
# [ 1.22014564 -1.6269579 ] 1
# [-4.00245497 -9.23934911] 0
# [-0.84923786 -8.69588794] 0
# [ 2.60836363 -3.49037304] 1
# [ 2.72581139 -1.478541  ] 1
# [ 0.28725306 -0.40393732] 1
# [ 1.95282461 -0.89562703] 1
# [-1.20439486 -8.7868813 ] 0
# [-2.30751691 -8.55781266] 0
# [ 1.17595778 -0.41999464] 1
# [-1.87775779 -9.45597997] 0
# [ 0.73565238 -0.75669461] 1
# [2.74277681 0.8550977 ] 1
# [-1.33364721 -8.37719942] 0
# [ -1.09754397 -11.17851406] 0
# [-1.34458012 -8.95261891] 0
# [-0.85530091 -8.56796988] 0
# [-0.41504457 -9.72545535] 0
# [-0.86795585 -9.53822188] 0
# [-1.14647721 -9.22774797] 0
# [-2.26874483 -8.06871947] 0
# [ 2.7290524 -0.662653 ] 1
# [-1.34361899 -7.85228114] 0
# [0.4136091  0.07985831] 1
# [ 0.28605559 -0.34050419] 1
# [ -2.95026521 -10.01985648] 0
# [ -1.39017104 -10.41906957] 0
# [-0.87904753 -8.97488165] 0
# [-0.15025355 -9.59923393] 0
# [ -2.29525553 -10.71366491] 0
# [1.78461843 0.47239147] 1
# [ 1.43397497 -0.64420152] 1
# [ 2.19012334 -1.64458358] 1
# [ -1.59465464 -11.01997069] 0
# [ -1.0006682  -11.30370663] 0
# [ 1.3739596  -2.56512103] 1
# [ 1.89375892 -0.44128534] 1
# [ -0.94182589 -10.44074177] 0
# [ 1.20309377 -0.33409709] 1
# [ 1.64680303 -1.92392969] 1
# [ 1.47043041 -8.02033336] 0
# [ -0.54146416 -11.06877094] 0
# [-1.29046464 -9.6079202 ] 0
# [ 0.87515492 -2.07049683] 1
# [ 0.29852525 -0.46910162] 1
# [-0.83636345  0.2739023 ] 1
# [ 1.41297847 -4.39597296] 1
# [ -1.77510438 -10.50864444] 0
# [ -0.07492032 -10.12732058] 0
# [ 3.0010628  -2.25155524] 1
# [-1.21704252 -9.25597391] 0
# [ -3.30982021 -10.31673505] 0
# [-1.35964718 -8.24084574] 0
# [-0.65564918 -0.52867433] 1
# [ -0.89923169 -10.68421601] 0
# [-0.56501379 -7.70630322] 0
# [ 0.75684751 -2.41252202] 1
# [ -1.36040755 -10.77369917] 0
# [ 0.82254637 -1.00424157] 1
# [ -3.50852799 -10.83928364] 0
# [ 2.29686206 -1.39797041] 1
# [-0.20574054 -7.48536459] 0
# [-0.40407357 -8.43515377] 0
# [-0.64770307 -7.24664729] 0
# [-3.69507065 -7.21420146] 0
# [-0.40926119 -8.88866857] 0
# [ 1.87295714 -1.90144891] 1
# [ 0.58322742 -2.60081047] 1
# [ 0.08428867 -0.92323012] 1
# [ 0.57126259 -1.74041608] 1
# [-1.42704514 -7.94206198] 0
# [-0.59989893 -9.87569763] 0
# [ 1.16605266 -0.98667092] 1
# [-1.05508126 -9.08674868] 0
# [1.27811137 0.3786704 ] 1
# [-1.0787857 -8.0829095] 0
# [-0.17738566  0.42169894] 1
# [ 1.39612863 -2.6396233 ] 1
# [-1.70745289 -7.35022888] 0
# [ 0.54951789 -9.92509541] 0
# [ 0.2757705  -3.26558674] 1
# [-1.07333317 -9.18287142] 0
# [ 3.0615007  -1.06019862] 1
# [-1.34904158 -9.87262323] 0
# [ 2.3118326  -0.98441784] 1
# [ -2.09027894 -10.97200305] 0
# [2.46975586 0.12646264] 1
# [ -0.36297803 -10.89543591] 0
# [ 2.52004735 -0.53298034] 1
# [ 1.60969336 -1.98673069] 1
# [ -1.03765133 -10.27371092] 0
# [ -2.6094484  -10.22707178] 0
# [ 2.15520102 -1.4725387 ] 1
# [ -1.06638002 -10.01481747] 0
# [ 0.23425171 -1.97019101] 1
# [-2.37490809 -7.79607238] 0
# [ 1.69231962 -0.73498233] 1
# [ 1.25531206 -2.29356242] 1
# [ 2.0383286  -0.29525958] 1
# [ 1.11542511 -0.64575097] 1
# [ 0.20296335 -2.10452733] 1
# [ 2.08805265 -0.54399181] 1
# [-0.4233498  -1.36450196] 1
# [ 1.21407331 -1.80477195] 1
# [-1.23027799 -7.61405938] 0
# [ -1.95108994 -10.14324437] 0
# [-0.18758503 -8.81687378] 0
# [ 3.72948515 -2.15673802] 1
# [ 1.43726479 -1.62358212] 1
# [ 0.50674213 -0.52906278] 1
# [ -0.25191706 -10.20335509] 0
# [0.04363416 0.11216018] 1
# [-0.92096863 -8.85925495] 0
# [-2.30151669 -9.04907966] 0
# [-0.35863305 -8.78087013] 0
# [-1.22815489 -9.17206614] 0
# [ -0.8995531  -11.08378961] 0
# [-2.28121783 -9.80242572] 0
# [ 1.49183607 -0.93021399] 1
# [-1.24285024 -0.22242814] 1
# [ 0.96051174 -0.24705203] 1
# [ 2.13690175 -1.24437383] 1
# [ 2.25295703 -1.80667663] 1
# [ 1.52646196 -1.20151725] 1
# [-0.35713422 -0.88507544] 1
# [ 0.47515797 -2.86251381] 1
# [-1.35683035 -9.22964632] 0
# [ 0.62141556 -2.46479013] 1
# [ 0.7596797  -0.66034014] 1
# [-0.83013197 -8.7577121 ] 0
# [-1.00673568 -9.32154113] 0
# [ 1.01503887 -0.35523323] 1
# [ 1.36046786 -0.79177332] 1
# [-2.16790137 -9.48898951] 0
# [1.14698738 0.32363279] 1
# [ 1.6370632  -0.85842683] 1
# [1.18078056 0.25536815] 1
# [-3.13050593 -9.1509873 ] 0
# [ 2.2503269  -1.21700396] 1
# [ 0.43166852 -9.82480636] 0
# [-0.93807141 -0.32508571] 1
# [ 2.0575648  -1.77574421] 1
# [-0.95377121 -7.92914075] 0
# [-0.68070773 -8.3491731 ] 0
# [ -1.51059533 -11.10734965] 0
# [2.09959149 0.28803973] 1
# [ -1.51070034 -11.80717901] 0
# [ 1.56113084 -1.69539618] 1
# [ 1.2577456  -2.28263261] 1
# [ 0.89387886 -0.93483747] 1
# [-2.2116086  -9.19719095] 0
# [ 0.87019875 -1.89803001] 1
# [-2.98540673 -8.65702239] 0
# [ 1.8788411  -1.46698223] 1
# [-1.99061875 -9.96934378] 0
# [-2.0537591  -8.98107516] 0
# [-1.77996074 -8.01024306] 0
# [ 2.4823694  -2.11933425] 1
# [ 0.33269356 -1.49810309] 1
# [ 1.44449358 -0.64108903] 1
# [ 1.4659111  -0.71329398] 1
# [ 0.58951743 -0.4845377 ] 1
# [ 0.10699174 -1.23223368] 1
# [ 0.95360165 -1.07350217] 1
# [ 0.67773924 -1.17839622] 1
# [ 0.09590832 -1.70017994] 1
# [-0.5686554  -3.02329491] 1
# [-2.72577703 -9.37294189] 0
# [ -2.62388484 -10.67535677] 0
# [ 1.41272808 -1.79950423] 1
# [ -1.6864302  -10.27515064] 0
# [ 1.59347089 -2.75388902] 1
# [ 0.34760141 -0.6741014 ] 1
# [-0.69204924 -7.78943184] 0
# [-0.3919561  -1.62173707] 1
# [1.15658351 0.27151926] 1
# [ -0.31529636 -10.08408909] 0
# [-0.38023543 -3.43997564] 1
# [ -1.84459539 -11.56928283] 0
# [ 1.92393477 -0.69296701] 1
# [ 0.3194669 -1.4225476] 1
# [-2.95373794 -8.98229101] 0
# [ 3.0648905  -0.41656084] 1
# [-0.11196576 -1.79010925] 1
# [-2.19054642 -9.86197282] 0
# [ 1.65187895 -2.05082522] 1
# [ 0.20382464 -1.30460611] 1
# [ 0.69818746 -2.36355479] 1
# [ -2.26626277 -10.24870752] 0
# [ -1.14222701 -10.15653838] 0
# [ 0.31623208 -2.05713858] 1
# [ 1.21654352 -0.81779793] 1
# [0.77538701 0.71116403] 1
# [ -0.37468359 -10.35633334] 0
# [ 0.30535799 -1.09167698] 1
# [ -0.87968311 -10.19112955] 0
# [-2.91627797 -8.99431071] 0
# [-0.03545618 -1.61424992] 1
# [ 0.25244512 -0.84077998] 1
# [-0.08918182 -0.10812959] 1
# [ -0.72743826 -10.32191838] 0
# [0.36695235 0.42789069] 1
# [ -1.62717472 -10.00547121] 0
# [ -1.17173631 -10.33142678] 0
# [ 0.05518705 -0.94635524] 1
# [1.17646613 0.21599281] 1
# [ 0.8650385  -0.85470087] 1
# [ 0.72511865 -1.6091947 ] 1
# [-2.35143617 -8.92276264] 0
# [ 1.99058068 -1.65821596] 1
# [-0.24772252  0.9799065 ] 1
# [-0.41267262  1.01791211] 1
# [-1.98896644 -9.84651921] 0
# [-1.02420962 -8.47578113] 0
# [-0.8246721  -9.59636989] 0
# [0.27631378 0.42255736] 1
# [-0.46225137 -9.69084721] 0
# [-0.23184813 -2.09968925] 1
# [-0.3916379  -8.93396076] 0
# [ 1.21701411 -2.30141294] 1
# [-1.58294937 -8.68150469] 0
# [-2.29476464 -8.23519363] 0
# [ 2.71282132 -1.13184863] 1
# [-0.94064219 -8.63808236] 0
# [ 1.03646658 -2.29371539] 1
# [ 1.42231346 -2.33182484] 1
# [-0.17905383 -1.28563632] 1
# [  0.66944583 -10.11716012] 0
# [-1.60917615 -8.37299733] 0
# [ 1.88663937 -2.20931948] 1
# [ 1.76665827 -1.35017524] 1
# [-1.10352039 -9.23236028] 0
# [ 0.40155766 -2.93920275] 1
# [ -2.97959373 -11.33476423] 0
# [-0.64707918 -9.40242137] 0
# [-1.21991744 -9.79205289] 0
# [-2.38015193 -7.54098866] 0
# [ -2.12048589 -11.1905671 ] 0
# [-0.52783179 -8.98467839] 0
# [ 1.62744391 -1.58628008] 1
# [-2.20680143 -9.88858983] 0
# [ -1.29016365 -10.11236296] 0
# [-0.09793332 -0.97512503] 1
# [ 0.02848067 -2.14177889] 1
# [ 1.74238541 -0.05926249] 1
# [0.21354281 0.19882912] 1
# [ 1.71865122 -0.87295665] 1
# [-0.50991765  0.57623304] 1
# [ 1.76694475 -0.31126893] 1
# [ 1.48116715 -1.25223022] 1
# [-0.88935296 -9.17933773] 0
# [-0.9429631  -7.90093075] 0
# [ 0.56475538 -9.07497386] 0
# [ 2.08817673 -1.55104881] 1
# [-1.430249  -8.6226343] 0
# [-0.61971996 -9.53463414] 0
# [-0.26819304 -1.13975325] 1
# [ 1.41258017 -1.21915171] 1
# [ -2.05856371 -10.44677444] 0
# [ 1.57471345 -0.35121554] 1
# [ 2.33705361 -2.18905274] 1
# [ -0.46089512 -10.73728758] 0
# [-1.19095139  0.3671105 ] 1
# [ 0.97408294 -2.61574149] 1
# [-0.32720954 -0.20509112] 1
# [-0.4449381   0.15402126] 1
# [-1.52824529 -9.38790358] 0
# [ 0.55288852 -1.65691497] 1
# [ 0.6028985  -8.37322984] 0
# [-0.44138897 -9.33164741] 0
# [ 0.04663909 -9.64851988] 0
# [ -1.2877031  -10.41530602] 0
# [  0.11024405 -11.13315496] 0
# [ 1.19444516 -1.86159755] 1
# [ -3.28723324 -11.21625321] 0
# [ 0.28420093 -1.84270197] 1
# [ -0.24822504 -10.47782315] 0
# [-1.83764114 -8.97130852] 0
# [-0.67092974 -2.32274347] 1
# [-2.50718818 -7.99329477] 0
# [1.45572381 0.7509323 ] 1
# [-0.82325479 -1.61978723] 1
# [ -1.31583407 -10.89181432] 0
# [ 1.13399101 -9.89112937] 0
# [ 1.53727755 -2.07257245] 1
# [-1.85819111 -9.25778508] 0
# [-0.62818567 -8.122181  ] 0
# [ 1.21938975 -0.88625626] 1
# [0.03399587 0.8451765 ] 1
# [-1.31184114 -1.12777209] 1
# [ -0.41467473 -10.06226885] 0
# [-1.35218357 -9.56440975] 0
# [ -0.8047847  -10.56506838] 0
# [ 1.94128459 -0.58838158] 1
# [-0.23975432 -1.98108852] 1
# [ 2.05547218 -1.53958054] 1
# [ 2.70224271 -0.79579066] 1
# [-1.21350384 -9.35844148] 0
# [ 1.40209071 -1.09626206] 1
# [-0.38426301 -1.15863867] 1
# [ -1.52445107 -10.96324691] 0
# [-0.60789252 -1.60055325] 1
# [ 1.20708262 -9.93283642] 0
# [ 0.57086486 -1.42827802] 1
# [ -1.95813182 -10.5688611 ] 0
# [-0.64830303 -9.06388263] 0
# [ 2.22137523 -1.22034881] 1
# [ 1.82502882 -1.30323727] 1
# [ 0.45772252 -9.56579804] 0
# [  0.26377464 -11.33423469] 0
# [ 1.25576024 -1.92348751] 1
# [ -0.75914569 -11.03293562] 0
# [-2.15822401 -8.96853527] 0
# [ 1.9107081  -0.82707484] 1
# [ 1.0395211  -3.49891377] 1
# [ 1.79507779 -1.34586181] 1
# [ 0.81876817 -0.90809555] 1
# [-0.15587925 -2.70071056] 1
# [-1.77975534 -1.40738105] 1
# [ 0.83758087 -0.07898889] 1
# [-1.57254538 -8.97668064] 0
# [-1.93335222 -8.63901908] 0
# [2.18327279 0.06368333] 1
# [ 0.6179658  -1.07129037] 1
# [-2.64728382 -8.02473443] 0
# [ 0.82170953 -1.24599603] 1
# [ 0.96711905 -1.36031072] 1
# [ -1.64471696 -11.11908975] 0
# [ 0.7001167  -0.90422531] 1
# [ 0.70888156 -0.5968187 ] 1
# [ -2.53389697 -10.25469132] 0
# [ -2.06813978 -10.95649561] 0
# [ 0.25140143 -1.04102687] 1
# [ 0.85356978 -1.08362362] 1
# [ 0.87779616 -0.58479152] 1
# [-2.1186144  -7.82332273] 0
# [ 0.94288038 -0.74637191] 1
# [ 1.86646845 -2.51358204] 1
# [-0.16832804 -9.45234132] 0
# [ 3.46530969 -3.40911304] 1
# [ 0.6819036  -1.52278373] 1
# [ 1.67489526 -1.31103418] 1
# [ 1.3639829  -0.50830003] 1
# [ -1.84871396 -11.12501817] 0
# [ 1.38943145 -1.22656974] 1
# [-1.38537685 -9.7328959 ] 0
# [ 0.69024236 -2.87019784] 1
# [ 0.44770084 -2.25501887] 1
# [ 1.97921905 -1.20229343] 1
# [ -1.28882255 -10.39703443] 0
# [ 0.10546649 -3.31001794] 1
# [-2.36733484 -8.16316016] 0
# [ 0.7282191  -3.19315993] 1
# [-2.30361694 -9.92965019] 0
# [ 0.84337081 -2.1450919 ] 1
# [ 0.30927578 -0.93909206] 1
# [-0.86279273 -9.62889245] 0
# [ -2.09442348 -10.22453816] 0
# [ 2.30979084 -0.52330719] 1
# [ 0.57634883 -0.11055156] 1
# [-0.25636978 -1.76855921] 1
# [-1.80284381 -9.99938775] 0
# [-0.79684905 -7.78056363] 0
# [ -2.56641702 -10.18807494] 0
# [-0.90852247 -8.13746298] 0
# [ -1.02353151 -10.47025441] 0
# [-0.22074428 -9.25607177] 0
# [-1.9271359  -8.59149273] 0
# [-1.35247543 -9.33118029] 0
# [ -2.39345984 -11.48050585] 0
# [-1.83125932 -8.80379516] 0
# [ 1.70923027 -1.87923976] 1
# [-0.23455987 -9.5874072 ] 0
# [ -2.95219189 -10.03091718] 0
# [-1.16211348 -9.04396659] 0
# [ 0.38686997 -2.64902899] 1
# [ 1.02063921 -2.50356268] 1
# [-1.94639949 -8.55756456] 0
# [-0.91470014 -0.02306206] 1
# [ 0.43239584 -2.150396  ] 1
# [-2.94707909 -9.25615756] 0
# [ -1.69803738 -11.3640099 ] 0
# [ 1.25023241 -0.06129699] 1
# [ 2.06796727 -0.23934049] 1
# [-1.2707217  -7.29605319] 0
# [ -1.68077649 -10.84864403] 0
# [ 1.50964567 -2.37182205] 1
# [-0.33098023 -9.43056837] 0
# [ -0.23729692 -10.32358001] 0
# [-0.02296908 -0.24099854] 1
# [-0.42926914 -1.51950522] 1
# [-0.87205152 -1.42407468] 1
# [ 0.47956636 -1.29514033] 1
# [  0.35658542 -11.0252437 ] 0
# [ 1.62964336 -1.3438162 ] 1
# [-0.08768935 -1.62672433] 1
# [-1.93599779 -8.56935131] 0
# [-1.03338569 -3.43166187] 1
# [-0.57328332 -0.21864024] 1
# [-0.31977975 -9.7137239 ] 0
# [-0.63684568 -9.16703163] 0
# [ 0.98900099 -2.54794919] 1
# [ 0.59148091 -1.36662531] 1
# [ 0.8020658  -1.01256373] 1
# [ 2.34584564 -0.94537956] 1
# [ 2.01691935 -1.16209903] 1
# [ 2.42907709 -1.6255128 ] 1
# [-0.21167634 -0.79447021] 1
# [-1.54915892 -7.25010857] 0
# [-0.56657751 -6.95174049] 0
# [ 0.67164959 -0.67923956] 1
# [  0.62191527 -10.0618584 ] 0
# [ 2.46571825 -2.36253547] 1
# [ 1.42359719 -0.21173227] 1
# [ 1.51812842 -1.64077081] 1
# [-0.00074814 -0.12815108] 1
# [ 0.95076955 -0.71413926] 1
# [-0.11131414 -0.37674311] 1
# [ -2.41442044 -10.18889625] 0
# [ -1.2388668  -11.75422156] 0
# [-1.38276571 -9.59231823] 0
# [ 0.91144624 -1.07158907] 1
# [-0.57770736 -9.19487557] 0
# [ 0.60259036 -0.89204292] 1
# [-1.50303436 -8.23592768] 0
# [ 2.36401846 -1.62936013] 1
# [ -1.05232651 -10.70870349] 0
# [-0.76320628 -9.23085104] 0
# [ 0.85784975 -2.27016497] 1
# [0.4733469  0.38733835] 1
# [ 0.34982742 -0.45130732] 1
# [-1.71638364 -8.89087769] 0
# [-1.98263137 -0.66676282] 1
# [-0.43318974 -9.23704353] 0
# [-0.03486478 -8.29406161] 0
# [  0.94524428 -10.38322507] 0
# [-0.62343982 -2.69147942] 1
# [ 0.5124909  -9.91048868] 0
# [ 1.10088    -2.85550514] 1
# [-0.08634258 -8.89598346] 0
# [1.53559373 0.32963078] 1
# [ 0.16807789 -1.34482018] 1
# [ 1.13611134 -2.60913198] 1
# [ -1.29344171 -10.24979861] 0
# [-0.56432613 -9.30063832] 0
# [ 2.48840897 -0.50319745] 1
# [ 0.56985709 -0.54290241] 1
# [-0.20530675 -9.12387821] 0
# [0.70853248 1.07984287] 1
# [  0.29678822 -10.88817495] 0
# [ -2.93477754 -10.30144289] 0
# [ -1.83957048 -10.26497172] 0
# [0.43522193 0.32804852] 1
# [ 0.57510147 -2.91036344] 1
# [ 0.14094612 -2.14836908] 1
# [2.50757878 0.32327809] 1
# [ 1.45852604 -2.36743602] 1
# [ -1.59481897 -10.48311313] 0
# [ 0.72312206 -0.96293181] 1
# [-0.29694037 -1.05141495] 1
# [ 0.24954602 -1.67950416] 1
# [ 1.71494507 -1.48543694] 1
# [-1.0333107  -1.08242844] 1
# [ -0.97258343 -10.86808772] 0
# [ 1.37800938 -0.63327946] 1
# [-0.6857928 -9.5595827] 0
# [-0.14274285 -1.32118272] 1
# [ 1.54700685 -2.21677932] 1
# [ -1.15718189 -11.14094592] 0
# [ 1.8509123  -1.80095388] 1
# [2.47218401 0.24433233] 1
# [-1.53959912 -8.75076441] 0
# [-2.65612805 -8.87368354] 0
# [ -1.01789657 -10.64978322] 0
# [ 1.08366286 -3.31224076] 1
# [-1.31931322 -9.02290177] 0
# [-2.02904521 -8.54969103] 0
# [ 2.12639871 -1.30743879] 1
# [-1.66674907 -9.86295603] 0
# [-1.46957122 -9.55869403] 0
# [-2.05986668 -9.18130186] 0
# [ 0.33970473 -8.52821248] 0
# [-1.06190618 -9.52340579] 0
# [ 1.84544577 -0.71896768] 1
# [ 1.76041815 -1.85941353] 1
# [-1.10003527 -9.54840641] 0
# [ 0.03285918 -3.1401228 ] 1
# [-0.88792911 -8.90271437] 0
# [ 2.2583703  -0.49102362] 1
# [ 0.22286895 -2.85935463] 1
# [-2.90316164 -9.65112113] 0
# [-0.88940344 -9.51899566] 0
# [ 1.30578081 -1.94821209] 1
# [ 0.72371684 -1.64408899] 1
# [-1.31478732 -8.78528161] 0
# [ -2.65476415 -10.63198212] 0
# [ -0.91350876 -10.93593518] 0
# [-0.85246092 -8.73633474] 0
# [ -1.98120783 -10.3675346 ] 0
# [ 0.26244861 -1.15706867] 1
# [ -0.55563429 -10.02021411] 0
# [ 0.10791466 -1.90425555] 1
# [ -0.52888677 -10.07622066] 0
# [ -1.60536032 -11.39790564] 0
# [-7.85733140e-03 -1.08833285e+01] 0
# [-0.92274191 -2.06476149] 1
# [ -1.81759568 -10.1822567 ] 0
# [-1.41965675 -1.08878785] 1
# [ 1.1493258 -1.3566545] 1
# [ 0.11951436 -1.25388609] 1
# [ 0.50336351 -1.71715051] 1
# [ 1.00414103 -1.48725008] 1
# [-0.97544317 -9.40384742] 0
# [-2.04812767 -8.35791092] 0
# [ -0.55104692 -10.06500084] 0
# [ -0.04512004 -10.1264311 ] 0
# [-2.02429582 -8.60646471] 0
# [ 0.92338824 -2.9506045 ] 1
# [-0.03921152 -0.59632312] 1
# [-0.94741798 -0.90841331] 1
# [ 0.38548554 -1.44700941] 1
# [-0.95207514 -3.27917809] 1
# [  0.40932671 -10.11343784] 0
# [ -1.69252062 -10.30197403] 0
# [ 0.82610074 -2.3400699 ] 1
# [-1.7096953  -9.21919334] 0
# [-0.95464072 -9.25404586] 0
# [ 1.85508999 -1.38120761] 1
# [ 0.47975105 -9.84598423] 0
# [ 1.96834925 -0.70781894] 1
# [ 0.53885869 -2.05086918] 1
# [ 5.92639517e-03 -8.69318296e+00] 0
# [-1.35727451 -9.16092601] 0
# [ 1.9150184  -2.82069849] 1
# [-2.17371117 -8.72957301] 0
# [ 0.26620494 -0.80076541] 1
# [ -0.76825619 -10.57796142] 0
# [-1.4470758  -9.40238227] 0
# [-1.59753587 -8.57621173] 0
# [-2.09392777 -9.76377166] 0
# [-0.39070523 -2.76791014] 1
# [ 0.26223636 -0.68300738] 1
# [0.6540514  0.31637576] 1
# [-1.65352283 -8.69581658] 0
# [-1.51273584 -9.61594237] 0
# [-0.76685051 -9.81631949] 0
# [1.83369977 0.25394571] 1
# [-2.22081653 -8.70603707] 0
# [-2.38588715 -8.73187631] 0
# [ 0.73850466 -8.97142177] 0
# [ 1.34929783 -1.50199401] 1
# [ -1.31192985 -10.8469125 ] 0
# [-2.05241196 -1.6618861 ] 1
# [ 0.01182744 -0.28567499] 1
# [ -3.19673248 -11.70881666] 0
# [-0.53172979 -2.59652263] 1
# [ 0.63265363 -1.6251038 ] 1
# [ 0.25226004 -2.57860624] 1
# [ 1.05215436 -1.09889976] 1
# [-0.33378555 -8.84025359] 0
# [ 2.35651331 -1.47627771] 1
# [ 0.34458752 -1.75223818] 1
# [ 1.46513685 -3.35215497] 1
# [ 0.69514793 -0.79413262] 1
# [ 1.63784634 -0.09648835] 1
# [0.26206627 0.34345986] 1
# [ -1.02717784 -10.06016178] 0
# [-0.30511294 -0.30594433] 1
# [ -1.92476185 -10.08829695] 0
# [-0.78026318 -9.58731118] 0
# [ 0.55371511 -1.21914727] 1
# [ 3.43267057 -2.0784814 ] 1
# [ 0.31412866 -8.87842475] 0
# [0.88784904 0.08767354] 1
# [ 1.08760195 -2.50765199] 1
# [ 1.47175313 -0.07900376] 1
# [ 0.35952966 -1.06412678] 1
# [ -3.28652733 -10.4142256 ] 0
# [-0.06508984 -2.8840912 ] 1
# [ -2.27140588 -10.54517778] 0
# [-0.9593823   0.03340334] 1
# [ 1.4001239  -0.92527577] 1
# [ 2.70959006 -3.41378695] 1
# [1.57227691 0.23982567] 1
# [ 0.1050152  -1.29495676] 1
# [-2.36665011 -9.71239286] 0
# [-2.91398559 -8.89158106] 0
# [-0.5743711  -8.52572272] 0
# [-1.60606777 -8.48578821] 0
# [ 2.44547818 -1.99086487] 1
# [-1.35731269 -7.53166978] 0
# [ -1.78105409 -10.06711282] 0
# [ 0.06475852 -9.15384428] 0
# [ 1.71886936 -1.50150928] 1
# [ -1.15146719 -10.02623822] 0
# [ 1.95941349 -3.01712835] 1
# [ 2.28382621 -1.23950398] 1
# [-0.73713271 -8.89639932] 0
# [ 0.99887582 -0.70398694] 1
# [ 0.29004106 -0.62148552] 1
# [-0.45031291 -9.14540941] 0
# [-1.57651053 -8.89611526] 0
# [ 2.45468959 -0.9946563 ] 1
# [ 0.75894203 -1.99139211] 1
# [  0.95147587 -11.04221147] 0
# [-1.23107771 -9.20629618] 0
# [2.85465008 0.00696706] 1
# [ 1.15248366 -0.1396268 ] 1
# [ 0.17996383 -0.76558959] 1
# [ 0.89461423 -1.24585981] 1
# [-0.54837165 -9.43676587] 0
# [ -0.37973953 -10.2312894 ] 0
# [ 0.3455088  -1.53417745] 1
# [ 0.46963238 -1.05259348] 1
# [ 1.60614247 -1.3667779 ] 1
# [-1.43985377 -8.10390064] 0
# [ 0.59170071 -0.1088563 ] 1
# [ 0.14482803 -3.91902563] 1
# [-3.79448067 -9.89661733] 0
# [ 1.73801497 -1.43231509] 1
# [-3.67338393 -9.52060762] 0
# [ 0.3049129  -2.89393954] 1
# [0.99806346 0.3323835 ] 1
# [-0.1606757  -9.84968241] 0
# [ 1.02043163 -3.94224864] 1
# [-1.07589398 -8.07477912] 0
# [ 0.31055793 -9.07884729] 0
# [-0.99217032 -9.07753432] 0
# [-2.07932215 -8.90911255] 0
# [-2.58520997 -7.47565109] 0
# [ -1.62472563 -11.4835546 ] 0
# [ 1.82297229 -1.3903472 ] 1
# [ -1.07813944 -11.71752189] 0
# [-3.02507015 -9.29740123] 0
# [1.31770524 1.22559129] 1
# [-1.38306299 -8.81224633] 0
# [  0.03120413 -11.48155206] 0
# [ -1.86585896 -11.53188385] 0
# [-0.22246739 -8.63910602] 0
# [ 0.19969609 -1.77979601] 1
# [1.09544591 1.52897312] 1
# [-7.38082224e-04 -9.31893478e+00] 0
# [-1.51865833 -9.23465091] 0
# [-1.16716058 -9.84983338] 0
# [ 2.80345327 -1.3387593 ] 1
# [-1.74885843 -9.49874699] 0
# [-1.27774262 -8.77572283] 0
# [ 1.09660451 -2.3416458 ] 1
# [ 0.32804632 -0.59698387] 1
# [-0.48610557 -9.23488885] 0
# [ 2.70894756 -1.30347592] 1
# [ 1.46964001 -1.1499066 ] 1
# [-1.45547533 -1.07394968] 1
# [-2.59037249 -9.11804139] 0
# [ 1.95955261 -2.01134351] 1
# [ 1.59741147 -1.56970315] 1
# [-0.76279592 -9.04823722] 0
# [-1.06236358 -8.85321132] 0
# [ -1.94538846 -10.2319954 ] 0
# [-1.82398534 -9.29717362] 0
# [ -1.93787032 -10.73292377] 0
# [-2.34793656 -8.67900823] 0
# [-2.14582062 -2.07265934] 1
# [ 3.29569214 -0.9279934 ] 1
# [ -1.77612257 -10.09464218] 0
# [ -3.64500121 -10.81232961] 0
# [-7.73839095e-03 -9.89658698e+00] 0
# [ 1.35434552 -1.14837341] 1
# [-1.45304533 -9.4738523 ] 0
# [-0.23827345 -8.33888179] 0
# [ 1.15326888 -2.30128879] 1
# [ 0.6252334  -0.22185128] 1
# [-0.18787104 -0.27600477] 1
# [-1.37329982 -9.34584395] 0
# [-6.68822607e-03 -7.55960683e+00] 0
# [-1.00109223 -9.99949898] 0
# [ 1.61180676 -1.29514469] 1
# [0.44147749 0.52777086] 1
# [-0.24707289 -9.8104778 ] 0
# [ 2.06689828 -2.01067289] 1
# [ 0.85721876 -0.96383239] 1
# [-0.97316309 -9.45935172] 0
# [ -2.6371782 -10.0324987] 0
# [ 1.6428838  -0.68348089] 1
# [ 1.93910723 -2.48729595] 1
# [ -0.77005617 -10.87354191] 0
# [ 1.79421044 -0.64869285] 1
# [ -2.2246447  -10.72272449] 0
# [-1.43127954 -8.90614988] 0
# [-1.9263494  -8.78621061] 0
# [-0.27109443 -8.38984865] 0
# [ -1.25959684 -10.59196792] 0
# [ 0.89598697 -0.6650668 ] 1
# [-0.76963435 -9.90998415] 0
# [-0.09671534 -9.10671879] 0
# [ 2.74628473 -2.58398492] 1
# [ 0.8218113  -0.52270994] 1
# [-2.75987134 -9.6146441 ] 0
# [-1.07404187 -9.7095392 ] 0
# [ 2.08327622 -1.52724988] 1
# [-0.91375668 -1.90156987] 1
# [-1.03722767 -7.50125541] 0
# [ -0.49104231 -11.10314917] 0
# [ -0.83440275 -10.01972541] 0
# [0.58543295 0.24242573] 1
# [ 1.4056372  -0.92129533] 1
# [-3.01920611 -9.6392164 ] 0
# [ 1.37090146 -2.50038451] 1
# [-1.42955949 -6.84026041] 0
# [ 1.32596419 -2.15905439] 1
# [ -0.46489592 -11.55639773] 0
# [-0.69462552 -7.54779382] 0
# [ 3.44425301 -1.89848042] 1
# [-1.01414034 -9.68910153] 0
# [2.29750866 0.29092318] 1
# [-1.83309247 -9.30903516] 0
# [-1.95720263 -9.33324793] 0
# [ 0.75048113 -2.71507632] 1
# [-1.21397554 -8.94591701] 0
# [-1.97827295 -9.24152417] 0
# [ 0.93739448 -2.75981552] 1
# [ 1.64214488 -0.93954097] 1
# [-0.71137636 -9.71595803] 0
# [ 0.67147407 -2.78791203] 1
# [ -1.58810469 -10.81039051] 0
# [ 1.23946844 -8.46243707] 0
# [ -0.2517642  -10.45787876] 0
# [ 1.40858422 -1.32024208] 1
# [ -2.06514809 -10.31614004] 0
# [ -0.56092636 -10.9510854 ] 0
# [ -0.39004029 -11.15262644] 0
# [-1.94446979 -9.11699491] 0
# [ 1.50600463 -0.32902264] 1
# [ 1.13436619 -9.37043694] 0
# [ 1.54645033 -1.59669228] 1
# [ -0.72998249 -11.2742363 ] 0
# [ 1.75897985 -0.912574  ] 1
# [ 1.07026032 -1.83213266] 1
# [-2.39006105 -9.25212175] 0
# [-1.61470203 -8.32612249] 0
# [-1.73432981 -8.96710465] 0
# [ -1.46347869 -10.64128226] 0
# [ 1.5549642  -1.40541558] 1
# [-0.2180757  -2.05928735] 1
# [ -0.79476306 -10.8034085 ] 0
# [-0.66995787 -9.05797846] 0
# [ 2.3495732  -2.80140356] 1
# [ 1.41532541 -8.58363568] 0
# [-0.4002015  -0.87096684] 1
# [ -2.92222916 -10.63460238] 0
# [ 1.41484838 -0.98520653] 1
# [ 0.12442779 -9.98298785] 0
# [-0.90234279 -9.818247  ] 0
# [2.18062055 0.11058761] 1
# [ 0.82232029 -3.32219001] 1
# [ 0.64692377 -2.05021519] 1
# [ 0.83379061 -1.32085577] 1
# [-1.27260451 -9.05094936] 0
# [ 0.60315722 -1.7698703 ] 1
# [  0.76859538 -10.12881076] 0
# [-1.01181731 -9.02681714] 0
# [ 1.28488895 -0.90120682] 1
# [1.54489579 1.33784666] 1
# [ 1.18160208 -1.98517843] 1
# [-0.41136629 -3.46754763] 1
# [ 0.80882598 -0.69353904] 1
# [ -0.73193269 -10.59525131] 0
# [ -1.17903324 -10.52933197] 0
# [-1.3090378 -8.3087928] 0
# [ 2.28271704 -0.35399018] 1
# [ -0.33795141 -11.02724129] 0
# [ 1.03450602 -2.9988269 ] 1
# [ 0.55334131 -1.01237747] 1
# [ 1.57754836 -2.60495137] 1
# [ 0.09181673 -2.30160142] 1
# [-1.76071231 -8.38039649] 0
# [-3.19733388e-04 -1.10561181e+00] 1
# [-0.16442108 -1.34940802] 1
# [0.77904921 0.77563202] 1
# [ 2.21216052 -2.21993638] 1
# [ 1.81279394 -1.36656235] 1
# [ 0.65213962 -1.13449109] 1
# [-1.79572369 -9.71903976] 0
# [-2.47510185 -9.96940591] 0
# [-0.3742573  -9.11553422] 0
# [ 0.73738052 -1.4207936 ] 1
# [-1.03439769 -9.77766893] 0
# [ 0.49622379 -2.43426574] 1
# [-1.03323704 -0.60917842] 1
# [ 0.31734274 -0.03926138] 1
# [ 0.82162737 -0.8919892 ] 1
# [ -1.22119269 -10.58183694] 0
# [ 0.01704107 -9.14645881] 0
# [ 1.17831773 -0.79810546] 1
# [ -1.98575818 -10.3516271 ] 0
# [ 0.5697242  -2.54110987] 1
# [-2.14531192 -7.7296572 ] 0
# [-1.56666305 -9.09738209] 0
# [ -0.85092439 -10.17862372] 0
# [-1.54738695 -8.33737127] 0
# [0.27016138 0.70314693] 1
# [ 0.5304297  -8.20791957] 0
# [1.06308647 0.043674  ] 1
# [-1.67503479 -9.25244049] 0
# [ 1.60550702 -2.03727508] 1
# [ 1.12677532 -0.72060615] 1
# [ 0.4016895 -0.7762896] 1
# [-0.52766461 -9.51225163] 0
# [ 1.45815771 -2.29693126] 1
# [ -1.58111801 -10.29350479] 0
# [ -3.23084991 -10.38379917] 0
# [ -1.32415338 -10.26209175] 0
# [ 6.03629579e-03 -1.04522755e+01] 0
# [-1.78553768 -8.74817706] 0
# [ 0.92171998 -1.39220314] 1
# [ 1.3434367  -2.96758028] 1
# [-1.82024797 -9.73598657] 0
# [-1.16592025 -8.58608535] 0
# [ 2.0577915  -0.67419975] 1
# [2.08043588 0.10321648] 1
# [  0.61028364 -10.29319059] 0
# [ 3.22900081 -1.30946777] 1
# [-1.08835385 -9.85509491] 0
# [ 0.598653   -8.61597178] 0
# [  0.01549559 -10.03428204] 0
# [ 0.81882061 -0.51848726] 1
# [  2.21177498 -10.09051497] 0
# [ 1.75631515 -1.10427846] 1
# [0.96663447 0.0640707 ] 1
# [-0.22855318 -0.87063642] 1
# [-1.80420755 -9.57531868] 0
# [ 0.78788565 -0.70758813] 1
# [ 2.02849505 -2.20025355] 1
# [ 2.59907098 -0.12955217] 1
# [-1.62069357 -8.73381314] 0
# [ 1.43275575 -1.7938884 ] 1
# [-2.14797706 -9.05542728] 0
# [ 1.61126246 -1.1751436 ] 1
# [ 1.83828345 -0.1451766 ] 1
# [ 0.24143093 -1.2462726 ] 1
# [-0.44248616 -9.61315777] 0
# [ -2.44096178 -10.09769329] 0
# [ 2.0612463  -1.62033491] 1
# [-3.32720447 -9.80476028] 0
# [ 0.36968273 -1.52173096] 1
# [ 0.48900742 -0.81989687] 1
# [ 0.08131398 -1.58490498] 1
# [ -2.60306667 -11.31187362] 0
# [ 0.40349471 -1.45866519] 1
# [ -0.53419717 -10.68129351] 0
# [ 0.81763377 -2.16267578] 1
# [-2.69891251 -9.73324948] 0
# [-0.86836788 -8.48116451] 0
# [ 1.92946742 -0.8514394 ] 1
# [-0.82218683 -0.3801507 ] 1
# [ 0.72200849 -0.37046922] 1
# [ 0.82180229 -1.90632026] 1
# [-0.16572786 -0.55184209] 1
# [0.55753922 0.72509294] 1
# [-1.46248962 -9.23154719] 0
# [1.8148692  0.71610229] 1
# [ 1.26647442 -8.69644218] 0
# [ 0.80240961 -2.4554542 ] 1
# [-0.19828526 -8.42207422] 0
# [-0.3353499  -9.39716609] 0
# [ 0.15961135 -9.80429273] 0
# [ 1.34899972 -1.10471705] 1
# [ 1.97289066 -1.9090024 ] 1
# [-1.27175543 -0.93808794] 1
# [-1.62952457 -9.63570588] 0
# [ 1.41064988 -0.56928345] 1
# [ -1.17705384 -10.13363931] 0
# [ -2.82677657 -11.5641273 ] 0
# [-2.82613668 -7.44078063] 0
# [ 1.86336885 -1.24847504] 1
# [ -2.33297607 -10.38046085] 0
# [-0.98630875 -9.12994842] 0
# [ 1.1434182  -2.44921058] 1
# [ 1.35878965 -2.48587518] 1
# [-2.1522069  -9.62793031] 0
# [-0.34644551 -3.23807242] 1
# [-0.86020485 -1.94637207] 1
# [ 0.86836277 -2.5636755 ] 1
# [ 0.75291675 -1.36742204] 1
# [ 1.19694914 -2.78291007] 1
# [-1.33884352 -9.36425507] 0
# [ 0.3482558  -9.46080468] 0
# [ -1.87461319 -10.55824885] 0
# [ -0.0931305  -11.20238035] 0
# [ -0.92600452 -10.36723284] 0
# [-0.25851752 -9.66116875] 0
# [ 2.09914389 -1.08030313] 1
# [-0.60298044 -2.47042895] 1
# [-0.46642556 -9.39334431] 0
# [-2.00594317 -9.87382235] 0
# [ -0.42354842 -10.58729819] 0
# [ 0.10189212 -1.27357178] 1
# [ 0.7584959  -2.97076306] 1
# [ 0.94383696 -1.21420807] 1
# [ -2.69835466 -11.1473841 ] 0
# [ 3.19996082 -0.12368773] 1
# [ 1.46936792 -1.26803696] 1
# [ 0.53132015 -0.27553142] 1
# [-1.22512422 -9.62535435] 0
# [ 1.66283536 -1.40358249] 1
# [ -0.71739707 -10.06354612] 0
# [0.24709843 0.55379298] 1
# [-0.67340068 -9.27625572] 0
# [ 2.36922755 -1.51540955] 1
# [-0.33964916 -9.30583374] 0
# [ -1.78487033 -10.43116424] 0
# [ 2.4335792  -2.31491798] 1
# [-0.80605206 -1.59124477] 1
# [ 1.3261447 -1.1267858] 1
# [ 1.2033299  -2.01613822] 1
# [-1.14760105 -9.82746778] 0
# [-0.50875422 -9.24731849] 0
# [ -1.19727948 -10.56887016] 0
# [ 1.02450089 -0.78374976] 1
# [ 2.06805131 -3.15722504] 1
# [ 2.18297852 -0.93785083] 1
# [ 1.63330812 -1.10368332] 1
# [ 0.95042278 -0.67111941] 1
# [ 1.23627274 -1.73415384] 1
# [ 1.5457807  -0.68630116] 1
# [ 1.47449185 -0.43658376] 1
# [-2.37697355 -9.74151803] 0
# [-1.45331481 -9.39738045] 0
# [ -0.26617439 -10.33852617] 0
# [-0.31516705 -1.54746604] 1
# [ 1.52367389 -0.45538303] 1
# [-1.70969495 -9.30989801] 0
# [-2.3211525  -8.62030224] 0
# [0.00225992 0.2086017 ] 1
# [-0.44392781 -9.41572853] 0
# [-2.38842479 -9.61164942] 0
# [ -1.0538678  -10.29064759] 0
# [ -1.95777753 -10.92091439] 0
# [ -1.36706532 -10.6536144 ] 0
# [-0.43560758 -0.59988813] 1
# [-1.46989766 -8.41384608] 0
# [ 2.22463839 -0.67778277] 1
# [ 1.71666138 -1.20890973] 1
# [-0.64493458 -8.65696398] 0
# [-0.51865355 -8.57921897] 0
# [ 0.0516653  -2.74700598] 1
# [-1.50588735 -1.02608658] 1
# [ 0.17395993 -0.29240743] 1
# [ -4.02854879 -10.99010784] 0
# [ -3.44872046 -10.14665553] 0
# [-1.26845786 -9.14401792] 0
# [-0.37874953  0.74393512] 1
# [ 0.4927225  -1.82835119] 1
# [ 1.63017716 -2.13371066] 1
# [ -0.0145778  -10.84122457] 0
# [ 1.06532639 -1.41807496] 1
# [ 1.30922404 -1.10367924] 1
# [ 0.92615568 -1.01721145] 1
# [-1.37735488 -8.46146371] 0
# [-2.27519262 -9.50055607] 0
# [ -0.19760488 -10.3243311 ] 0
# [ -1.50834952 -11.55108763] 0
# [-1.78742688 -8.12125041] 0
# [ 0.32565589 -1.78582306] 1
# [-0.39391527 -1.80147341] 1
# [-1.98038004 -8.88848257] 0
# [ -1.22801909 -12.2380541 ] 0
# [-2.75684604 -9.60332748] 0
# [ -1.51424296 -11.73416065] 0
# [ 0.17884694 -1.34312766] 1
# [ -0.11744155 -10.41953472] 0
# [ -2.59577095 -10.79252808] 0
# [-1.31666314 -8.97756255] 0
# [ 1.46307947 -1.85559909] 1
# [ 0.42409665 -8.89536602] 0
# [-0.89693844 -9.85132354] 0
# [-0.34826823 -0.37944379] 1
# [ 2.49471836 -2.6383935 ] 1
# [ 3.42893032 -1.80261832] 1
# [ -2.16213844 -10.05575883] 0
# [ 1.59021043 -0.41158463] 1
# [ 1.69783423 -2.46474075] 1
# [ 2.504969   -3.28715554] 1
# [-0.44259907 -9.19106819] 0
# [ -2.73168627 -12.26440699] 0
# [ -2.34429467 -10.93584697] 0
# [ 1.19801443 -1.58411089] 1
# [ -1.83538183 -11.45267165] 0
# [ -1.57727674 -10.59578683] 0
# [ 0.83989643 -0.52113678] 1
# [ 2.01543528 -1.08302481] 1
# [-1.89730933 -9.2678868 ] 0
# [ -0.33046572 -10.16779029] 0
# [ 0.28219697 -3.56466256] 1
# [-1.48559887 -9.25512836] 0
# [-0.69565475 -8.30486448] 0
# [-1.48582987 -9.66109458] 0
# [ 2.50845371 -1.23839571] 1
# [ 2.20597163 -1.01206148] 1
# [ -0.41656986 -10.38635724] 0
# [ 0.94827102 -1.39813865] 1
# [-1.7632619  -9.45031716] 0
# [ 1.23689841 -1.15960695] 1
# [ 1.32382053 -2.33492418] 1
# [  0.24855484 -11.69490579] 0
# [-1.73784855 -9.61609601] 0
# [-1.58803735 -9.69830663] 0
# [ 0.88236045 -8.82392412] 0
# [-1.20622022e-03 -1.92524260e+00] 1
# [ 1.38751062 -1.96886954] 1
# [ 2.23729229 -1.18956017] 1
# [-1.47232395 -9.3791876 ] 0
# [-0.06587504 -2.12268743] 1
# [-1.39714717 -9.24075916] 0
# [  0.26466202 -10.53617189] 0
# [-0.64701925 -9.64060193] 0
# [-0.2647745  -9.90874534] 0
# [ 0.52374116 -0.20280904] 1
# [-0.5633822 -7.3912423] 0
# [ -0.41502913 -10.60586066] 0
# [-1.20667368 -9.15550681] 0
# [-2.37277179 -8.67907318] 0
# [ 0.27591482 -9.18986127] 0
# [-2.80949331 -9.7894631 ] 0
# [0.9287235  0.99606282] 1
# [ 1.10211159 -0.90822168] 1
# [ 3.23161424 -2.74146583] 1
# [-0.75380273 -7.69368762] 0
# [1.02538803 0.08035725] 1
# [ -4.60697206 -10.20354206] 0
# [-1.98196502 -9.54990096] 0
# [ -0.38960345 -10.60016212] 0
# [-1.66161844 -9.41498635] 0
# [ 1.42697835 -0.64669626] 1
# [ 2.11390842 -2.45276447] 1
# [-0.54222534 -9.42042242] 0
# [ 1.53672662 -1.27602107] 1
# [-2.571251   -7.44055761] 0
# [ 0.7823041  -2.02074985] 1
# [ 1.98637559 -0.27760193] 1
# [-0.23922342 -9.28755648] 0
# [-1.03866233 -8.98404971] 0
# [ 0.96637883 -2.04602636] 1
# [ 0.33083689 -0.67913664] 1
# [ 1.74097511 -2.79458397] 1
# [-1.87482446 -9.79628721] 0
# [-1.96858766 -9.29023755] 0
# [-1.28052322 -9.22456003] 0
# [-1.6902387  -9.70141753] 0
# [ 0.66595851 -1.29205099] 1
# [ 0.21561716 -1.81694728] 1
# [ 1.27821647 -0.93065051] 1
# [ 1.2748391  -2.45781854] 1
# [-2.1421701  -9.19136267] 0
# [-2.14622756 -8.08095289] 0
# [ 1.00500806 -1.91482741] 1
# [ 0.27305763 -2.74497627] 1
# [-2.21314621 -9.30714979] 0
# [-0.42190253 -9.84373135] 0
# [-0.7694607  -8.42019198] 0
# [-0.7256384  -8.79570611] 0
# [ 0.99663148 -0.85913607] 1
# [ 2.01243043 -1.18096934] 1
# [ 1.25084882 -1.09134108] 1
# [ 2.31903223 -1.56241439] 1
# [-2.56576661 -8.70301072] 0
# [-0.49225844 -3.01101052] 1
# [ 1.43195446 -0.66313496] 1
# [  0.75565213 -12.09840227] 0
# [-0.64421295 -2.41423834] 1
# [-0.63884425 -8.1051687 ] 0
# [1.90931858 1.14881622] 1
# [-1.49539045 -8.6010571 ] 0
# [-0.48607113 -0.32019626] 1
# [ 0.68226769 -8.08133853] 0
# [ -1.46198348 -11.07377017] 0
# [ 1.85754571 -2.32873774] 1
# [ -0.03165166 -10.72720192] 0
# [ 0.9528221  -0.90524503] 1
# [ 2.67961725 -2.1935137 ] 1
# [ 0.37882092 -1.3958744 ] 1
# [  0.24477012 -10.36528897] 0
# [ 1.07447658 -1.21166611] 1
# [ 2.88969781 -1.63734398] 1
# [1.34877276 0.29320475] 1
# [ 0.34099102 -8.76879209] 0
# [ -1.34079545 -10.07047049] 0
# [-2.32226069 -9.70799919] 0
# [-0.59988864 -2.08504331] 1
# [-0.27165929 -1.21863479] 1
# [ -2.75997525 -10.78560714] 0
# [-0.32692456 -9.82671733] 0
# [ -0.57530911 -10.35321791] 0
# [ 0.94489448 -1.40449844] 1
# [-1.50722219 -9.95186268] 0
# [ 0.02777616 -2.30893052] 1
# [ 1.71061571 -1.2937821 ] 1
# [-1.88374614 -8.46574964] 0
# ...
# [ 0.11660875 -1.07201719] 1
# [-0.04133938 -1.44561578] 1
# [-1.95480126 -2.13104295] 1
# [-0.49479438 -9.05165602] 0
# [-0.71743288 -9.64599042] 0
# [-2.61446054 -8.79855399] 0
# [ -2.65281836 -11.26808669] 0
# [-2.05265809 -8.66101387] 0
# [-1.7642323  -8.71607841] 0
# [-1.64428521 -8.78176335] 0
# [-0.6545163  -1.12029222] 1
# [ 0.05012884 -2.81288175] 1
# [-0.76975409 -0.83023261] 1
# [-0.18045891 -9.0919145 ] 0
# [-2.21915932 -7.78343085] 0
# [ 0.44767448 -0.672431  ] 1
# [-1.9179499  -9.41564189] 0
# [  0.20874401 -10.18682255] 0
# [-1.27006829 -0.70010717] 1
# [ 2.05169411 -0.21801283] 1
# [-2.19097173 -7.49931203] 0
# [  0.11202816 -10.57022704] 0
# [-1.23253154 -0.88643834] 1
# [-0.99866904 -9.80432712] 0
# [-1.68924499 -9.97375686] 0
# [ -0.56804073 -11.2821914 ] 0
# [ -2.78114205 -11.99691482] 0
# [ 1.38127416 -0.59395624] 1
# [-1.52653357 -8.56454841] 0
# [ 0.99803212 -0.27825586] 1
# [ -0.81737595 -10.1028391 ] 0
# [1.35915215 0.66673366] 1
# [ 1.48668748 -1.27730989] 1
# [-1.77510284 -9.74839843] 0
# [-0.41205549 -1.62726645] 1
# [-1.0199569  -7.67447763] 0
# [ -0.59972555 -10.10386445] 0
# [ -1.11465369 -10.24403395] 0
# [-2.21999163 -9.42659965] 0
# [ 0.6406128  -0.46851953] 1
# [-0.1338198  -9.25858853] 0
# [ 1.29902184 -1.51284012] 1
# [ 1.11504029 -2.10055094] 1
# [-0.02725393  2.08595009] 1
# [ 0.89436805 -3.1826059 ] 1
# [-0.88224607 -9.73564497] 0
# [-0.77675272 -1.91939304] 1
# [ 1.12017443 -3.7347329 ] 1
# [ 0.67152074 -2.1689096 ] 1
# [ 1.52360933 -2.17131778] 1
# [ 1.53152054 -0.90531042] 1
# [-2.93096958 -9.7350811 ] 0
# [ 1.14188919 -1.74831086] 1
# [-0.78056008 -2.62746302] 1
# [ 1.05114015 -0.15656299] 1
# [-0.43855136 -1.37492279] 1
# [-2.27055627 -9.27669083] 0
# [ 0.11742546 -1.93215091] 1
# [-1.11930238 -9.84020958] 0
# [ 0.83424351 -1.96328215] 1
# [ 0.17690567 -0.66560212] 1
# [ 1.67643221 -2.41136036] 1
# [ 1.36668861 -1.68279854] 1
# [ 1.22557211 -0.62756312] 1
# [ 0.28954613 -2.08002214] 1
# [ 0.4433268  -1.90643795] 1
# [ 1.50845727 -0.86524281] 1
# [ -1.72361342 -11.07660976] 0
# [ -1.0166314  -10.96883937] 0
# [-0.49708187 -9.88853841] 0
# [-0.12881824 -9.06395724] 0
# [-0.77473706 -8.74282353] 0
# [-1.4518282 -8.3860476] 0
# [ 0.63727606 -2.20263408] 1
# [ 0.2567226  -2.12964931] 1
# [-0.8835818 -9.7960928] 0
# [-1.50912683 -8.23832532] 0
# [ -2.03948172 -10.0062187 ] 0
# [-0.68028153 -8.9320909 ] 0
# [ 0.14747888 -1.47212814] 1
# [ 0.10735807 -7.7488758 ] 0
# [ 0.606653   -2.57354842] 1
# [-1.80275705 -9.91048763] 0
# [0.46341287 0.87771138] 1
# [-3.30381275 -7.8330126 ] 0
# [ 0.3448738  -1.36591631] 1
# [ -1.71043751 -11.43175243] 0
# [ -1.33096863 -10.81588765] 0
# [-1.11305327 -7.94018748] 0
# [-1.47570054 -8.08367495] 0
# [-0.61241008 -9.08833358] 0
# [1.41184447 0.46246412] 1
# [ 1.7404472 -1.1383356] 1
# [ 0.91252586 -1.27926147] 1
# [ 0.71766163 -0.47044899] 1
# [-0.53250302 -9.71437236] 0
# [-2.20331212 -9.49114555] 0
# [ 1.53316963 -2.20563725] 1
# [ 0.66723524 -0.80545557] 1
# [-1.62541021 -9.5292525 ] 0
# [ 0.81350189 -1.25468573] 1
# [ 1.84732626 -1.26819049] 1
# [-1.81950855 -8.66329285] 0
# [ -2.44462876 -10.35757461] 0
# [ 1.13209141 -2.43046765] 1
# [ 0.71891284 -0.62780977] 1
# [ 0.010666   -9.11736674] 0
# [ 1.16459783 -0.65205898] 1
# [ 0.0993643  -2.58940818] 1
# [-0.80647118 -1.74207774] 1
# [-1.9775117  -9.86485175] 0
# [ 0.6449267  -1.56378068] 1
# [ 0.1593634  -0.63063225] 1
# [-0.80334865  0.20475966] 1
# [-0.1801749  -1.42745008] 1
# [ -2.1244102  -10.04129548] 0
# [ 0.08713347 -8.26358973] 0
# [-0.97376565 -8.87352193] 0
# [1.36931658 0.12904331] 1
# [-1.75586593 -9.19084461] 0
# [ -0.60314727 -10.5631924 ] 0
# [-2.57379665 -9.51444069] 0
# [-0.90965742 -8.1218415 ] 0
# [ 0.35191514 -0.5716032 ] 1
# [ 0.88224051 -2.003847  ] 1
# [ 2.45800105 -2.42098211] 1
# [-0.96196505 -7.9720045 ] 0
# [ 0.21194283 -0.470739  ] 1
# [-0.21558465 -9.00658567] 0
# [-0.9515123 -0.7213883] 1
# [ -0.71213655 -10.45313127] 0
# [ -1.62692529 -10.54729165] 0
# [-0.68262296  0.31565117] 1
# [ 2.16996559 -0.79056793] 1
# [ -0.48129165 -11.20300488] 0
# [ 0.52827331 -9.80063461] 0
# [-1.18780616 -7.92332809] 0
# [ 1.01193263 -1.4880058 ] 1
# [-0.71164918 -1.76463996] 1
# [-2.41323523 -9.04838281] 0
# [ 1.44078712 -0.93735271] 1
# [ 0.38600714 -8.61086739] 0
# [ 2.13559562 -0.92309862] 1
# [ -1.01859762 -11.22386005] 0
# [ 0.45903189 -9.11253939] 0
# [ 0.53393705 -1.47402258] 1
# [ 1.36056342 -1.73371516] 1
# [-1.59539454 -9.982681  ] 0
# [ -2.49631302 -12.81604506] 0
# [ 0.63249872 -9.52673857] 0
# [ -1.82455066 -10.64222965] 0
# [ 1.20245228 -2.2602545 ] 1
# [0.56886122 0.48579298] 1
# [ -1.15536356 -11.3055859 ] 0
# [ 0.95471336 -1.22841955] 1
# [ -1.88709091 -10.92716864] 0
# [ 0.35489411 -1.28648185] 1
# [ -1.3223735  -10.15183855] 0
# [-3.12734763 -8.90754192] 0
# [ 0.94617855 -1.40316702] 1
# [-2.39826292 -9.55195241] 0
# [-2.37951408 -9.5431619 ] 0
# [ 1.68401508 -0.9925289 ] 1
# [ 1.90693532 -0.74898098] 1
# [ -2.05126383 -10.38907694] 0
# [ 1.66815946 -1.03807375] 1
# [ 1.4301052  -1.51978165] 1
# [ 0.43596492 -0.77477636] 1
# [ 0.92269857 -0.95410798] 1
# [ 0.97539942 -0.50154979] 1
# [ 0.91439332 -1.94465886] 1
# [ -1.18105551 -10.19969394] 0
# [ 2.51395186 -0.33363098] 1
# [ 1.49196008 -1.03020009] 1
# [ 2.61885987 -2.47835363] 1
# [ 1.47383299 -1.42913765] 1
# [ 1.35593925 -0.33331417] 1
# [ -1.01561835 -10.85354969] 0
# [ 0.01936749 -0.15142793] 1
# [ 1.29958326 -2.2137923 ] 1
# [-0.04629498 -1.43482878] 1
# [ 0.58085128 -1.17362506] 1
# [ 1.63057433 -0.36488923] 1
# [-2.47565876 -8.05301446] 0
# [ 1.66440385 -1.67829144] 1
# [ 1.05126413 -2.54338887] 1
# [ -1.89055157 -11.2523875 ] 0
# [  0.11647979 -10.73890929] 0
# [ -1.83541533 -10.23617854] 0
# [-1.49405349 -8.95505356] 0
# [ 1.57526458 -0.40146686] 1
# [-0.78761646 -9.41019549] 0
# [ 2.46595086 -1.43811489] 1
# [-0.21396555 -7.26211263] 0
# [-1.73876979 -9.91810412] 0
# [ 0.20949353 -2.17216345] 1
# [ 1.62480682 -0.70300155] 1
# [ 0.32694321 -1.245242  ] 1
# [ 1.06436949 -1.91759546] 1
# [ 1.29077735 -0.95107999] 1
# [-0.38462843 -9.61254622] 0
# [ -0.77824475 -10.32568907] 0
# [-0.45722518 -0.75805084] 1
# [ 2.6538455  -0.44318837] 1
# [-1.17741071 -2.82936317] 1
# [ 0.78974075 -1.94279781] 1
# [ -1.48588389 -11.47451011] 0
# [ 1.53590332 -1.90602914] 1
# [-3.45383928 -9.03888252] 0
# [0.29380499 0.13800279] 1
# [-1.68711332 -7.11992701] 0
# [ 0.43070864 -0.50228138] 1
# [ 1.28705225 -1.99025973] 1
# [ 0.18507095 -1.82357748] 1
# [ -0.58374081 -10.15389578] 0
# [-1.20384991 -9.0759972 ] 0
# [-0.19218254 -1.75949825] 1
# [ 1.28385155 -0.77262783] 1
# [ -1.56959651 -10.52848283] 0
# [ 1.17947288 -0.40054046] 1
# [-1.03014875 -8.99891034] 0
# [-0.90355605 -9.61695513] 0
# [-1.01552328 -8.47653121] 0
# [ -2.50223452 -10.05448843] 0
# [ 1.82775024 -0.64169069] 1
# [-2.74803106 -9.17932497] 0
# [ 0.2232444  -0.76051421] 1
# [ 1.90488189 -0.55125543] 1
# [ -2.41557955 -10.46828601] 0
# [-2.69291444 -8.96808677] 0
# [ 2.32290608 -0.86413261] 1
# [ 0.15719588 -1.16105395] 1
# [ -1.22843589 -10.23070616] 0
# [-0.54438126 -9.30824985] 0
# [-0.77964135 -0.61798185] 1
# [ 0.56353314 -0.67640631] 1
# [ 2.57049019 -1.84234025] 1
# [ 0.23906364 -0.79101401] 1
# [ 2.13546544 -1.57049001] 1
# [ 2.01007696 -0.07522918] 1
# [  0.08372333 -11.0342332 ] 0
# [-2.35484133 -8.33926324] 0
# [-0.94062815 -9.63650145] 0
# [ 0.84202369 -1.94526913] 1
# [2.40834453 0.12690705] 1
# [-1.8706056  -9.79650941] 0
# [-0.01780049 -0.99315292] 1
# [-1.07094113 -9.13682453] 0
# [-2.61538216 -9.67940594] 0
# [-1.61048467 -8.81171495] 0
# [1.35038959 0.08929557] 1
# [ 1.32227579 -1.3983919 ] 1
# [-2.54455441 -9.66407635] 0
# [ 1.34896205 -1.63450019] 1
# [ 1.11461846 -1.33956089] 1
# [ -0.38756916 -10.34342097] 0
# [-0.95234774 -8.5662466 ] 0
# [-2.67687719 -9.21735648] 0
# [ 0.38380266 -0.62008853] 1
# [-2.21597087 -8.7460649 ] 0
# [-1.4813867  -9.07925902] 0
# [ 2.2458207  -1.56396342] 1
# [-0.41752818 -9.60538276] 0
# [-0.76272618 -8.04759707] 0
# [0.79106555 0.52068073] 1
# [-2.60407391 -9.31732144] 0
# [-0.23462397 -8.11245934] 0
# [-2.43270047 -9.95969637] 0
# [ -0.25510582 -10.64573555] 0
# [ -2.14541537 -10.12219553] 0
# [-0.10273011 -2.11141121] 1
# [ 1.69989407 -2.98393072] 1
# [ 1.62162207 -2.73241997] 1
# [ 0.7356403  -2.09433231] 1
# [ 0.15777873 -8.59523895] 0
# [-0.48152663 -7.97845689] 0
# [ 0.56692387 -1.66130085] 1
# [ 1.00243768 -9.97725421] 0
# [ 1.08530606 -2.31231669] 1
# [ 0.40468337 -0.09086272] 1
# [ 0.29046949 -1.72377737] 1
# [-3.26027507 -9.42535708] 0
# [ 1.44030284 -0.75846585] 1
# [ -1.22222141 -10.06824326] 0
# [ 0.95999217 -0.28962443] 1
# [ 1.05937389 -1.75920481] 1
# [-0.11611143 -2.25371298] 1
# [ 0.56594636 -1.30906283] 1
# [-0.5603501  -2.72218228] 1
# [1.02030009 0.66815685] 1
# [ 0.91330349 -8.86937607] 0
# [-2.12139298 -7.61587987] 0
# [ 0.61136766 -0.87386579] 1
# [1.15328552 0.12842242] 1
# [-2.65052594 -8.36794557] 0
# [ -0.97028908 -10.22685034] 0
# [-0.91859544 -7.29974418] 0
# [ -1.79779761 -10.26932705] 0
# [ -0.84811298 -10.49933809] 0
# [ 1.69321407 -1.6652343 ] 1
# [ 0.45011994 -1.61075404] 1
# [-1.88020017 -9.32931857] 0
# [-0.42311973 -7.60300365] 0
# [ 2.07486928 -0.98886838] 1
# [ 0.25996514 -3.51884161] 1
# [-0.76703689 -8.79073328] 0
# [ 1.2044769  -2.50585887] 1
# [ 0.31990835 -8.80871324] 0
# [ -1.26631478 -10.50303413] 0
# [-2.65218964 -9.13881504] 0
# [  0.25574196 -10.20477577] 0
# [  0.93712208 -10.10569749] 0
# [-0.15688726 -9.07082746] 0
# [-0.64878279 -9.89238435] 0
# [ 1.18589273 -1.65251185] 1
# [-1.38275601 -0.90602729] 1
# [ 1.7365377  -0.98329216] 1
# [ 2.66952937 -0.66248768] 1
# [-0.99858225 -9.34073513] 0
# [-0.22222156 -0.82884358] 1
# [ -1.72977511 -10.12030014] 0
# [-1.52006844 -7.69354174] 0
# [ -0.65911099 -10.75089438] 0
# [ 2.99171102 -2.14613227] 1
# [-2.49401846 -7.87832124] 0
# [ -0.01221961 -10.04965552] 0
# [ 2.74154882 -1.3683033 ] 1
# [ 0.66826528 -1.86102229] 1
# [ -2.44491328 -11.18392104] 0
# [ 2.04487461 -0.56345434] 1
# [ 0.90017089 -0.07914235] 1
# [ 1.12341928 -1.08540968] 1
# [-2.33106217 -7.96297855] 0
# [ -0.78192706 -10.13737759] 0
# [-2.0393273 -8.8710376] 0
# [ 0.73237185 -1.54102468] 1
# [ 0.66783612 -1.90947763] 1
# [ -0.81753008 -10.82896833] 0
# [-1.21219059 -9.97076854] 0
# [-0.98641869 -9.20699599] 0
# [ 0.55516552 -2.46287413] 1
# [-2.3679044  -9.13192521] 0
# [ 0.91749375 -1.85154945] 1
# [-2.61350594 -9.95131604] 0
# [ -0.05833335 -11.31453832] 0
# [ 0.94993907 -1.26245923] 1
# [ 2.50816687 -1.57808849] 1
# [ 3.3851736  -1.09058204] 1
# [ 1.41259841 -1.35039473] 1
# [ 1.64632067 -1.89735976] 1
# [ 3.23031001 -1.69976211] 1
# [-0.62226803 -0.30581042] 1
# [ -1.14106943 -10.61187945] 0
# [ 0.24067071 -0.79433328] 1
# [ 1.36624215 -1.01520428] 1
# [ 0.35744747 -0.81547316] 1
# [ 1.98171227 -2.08372074] 1
# [-1.88697645 -9.86862987] 0
# [2.39264914 0.63186517] 1
# [-0.1250845   0.93023792] 1
# [ 1.7006468  -4.62851737] 1
# [1.93353951 0.57449177] 1
# [ 1.06350654 -0.66198253] 1
# [ -1.16230541 -10.01816067] 0
# [-1.64332648 -9.60231364] 0
# [ 1.19740826 -1.11325332] 1
# [ 0.20135221 -0.87082671] 1
# [ -0.06190154 -10.427644  ] 0
# [ 1.17408469 -2.02830585] 1
# [-0.53617155 -0.82985413] 1
# [-0.25438342 -1.92190919] 1
# [ 1.13308977 -0.04580469] 1
# [ -1.26320876 -10.86240539] 0
# [ 3.35693214 -1.78895415] 1
# [ 0.99501829 -1.64516558] 1
# [-0.26231932 -2.54243943] 1
# [-0.2564437  -8.83722618] 0
# [ 1.9697368  -1.82355822] 1
# [ -1.96366377 -10.960908  ] 0
# [  0.68747199 -10.30849933] 0
# [-1.46432821 -9.34316161] 0
# [-0.71806082 -9.79756939] 0
# [-0.50173608 -9.35879206] 0
# [ 1.22699201 -0.03153722] 1
# [ 1.57000133 -0.99822321] 1
# [  0.83261301 -12.28893247] 0
# [-1.70630209 -9.14212728] 0
# [4.04583769 0.23949904] 1
# [ 1.76340765 -0.59181051] 1
# [ -0.72996394 -11.10669886] 0
# [-0.20327231 -9.04406513] 0
# [ 1.85013585 -0.31517729] 1
# [ -3.22443289 -10.68562395] 0
# [ 0.61376319 -0.4692471 ] 1
# [-2.43031963 -8.79585762] 0
# [ 0.19855032 -9.66189528] 0
# [ 0.75293047 -0.97842957] 1
# [-3.09835441 -7.44482542] 0
# [-2.01034497 -9.45211592] 0
# [ 0.71137997 -1.52105196] 1
# [ -3.90982851 -10.55983182] 0
# [ 1.12367657 -1.72097396] 1
# [-1.35307817 -9.35896969] 0
# [ 0.51715516 -0.24849213] 1
# [ 1.24427807 -1.80544995] 1
# [1.4505947 0.3230335] 1
# [ 1.04525263 -2.47152495] 1
# [-1.19983134 -8.68795077] 0
# [ 0.14282774 -0.39565253] 1
# [ -2.18234803 -10.07244764] 0
# [-2.76256743 -8.63516347] 0
# [ 0.46171023 -9.92897624] 0
# [ 1.47097543 -2.80936289] 1
# [ 0.76119556 -9.0177211 ] 0
# [-3.38029365 -8.98030376] 0
# [ 1.93873954 -0.15591196] 1
# [ -0.54548692 -10.91474046] 0
# [ -2.8376654  -10.50133589] 0
# [-2.87455239 -9.40506035] 0
# [-1.38950334 -8.267982  ] 0
# [ 0.15407981 -0.14761657] 1
# [ 1.34678489 -0.1689991 ] 1
# [-1.32273757 -8.11887781] 0
# [-1.39603949 -9.38065823] 0
# [ 1.34816985 -0.5423269 ] 1
# [ 2.01890197 -1.07587912] 1
# [-1.04878484 -9.90572622] 0
# [ 0.14689558 -2.78934713] 1
# [ -1.08852831 -10.14368438] 0
# [0.94408113 1.16748276] 1
# [-1.83848893 -9.20938548] 0
# [-0.01839467 -0.20180819] 1
# [0.25943241 0.94564879] 1
# [-1.2821099  -8.68541403] 0
# [-1.88380218 -8.7261383 ] 0
# [-0.63654288 -9.45113945] 0
# [-0.31109677 -9.80216654] 0
# [-1.51073796 -7.29534307] 0
# [ 1.66740589 -1.28882707] 1
# [ -0.11902619 -10.47511915] 0
# [ 0.94274607 -0.92939997] 1
# [-2.0749744  -9.88676163] 0
# [ 2.94853028 -0.92165209] 1
# [ 0.7721469  -1.13777387] 1
# [ 0.63062486 -2.36434749] 1
# [ 1.55582995 -1.11897251] 1
# [ -1.15899638 -10.32830412] 0
# [-0.50999653 -1.50589989] 1
# [-0.55013541  1.41218118] 1
# [2.53979906 0.31438894] 1
# [ -1.63847443 -10.40155595] 0
# [ 0.68667082 -1.24095846] 1
# [  1.23008514 -10.81561213] 0
# [ 1.48099907 -2.37381342] 1
# [ 2.79915544 -0.82731578] 1
# [ 1.20303279 -2.08992412] 1
# [  0.50503135 -10.00227315] 0
# [ 0.44369394 -1.08589844] 1
# [-0.30220738 -9.90199985] 0
# [-0.69704828 -8.96994804] 0
# [-2.0015554  -8.89858166] 0
# [-2.39269101 -8.58401539] 0
# [ 2.90326704 -1.014657  ] 1
# [ -0.11526357 -10.66927707] 0
# [ -0.59534199 -11.18901441] 0
# [-1.93590892 -8.84582747] 0
# [1.67290011 0.50864521] 1
# [-0.8436303 -8.5379378] 0
# [ 0.02966237 -2.11621674] 1
# [ -2.87188968 -10.96905826] 0
# [ 1.27810143 -1.83305864] 1
# [-0.22484663 -8.78225334] 0
# [ -0.17845399 -10.00190106] 0
# [ 0.40235967 -0.50399576] 1
# [-0.76117703 -9.97447027] 0
# [0.14516773 0.09316934] 1
# [-1.51642535 -7.91347036] 0
# [ 0.41147609 -3.78928068] 1
# [-1.79803628 -8.90018912] 0
# [1.39778279 1.10458322] 1
# [1.18923976 0.50122776] 1
# [  1.02701332 -10.11601651] 0
# [ -0.1845597  -10.68564333] 0
# [-0.28937763 -8.38712467] 0
# [ 1.38795734 -1.01395038] 1
# [-1.75586415 -9.47636089] 0
# [ 0.40934872 -0.86382294] 1
# [ 1.85476227 -1.27824595] 1
# [ -1.24753649 -11.12203559] 0
# [-0.26680909 -7.72374454] 0
# [-1.65643605 -7.83785575] 0
# [  0.18937709 -10.28546313] 0
# [-0.45816915 -2.11783832] 1
# [ -2.0324175 -10.2365782] 0
# [ -0.92366614 -10.73454006] 0
# [ -1.0614862  -10.60643099] 0
# [ 0.73091962 -1.48209085] 1
# [ -2.53744465 -10.31923002] 0
# [-0.69721377 -4.30303864] 1
# [ -1.82746223 -10.23182501] 0
# [-2.00373646 -8.44303148] 0
# [ -0.52813711 -10.47523635] 0
# [ 0.45466073 -8.39270473] 0
# [-1.45983855 -9.88522379] 0
# [ -3.9561287  -10.44363278] 0
# [ 0.57975981 -1.55751926] 1
# [ 1.39858797 -1.97456486] 1
# [-0.91313386 -9.46076128] 0
# [  0.1385258  -10.21167575] 0
# [ 2.02636249 -0.50722717] 1
# [-1.50613352 -8.99427512] 0
# [ 0.52597844 -1.13719552] 1
# [ 3.42631871 -1.54619207] 1
# [-1.53722693 -9.61845366] 0
# [ 1.10606579 -8.8327205 ] 0
# [ -1.42013151 -10.83415289] 0
# [ 1.2815291  -0.59581183] 1
# [ 1.18143369 -2.01972924] 1
# [-0.78451356 -9.75329649] 0
# [-2.36566431 -9.98048545] 0
# [2.36153575 0.76340124] 1
# [-0.38727259 -8.1189064 ] 0
# [ 3.40229069 -1.26078591] 1
# [-0.40259006 -9.12372844] 0
# [ -3.07473452 -10.21628124] 0
# [ 1.34695583 -1.11220433] 1
# [-1.4684277  -1.66536993] 1
# [ 1.31253696 -0.81057552] 1
# [ 1.46404037 -0.66222231] 1
# [ 0.69150643 -1.73644015] 1
# [-1.74210731 -9.13058687] 0
# [-0.87086557 -9.26228159] 0
# [ -1.51204987 -11.0036551 ] 0
# [ 0.87864444 -0.41374639] 1
# [ 0.82919334 -0.18587331] 1
# [ -1.54349003 -10.15883586] 0
# [ -1.25167479 -10.53512128] 0
# [ 0.83932621 -1.83976817] 1
# [-3.22418291 -9.75186746] 0
# [ -0.6075791  -11.81501876] 0
# [ 1.32394116 -1.18326611] 1
# [ 2.11096474 -1.73049565] 1
# [-1.02466822 -9.05175991] 0
# [-1.44882728 -8.87372832] 0
# [-2.56764812 -7.61663663] 0
# [ 2.24199253 -1.67664949] 1
# [ 1.23790952 -8.45610845] 0
# [-0.43878752 -8.48581716] 0
# [-0.4442324  -2.08481562] 1
# [-1.24416778 -8.73986132] 0
# [ 2.48166097 -0.95262893] 1
# [-0.3522926  -8.31174375] 0
# [ 1.38230919 -2.88897585] 1
# [ -0.25308285 -10.49315713] 0
# [-1.74296783 -9.69592811] 0
# [ 0.93582831 -1.52000019] 1
# [-2.12542337 -8.27597772] 0
# [-1.71926227 -9.5205323 ] 0
# [ -0.77722054 -10.72676345] 0
# [ -1.02564803 -11.45895948] 0
# [ 1.42124471 -2.83156983] 1
# [-0.22770679 -9.79582844] 0
# [-1.82596423 -3.63565601] 1
# [ 0.22933486 -2.04177766] 1
# [ 0.14362589 -9.79813159] 0
# [-0.69661869 -9.92725616] 0

# %%
# load_model_sample.py TRY THIS FOR A SINGLE IMAGE https://stackoverflow.com/questions/43469281/how-to-predict-input-image-using-trained-model-in-keras
from keras.models import load_model
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
import os


def load_image(img_path, show=False):

    img = image.load_img(img_path, target_size=(150, 150))
    img_tensor = image.img_to_array(img)                    # (height, width, channels)
    img_tensor = np.expand_dims(img_tensor, axis=0)         # (1, height, width, channels), add a dimension because the model expects this shape: (batch_size, height, width, channels)
    img_tensor /= 255.                                      # imshow expects values in the range [0, 1]

    if show:
        plt.imshow(img_tensor[0])                           
        plt.axis('off')
        plt.show()

    return img_tensor


if __name__ == "__main__":

    # load model
    model = load_model("model_aug.h5")

    # image path
    img_path = '/media/data/dogscats/test1/3867.jpg'    # dog
    #img_path = '/media/data/dogscats/test1/19.jpg'      # cat

    # load a single image
    new_image = load_image(img_path)

    # check prediction
    pred = model.predict(new_image)

# %%
# TRY this also for a single image https://stackoverflow.com/questions/43469281/how-to-predict-input-image-using-trained-model-in-keras
# load_model_sample.py
from keras.models import load_model
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
import os


def load_image(img_path, show=False):

    img = image.load_img(img_path, target_size=(150, 150))
    img_tensor = image.img_to_array(img)                    # (height, width, channels)
    img_tensor = np.expand_dims(img_tensor, axis=0)         # (1, height, width, channels), add a dimension because the model expects this shape: (batch_size, height, width, channels)
    img_tensor /= 255.                                      # imshow expects values in the range [0, 1]

    if show:
        plt.imshow(img_tensor[0])                           
        plt.axis('off')
        plt.show()

    return img_tensor


if __name__ == "__main__":

    # load model
    model = load_model("model_aug.h5")

    # image path
    img_path = '/media/data/dogscats/test1/3867.jpg'    # dog
    #img_path = '/media/data/dogscats/test1/19.jpg'      # cat

    # load a single image
    new_image = load_image(img_path)

    # check prediction
    pred = model.predict(new_image)
